# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset
from collections import Counter
import numpy as np
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import pandas as pd
import re
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.model_selection import StratifiedKFold

# -----------------------------
# 1. Text Preprocessing Classes
# -----------------------------
class TextPreprocessor:
    def __init__(self, max_vocab_size=15000, max_seq_length=128):
        self.max_vocab_size = max_vocab_size
        self.max_seq_length = max_seq_length
        self.word2idx = {'<PAD>': 0, '<UNK>': 1}
        self.idx2word = {0: '<PAD>', 1: '<UNK>'}
        self.word_counts = Counter()
        
    def clean_text(self, text):
        text = str(text).lower()
        text = re.sub(r'[^a-zA-Z0-9\s.,!?]', '', text)
        text = ' '.join(text.split())
        return text
        
    def fit(self, texts):
        for text in texts:
            cleaned_text = self.clean_text(text)
            words = cleaned_text.split()
            self.word_counts.update(words)
        
        # Reserve two indices for PAD and UNK tokens
        vocab_words = [word for word, count in self.word_counts.most_common(self.max_vocab_size - 2)]
        for word in vocab_words:
            idx = len(self.word2idx)
            self.word2idx[word] = idx
            self.idx2word[idx] = word
    
    def transform(self, texts):
        sequences = []
        for text in texts:
            cleaned_text = self.clean_text(text)
            words = cleaned_text.split()
            # Truncate or pad sequences
            seq = [self.word2idx.get(word, self.word2idx['<UNK>']) for word in words[:self.max_seq_length]]
            seq = seq + [self.word2idx['<PAD>']] * (self.max_seq_length - len(seq))
            sequences.append(seq)
        return torch.tensor(sequences)

class TextDataset(Dataset):
    def __init__(self, texts, labels):
        self.texts = texts
        self.labels = labels
        
    def __len__(self):
        return len(self.texts)
    
    def __getitem__(self, idx):
        return self.texts[idx], self.labels[idx]

# -----------------------------
# 2. Define the Model
# -----------------------------
class ImprovedTextClassifier(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_classes, num_layers=2):
        super(ImprovedTextClassifier, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        self.embedding_dropout = nn.Dropout(0.2 if num_layers > 1 else 0.1)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, num_layers=num_layers, 
                            batch_first=True, bidirectional=True,
                            dropout=0.2 if num_layers > 1 else 0)
        self.attention = nn.Linear(hidden_dim * 2, 1)
        self.fc1 = nn.Linear(hidden_dim * 2, hidden_dim)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.dropout1 = nn.Dropout(0.3)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim // 2)
        self.bn2 = nn.BatchNorm1d(hidden_dim // 2)
        self.dropout2 = nn.Dropout(0.2)
        self.fc3 = nn.Linear(hidden_dim // 2, num_classes)
        
    def attention_net(self, lstm_output):
        # Compute attention weights and context vector
        energy = torch.tanh(self.attention(lstm_output))
        attention_weights = torch.softmax(self.attention(lstm_output), dim=1)
        context_vector = torch.sum(attention_weights * lstm_output, dim=1)
        return context_vector
        
    def forward(self, x):
        embedded = self.embedding(x)
        embedded = self.embedding_dropout(embedded)
        lstm_out, _ = self.lstm(embedded)
        attn_out = self.attention_net(lstm_out)
        x = self.fc1(attn_out)
        x = self.bn1(x)
        x = torch.relu(x)
        x = self.dropout1(x)
        x = self.fc2(x)
        x = self.bn2(x)
        x = torch.relu(x)
        x = self.dropout2(x)
        x = self.fc3(x)
        return x

# -----------------------------
# 3. Function to Load Pretrained Embeddings (GloVe)
# -----------------------------
def load_pretrained_embeddings(embedding_path, word2idx, embed_dim):
    print("Loading pretrained embeddings...")
    # Initialize embeddings with a uniform distribution
    embeddings = np.random.uniform(-0.05, 0.05, (len(word2idx), embed_dim))
    embeddings[word2idx['<PAD>']] = np.zeros(embed_dim)
    found = 0
    with open(embedding_path, 'r', encoding='utf-8') as f:
        for line in f:
            values = line.rstrip().split(' ')
            word = values[0]
            vector = np.asarray(values[1:], dtype='float32')
            if vector.shape[0] != embed_dim:
                continue  # Skip if dimensions mismatch
            if word in word2idx:
                embeddings[word2idx[word]] = vector
                found += 1
    print(f"Found {found} pretrained embeddings out of {len(word2idx)} words")
    return torch.tensor(embeddings, dtype=torch.float)

# -----------------------------
# 4. Training Function
# -----------------------------
def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs, device, preprocessor, config):
    best_f1 = 0
    patience = 5
    patience_counter = 0
    
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        train_preds = []
        train_labels = []
        
        for batch_texts, batch_labels in train_loader:
            batch_texts, batch_labels = batch_texts.to(device), batch_labels.to(device)
            optimizer.zero_grad()
            outputs = model(batch_texts)
            loss = criterion(outputs, batch_labels)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            train_loss += loss.item()
            predictions = torch.argmax(outputs, dim=1)
            train_preds.extend(predictions.cpu().numpy())
            train_labels.extend(batch_labels.cpu().numpy())
        
        model.eval()
        val_loss = 0
        val_preds = []
        val_labels = []
        
        with torch.no_grad():
            for batch_texts, batch_labels in val_loader:
                batch_texts, batch_labels = batch_texts.to(device), batch_labels.to(device)
                outputs = model(batch_texts)
                loss = criterion(outputs, batch_labels)
                val_loss += loss.item()
                predictions = torch.argmax(outputs, dim=1)
                val_preds.extend(predictions.cpu().numpy())
                val_labels.extend(batch_labels.cpu().numpy())
        
        train_precision, train_recall, train_f1, _ = precision_recall_fscore_support(train_labels, train_preds, average='binary')
        train_accuracy = accuracy_score(train_labels, train_preds)
        
        val_precision, val_recall, val_f1, _ = precision_recall_fscore_support(val_labels, val_preds, average='macro', zero_division=1)
        val_accuracy = accuracy_score(val_labels, val_preds)
        
        scheduler.step(val_loss)
        
        print(f'Epoch {epoch+1}/{num_epochs}:')
        print(f'Train Loss: {train_loss/len(train_loader):.4f}, Accuracy: {train_accuracy:.4f}, F1: {train_f1:.4f}')
        print(f'Val Loss: {val_loss/len(val_loader):.4f}, Accuracy: {val_accuracy:.4f}, F1: {val_f1:.4f}')
        print(f'Val Precision: {val_precision:.4f}, Recall: {val_recall:.4f}\n')
        
        if val_f1 > best_f1:
            best_f1 = val_f1
            torch.save({
                'model_state_dict': model.state_dict(),
                'preprocessor': preprocessor,
                'config': config
            }, 'best_model.pt')
            patience_counter = 0
        else:
            patience_counter += 1
            
        if patience_counter >= patience:

            print(f'Early stopping triggered after epoch {epoch+1}')
            break

# -----------------------------
# 5. Configuration and Data Loading
# -----------------------------
config = {
    'max_vocab_size': 15000,
    'max_seq_length': 128,
    'embed_dim': 300,  # Must match the dimension of the pretrained embeddings
    'hidden_dim': 256,
    'batch_size': 16,
    'learning_rate': 0.001,
    'num_epochs': 20,
    'num_lstm_layers': 2,
    'pretrained_embedding_path': '/Users/User/CSProjects/CSC392_AI_agent/emphatic-AI-Winter2025/glove.6B/glove.6B.300d.txt'  # Update this path as needed
}  

# Load your datasets (assumed to be in TSV format)
train_df = pd.read_csv('train.tsv', sep='\t')
test_df = pd.read_csv('test.tsv', sep='\t')

# Map your string labels to numerical values
label_mapping = {'NOCUOUS': 0, 'INNOCUOUS': 1}
train_df['Detected as'] = train_df['Detected as'].map(label_mapping)
test_df['Detected as'] = test_df['Detected as'].map(label_mapping)

# -----------------------------
# 6. Preprocessing
# -----------------------------
preprocessor = TextPreprocessor(max_vocab_size=config['max_vocab_size'], 
                                max_seq_length=config['max_seq_length'])
preprocessor.fit(train_df['Sentence'])

X_train = preprocessor.transform(train_df['Sentence'])
X_val = preprocessor.transform(test_df['Sentence'])
y_train = torch.tensor(train_df['Detected as'].values)
y_val = torch.tensor(test_df['Detected as'].values)

train_dataset = TextDataset(X_train, y_train)
val_dataset = TextDataset(X_val, y_val)

train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=config['batch_size'])

x_np = X_train.numpy()
y_np = y_train.numpy()

# ----------------------------
# 7. 10-Fold Cross Validation
# ----------------------------

num_folds = 10
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

fold_results = []

for fold, (train_idx, val_idx) in enumerate(skf.split(x_np, y_np)): 
    print(f"\n------- Fold {fold+1} / {num_folds} --------- ")

    # -----------------------------
    # 1. Split Data
    # -----------------------------
    X_train_fold = torch.tensor(x_np[train_idx])
    y_train_fold = torch.tensor(y_np[train_idx])
    X_val_fold = torch.tensor(x_np[val_idx])
    y_val_fold = torch.tensor(y_np[val_idx])

    train_dataset = TextDataset(X_train_fold, y_train_fold)
    val_dataset = TextDataset(X_val_fold, y_val_fold)

    train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=config['batch_size'])

    # -----------------------------
    # 2. Initialize Model, Optimizer, and Criterion Inside the Loop
    # -----------------------------
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    model = ImprovedTextClassifier(
        vocab_size=len(preprocessor.word2idx),
        embed_dim=config['embed_dim'],
        hidden_dim=config['hidden_dim'],
        num_classes=2,
        num_layers=config['num_lstm_layers']
    ).to(device)

    # Load pretrained embeddings and replace the embedding layer weights
    pretrained_weights = load_pretrained_embeddings(config['pretrained_embedding_path'], 
                                                    preprocessor.word2idx, 
                                                    config['embed_dim'])
    model.embedding = nn.Embedding.from_pretrained(pretrained_weights, freeze=False, padding_idx=0)

    # Compute class weights to handle class imbalance
    small_factor = 1e-4
    class_counts = torch.bincount(y_train_fold) + small_factor  # Avoid division by zero
    class_weights = 1.0 / class_counts.float()
    class_weights = class_weights / class_weights.sum()
    class_weights = class_weights.to(device)

    criterion = nn.CrossEntropyLoss(weight=class_weights)
    optimizer = optim.AdamW(model.parameters(), lr=config['learning_rate'], weight_decay=0.01)
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2, verbose=True)

    # -----------------------------
    # 3. Train the Model
    # -----------------------------
    train_model(model, train_loader, val_loader, criterion, optimizer, scheduler,
                config['num_epochs'], device, preprocessor, config)

    # Load the best model for this fold
    with torch.serialization.safe_globals([TextPreprocessor]):
        checkpoint = torch.load('best_model.pt', weights_only=False)
    
    model.load_state_dict(checkpoint['model_state_dict'])

    # -----------------------------
    # 4. Evaluate the Model
    # -----------------------------
    model.eval()
    val_preds = []
    val_labels = []

    with torch.no_grad():
        for batch_texts, batch_labels in val_loader:
            batch_texts, batch_labels = batch_texts.to(device), batch_labels.to(device)
            outputs = model(batch_texts)
            predictions = torch.argmax(outputs, dim=1)
            val_preds.extend(predictions.cpu().numpy())
            val_labels.extend(batch_labels.cpu().numpy())

    # Compute metrics
    val_precision, val_recall, val_f1, _ = precision_recall_fscore_support(val_labels, val_preds, average='binary')
    val_accuracy = accuracy_score(val_labels, val_preds)

    print(f"Fold {fold+1} Metrics:")
    print(f"Accuracy: {val_accuracy:.4f}, F1-score: {val_f1:.4f}, Precision: {val_precision:.4f}, Recall: {val_recall:.4f}\n")

    fold_results.append((val_accuracy, val_f1, val_precision, val_recall))

# -----------------------------
# 5. Display Overall Results
# -----------------------------
avg_accuracy = sum([x[0] for x in fold_results]) / num_folds
avg_f1 = sum([x[1] for x in fold_results]) / num_folds
avg_precision = sum([x[2] for x in fold_results]) / num_folds
avg_recall = sum([x[3] for x in fold_results]) / num_folds

print("\n========== Final Cross-Validation Results ==========")
print(f"Avg Accuracy: {avg_accuracy:.4f}, Avg F1-score: {avg_f1:.4f}, Avg Precision: {avg_precision:.4f}, Avg Recall: {avg_recall:.4f}")
# Out:
# ------- Fold 1 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/20:
# Train Loss: 0.6935, Accuracy: 0.6160, F1: 0.6000
# Val Loss: 0.6889, Accuracy: 0.5714, F1: 0.3636
# Val Precision: 0.7857, Recall: 0.5000
#
# Epoch 2/20:
# Train Loss: 0.6790, Accuracy: 0.5760, F1: 0.5954
# Val Loss: 0.6938, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4500, Recall: 0.4583
#
# Epoch 3/20:
# Train Loss: 0.4158, Accuracy: 0.8000, F1: 0.8000
# Val Loss: 0.6845, Accuracy: 0.5714, F1: 0.3636
# Val Precision: 0.7857, Recall: 0.5000
#
# Epoch 4/20:
# Train Loss: 0.3368, Accuracy: 0.8880, F1: 0.8852
# Val Loss: 0.6877, Accuracy: 0.5714, F1: 0.3636
# Val Precision: 0.7857, Recall: 0.5000
#
# Epoch 5/20:
# Train Loss: 0.4264, Accuracy: 0.8320, F1: 0.8346
# Val Loss: 0.6892, Accuracy: 0.5714, F1: 0.4750
# Val Precision: 0.5417, Recall: 0.5208
#
# Epoch 6/20:
# Train Loss: 0.2371, Accuracy: 0.9120, F1: 0.9134
# Val Loss: 0.7318, Accuracy: 0.5714, F1: 0.5333
# Val Precision: 0.5500, Recall: 0.5417
#
# Epoch 7/20:
# Train Loss: 0.1230, Accuracy: 0.9760, F1: 0.9752
# Val Loss: 0.8211, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 8/20:
# Train Loss: 0.1724, Accuracy: 0.9520, F1: 0.9500
# Val Loss: 1.0435, Accuracy: 0.5000, F1: 0.4759
# Val Precision: 0.5606, Recall: 0.5417
#
# Epoch 9/20:
# Train Loss: 0.1344, Accuracy: 0.9680, F1: 0.9661
# Val Loss: 1.1984, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 10/20:
# Train Loss: 0.1189, Accuracy: 0.9520, F1: 0.9500
# Val Loss: 1.4839, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5222, Recall: 0.5208
#
# Epoch 11/20:
# Train Loss: 0.0528, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.5916, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5222, Recall: 0.5208
#
# Epoch 12/20:
# Train Loss: 0.1074, Accuracy: 0.9680, F1: 0.9672
# Val Loss: 1.4669, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Early stopping triggered after epoch 12
# Fold 1 Metrics:
# Accuracy: 0.6429, F1-score: 0.6154, Precision: 0.5714, Recall: 0.6667
#
#
# ------- Fold 2 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/20:
# Train Loss: 0.7580, Accuracy: 0.5280, F1: 0.5693
# Val Loss: 0.6969, Accuracy: 0.4286, F1: 0.3000
# Val Precision: 0.7143, Recall: 0.5000
#
# Epoch 2/20:
# Train Loss: 0.6284, Accuracy: 0.6160, F1: 0.6190
# Val Loss: 0.6935, Accuracy: 0.5000, F1: 0.4759
# Val Precision: 0.5606, Recall: 0.5417
#
# Epoch 3/20:
# Train Loss: 0.5490, Accuracy: 0.7360, F1: 0.7402
# Val Loss: 0.6916, Accuracy: 0.7143, F1: 0.6889
# Val Precision: 0.7250, Recall: 0.6875
#
# Epoch 4/20:
# Train Loss: 0.3939, Accuracy: 0.8160, F1: 0.8067
# Val Loss: 0.6735, Accuracy: 0.7143, F1: 0.6889
# Val Precision: 0.7250, Recall: 0.6875
#
# Epoch 5/20:
# Train Loss: 0.3238, Accuracy: 0.8560, F1: 0.8500
# Val Loss: 0.6819, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 6/20:
# Train Loss: 0.3326, Accuracy: 0.8880, F1: 0.8871
# Val Loss: 0.7576, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 7/20:
# Train Loss: 0.2153, Accuracy: 0.9280, F1: 0.9280
# Val Loss: 0.8399, Accuracy: 0.5714, F1: 0.3636
# Val Precision: 0.7857, Recall: 0.5000
#
# Epoch 8/20:
# Train Loss: 0.1862, Accuracy: 0.9360, F1: 0.9333
# Val Loss: 1.0162, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Early stopping triggered after epoch 8
# Fold 2 Metrics:
# Accuracy: 0.7143, F1-score: 0.6000, Precision: 0.7500, Recall: 0.5000
#
#
# ------- Fold 3 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/20:
# Train Loss: 0.7252, Accuracy: 0.5200, F1: 0.4118
# Val Loss: 0.6893, Accuracy: 0.5714, F1: 0.3636
# Val Precision: 0.7857, Recall: 0.5000
#
# Epoch 2/20:
# Train Loss: 0.6070, Accuracy: 0.6960, F1: 0.6885
# Val Loss: 0.6893, Accuracy: 0.5714, F1: 0.3636
# Val Precision: 0.7857, Recall: 0.5000
#
# Epoch 3/20:
# Train Loss: 0.5642, Accuracy: 0.7360, F1: 0.7442
# Val Loss: 0.6844, Accuracy: 0.5714, F1: 0.3636
# Val Precision: 0.7857, Recall: 0.5000
#
# Epoch 4/20:
# Train Loss: 0.4243, Accuracy: 0.8080, F1: 0.8065
# Val Loss: 0.6745, Accuracy: 0.5714, F1: 0.3636
# Val Precision: 0.7857, Recall: 0.5000
#
# Epoch 5/20:
# Train Loss: 0.3284, Accuracy: 0.8640, F1: 0.8640
# Val Loss: 0.7074, Accuracy: 0.3571, F1: 0.3538
# Val Precision: 0.3571, Recall: 0.3542
#
# Epoch 6/20:
# Train Loss: 0.3413, Accuracy: 0.8400, F1: 0.8361
# Val Loss: 0.6247, Accuracy: 0.7857, F1: 0.7846
# Val Precision: 0.7857, Recall: 0.7917
#
# Epoch 7/20:
# Train Loss: 0.1642, Accuracy: 0.9760, F1: 0.9748
# Val Loss: 0.7961, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 8/20:
# Train Loss: 0.1370, Accuracy: 0.9600, F1: 0.9587
# Val Loss: 2.0437, Accuracy: 0.6429, F1: 0.5238
# Val Precision: 0.8077, Recall: 0.5833
#
# Epoch 9/20:
# Train Loss: 0.1979, Accuracy: 0.9520, F1: 0.9492
# Val Loss: 2.0458, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 10/20:
# Train Loss: 0.0532, Accuracy: 0.9840, F1: 0.9836
# Val Loss: 2.0171, Accuracy: 0.5000, F1: 0.4759
# Val Precision: 0.5606, Recall: 0.5417
#
# Epoch 11/20:
# Train Loss: 0.0879, Accuracy: 0.9680, F1: 0.9672
# Val Loss: 0.9641, Accuracy: 0.7857, F1: 0.7846
# Val Precision: 0.7857, Recall: 0.7917
#
# Early stopping triggered after epoch 11
# Fold 3 Metrics:
# Accuracy: 0.7857, F1-score: 0.7692, Precision: 0.7143, Recall: 0.8333
#
#
# ------- Fold 4 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/20:
# Train Loss: 0.7706, Accuracy: 0.6000, F1: 0.4186
# Val Loss: 0.6898, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 2/20:
# Train Loss: 0.7165, Accuracy: 0.6560, F1: 0.5905
# Val Loss: 0.6922, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 3/20:
# Train Loss: 0.5299, Accuracy: 0.7520, F1: 0.7438
# Val Loss: 0.6849, Accuracy: 0.5000, F1: 0.4269
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 4/20:
# Train Loss: 0.4323, Accuracy: 0.8240, F1: 0.8197
# Val Loss: 0.6551, Accuracy: 0.4286, F1: 0.3000
# Val Precision: 0.2308, Recall: 0.4286
#
# Epoch 5/20:
# Train Loss: 0.3424, Accuracy: 0.8800, F1: 0.8780
# Val Loss: 0.7125, Accuracy: 0.4286, F1: 0.3000
# Val Precision: 0.2308, Recall: 0.4286
#
# Epoch 6/20:
# Train Loss: 0.2870, Accuracy: 0.9200, F1: 0.9167
# Val Loss: 0.6554, Accuracy: 0.6429, F1: 0.6257
# Val Precision: 0.6750, Recall: 0.6429
#
# Epoch 7/20:
# Train Loss: 0.1898, Accuracy: 0.9200, F1: 0.9194
# Val Loss: 0.7412, Accuracy: 0.5714, F1: 0.5333
# Val Precision: 0.6061, Recall: 0.5714
#
# Epoch 8/20:
# Train Loss: 0.1642, Accuracy: 0.9520, F1: 0.9474
# Val Loss: 0.6907, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7333, Recall: 0.7143
#
# Epoch 9/20:
# Train Loss: 0.1255, Accuracy: 0.9760, F1: 0.9752
# Val Loss: 0.7006, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7333, Recall: 0.7143
#
# Epoch 10/20:
# Train Loss: 0.0806, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 0.8934, Accuracy: 0.6429, F1: 0.6257
# Val Precision: 0.6750, Recall: 0.6429
#
# Epoch 11/20:
# Train Loss: 0.0652, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 0.8345, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7333, Recall: 0.7143
#
# Epoch 12/20:
# Train Loss: 0.0725, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 0.9866, Accuracy: 0.6429, F1: 0.6257
# Val Precision: 0.6750, Recall: 0.6429
#
# Epoch 13/20:
# Train Loss: 0.0460, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 0.9442, Accuracy: 0.6429, F1: 0.6257
# Val Precision: 0.6750, Recall: 0.6429
#
# Early stopping triggered after epoch 13
# Fold 4 Metrics:
# Accuracy: 0.7143, F1-score: 0.7500, Precision: 0.6667, Recall: 0.8571
#
#
# ------- Fold 5 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/20:
# Train Loss: 0.7106, Accuracy: 0.5840, F1: 0.5806
# Val Loss: 0.6914, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 2/20:
# Train Loss: 0.6076, Accuracy: 0.7200, F1: 0.7059
# Val Loss: 0.6891, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 3/20:
# Train Loss: 0.5463, Accuracy: 0.7040, F1: 0.6838
# Val Loss: 0.6879, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 4/20:
# Train Loss: 0.4185, Accuracy: 0.8000, F1: 0.7934
# Val Loss: 0.8098, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 5/20:
# Train Loss: 0.3501, Accuracy: 0.8320, F1: 0.8293
# Val Loss: 0.8626, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 6/20:
# Train Loss: 0.2588, Accuracy: 0.8800, F1: 0.8673
# Val Loss: 0.9187, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Early stopping triggered after epoch 6
# Fold 5 Metrics:
# Accuracy: 0.5000, F1-score: 0.6667, Precision: 0.5000, Recall: 1.0000
#
#
# ------- Fold 6 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/20:
# Train Loss: 0.6959, Accuracy: 0.5920, F1: 0.5854
# Val Loss: 0.6920, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 2/20:
# Train Loss: 0.5874, Accuracy: 0.7040, F1: 0.6992
# Val Loss: 0.6890, Accuracy: 0.5714, F1: 0.4750
# Val Precision: 0.7692, Recall: 0.5714
#
# Epoch 3/20:
# Train Loss: 0.4479, Accuracy: 0.8080, F1: 0.7931
# Val Loss: 0.6713, Accuracy: 0.5714, F1: 0.4750
# Val Precision: 0.7692, Recall: 0.5714
#
# Epoch 4/20:
# Train Loss: 0.3461, Accuracy: 0.8640, F1: 0.8640
# Val Loss: 0.6537, Accuracy: 0.5714, F1: 0.4750
# Val Precision: 0.7692, Recall: 0.5714
#
# Epoch 5/20:
# Train Loss: 0.2894, Accuracy: 0.8960, F1: 0.8926
# Val Loss: 0.6447, Accuracy: 0.6429, F1: 0.5906
# Val Precision: 0.7917, Recall: 0.6429
#
# Epoch 6/20:
# Train Loss: 0.2108, Accuracy: 0.9440, F1: 0.9402
# Val Loss: 0.6315, Accuracy: 0.6429, F1: 0.5906
# Val Precision: 0.7917, Recall: 0.6429
#
# Epoch 7/20:
# Train Loss: 0.1775, Accuracy: 0.9360, F1: 0.9322
# Val Loss: 0.4771, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7333, Recall: 0.7143
#
# Epoch 8/20:
# Train Loss: 0.1390, Accuracy: 0.9440, F1: 0.9412
# Val Loss: 0.8005, Accuracy: 0.6429, F1: 0.5906
# Val Precision: 0.7917, Recall: 0.6429
#
# Epoch 9/20:
# Train Loss: 0.1130, Accuracy: 0.9440, F1: 0.9431
# Val Loss: 1.4198, Accuracy: 0.6429, F1: 0.5906
# Val Precision: 0.7917, Recall: 0.6429
#
# Epoch 10/20:
# Train Loss: 0.1220, Accuracy: 0.9680, F1: 0.9667
# Val Loss: 0.6639, Accuracy: 0.7857, F1: 0.7846
# Val Precision: 0.7917, Recall: 0.7857
#
# Epoch 11/20:
# Train Loss: 0.0866, Accuracy: 0.9600, F1: 0.9573
# Val Loss: 0.8592, Accuracy: 0.7857, F1: 0.7754
# Val Precision: 0.8500, Recall: 0.7857
#
# Epoch 12/20:
# Train Loss: 0.0510, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.0183, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7333, Recall: 0.7143
#
# Epoch 13/20:
# Train Loss: 0.0221, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2386, Accuracy: 0.6429, F1: 0.6257
# Val Precision: 0.6750, Recall: 0.6429
#
# Epoch 14/20:
# Train Loss: 0.0397, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 0.9642, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7143, Recall: 0.7143
#
# Epoch 15/20:
# Train Loss: 0.0137, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3636, Accuracy: 0.6429, F1: 0.6257
# Val Precision: 0.6750, Recall: 0.6429
#
# Early stopping triggered after epoch 15
# Fold 6 Metrics:
# Accuracy: 0.7857, F1-score: 0.8000, Precision: 0.7500, Recall: 0.8571
#
#
# ------- Fold 7 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/20:
# Train Loss: 0.7253, Accuracy: 0.6080, F1: 0.5664
# Val Loss: 0.6922, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 2/20:
# Train Loss: 0.6093, Accuracy: 0.7120, F1: 0.7000
# Val Loss: 0.6945, Accuracy: 0.5714, F1: 0.4750
# Val Precision: 0.7692, Recall: 0.5714
#
# Epoch 3/20:
# Train Loss: 0.5188, Accuracy: 0.7520, F1: 0.7559
# Val Loss: 0.6995, Accuracy: 0.5000, F1: 0.4269
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 4/20:
# Train Loss: 0.3730, Accuracy: 0.8400, F1: 0.8333
# Val Loss: 0.7250, Accuracy: 0.3571, F1: 0.3538
# Val Precision: 0.3542, Recall: 0.3571
#
# Epoch 5/20:
# Train Loss: 0.2503, Accuracy: 0.9040, F1: 0.9016
# Val Loss: 0.7672, Accuracy: 0.3571, F1: 0.3538
# Val Precision: 0.3542, Recall: 0.3571
#
# Epoch 6/20:
# Train Loss: 0.2585, Accuracy: 0.8880, F1: 0.8793
# Val Loss: 0.8827, Accuracy: 0.4286, F1: 0.3778
# Val Precision: 0.3939, Recall: 0.4286
#
# Epoch 7/20:
# Train Loss: 0.2005, Accuracy: 0.9280, F1: 0.9231
# Val Loss: 1.0068, Accuracy: 0.2857, F1: 0.2708
# Val Precision: 0.2667, Recall: 0.2857
#
# Early stopping triggered after epoch 7
# Fold 7 Metrics:
# Accuracy: 0.5714, F1-score: 0.7000, Precision: 0.5385, Recall: 1.0000
#
#
# ------- Fold 8 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/20:
# Train Loss: 0.7342, Accuracy: 0.5760, F1: 0.5546
# Val Loss: 0.6923, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 2/20:
# Train Loss: 0.5887, Accuracy: 0.6720, F1: 0.6555
# Val Loss: 0.6944, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 3/20:
# Train Loss: 0.5088, Accuracy: 0.7680, F1: 0.7603
# Val Loss: 0.7001, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 4/20:
# Train Loss: 0.3849, Accuracy: 0.8640, F1: 0.8661
# Val Loss: 0.6617, Accuracy: 0.4286, F1: 0.3000
# Val Precision: 0.2308, Recall: 0.4286
#
# Epoch 5/20:
# Train Loss: 0.3017, Accuracy: 0.8800, F1: 0.8780
# Val Loss: 0.7202, Accuracy: 0.7857, F1: 0.7754
# Val Precision: 0.8500, Recall: 0.7857
#
# Epoch 6/20:
# Train Loss: 0.2245, Accuracy: 0.9040, F1: 0.9000
# Val Loss: 0.8900, Accuracy: 0.7857, F1: 0.7846
# Val Precision: 0.7917, Recall: 0.7857
#
# Epoch 7/20:
# Train Loss: 0.1350, Accuracy: 0.9680, F1: 0.9667
# Val Loss: 1.1275, Accuracy: 0.4286, F1: 0.3000
# Val Precision: 0.2308, Recall: 0.4286
#
# Epoch 8/20:
# Train Loss: 0.1149, Accuracy: 0.9440, F1: 0.9421
# Val Loss: 1.0214, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 9/20:
# Train Loss: 0.0616, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.0956, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 10/20:
# Train Loss: 0.0824, Accuracy: 0.9760, F1: 0.9744
# Val Loss: 1.4268, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 11/20:
# Train Loss: 0.0437, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.3719, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Early stopping triggered after epoch 11
# Fold 8 Metrics:
# Accuracy: 0.7857, F1-score: 0.7692, Precision: 0.8333, Recall: 0.7143
#
#
# ------- Fold 9 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/20:
# Train Loss: 0.7644, Accuracy: 0.5040, F1: 0.5921
# Val Loss: 0.6890, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 2/20:
# Train Loss: 0.6415, Accuracy: 0.6320, F1: 0.6515
# Val Loss: 0.6894, Accuracy: 0.5714, F1: 0.4750
# Val Precision: 0.7692, Recall: 0.5714
#
# Epoch 3/20:
# Train Loss: 0.4477, Accuracy: 0.8320, F1: 0.8205
# Val Loss: 0.6903, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 4/20:
# Train Loss: 0.4553, Accuracy: 0.7680, F1: 0.7521
# Val Loss: 0.7016, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 5/20:
# Train Loss: 0.2312, Accuracy: 0.9280, F1: 0.9231
# Val Loss: 0.7439, Accuracy: 0.4286, F1: 0.3000
# Val Precision: 0.2308, Recall: 0.4286
#
# Epoch 6/20:
# Train Loss: 0.1689, Accuracy: 0.9600, F1: 0.9573
# Val Loss: 0.8167, Accuracy: 0.4286, F1: 0.3000
# Val Precision: 0.2308, Recall: 0.4286
#
# Epoch 7/20:
# Train Loss: 0.2467, Accuracy: 0.9040, F1: 0.8966
# Val Loss: 0.9061, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 8/20:
# Train Loss: 0.1593, Accuracy: 0.9520, F1: 0.9483
# Val Loss: 0.9431, Accuracy: 0.4286, F1: 0.4286
# Val Precision: 0.4286, Recall: 0.4286
#
# Early stopping triggered after epoch 8
# Fold 9 Metrics:
# Accuracy: 0.5714, F1-score: 0.6250, Precision: 0.5556, Recall: 0.7143
#
#
# ------- Fold 10 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/20:
# Train Loss: 0.7525, Accuracy: 0.5794, F1: 0.6074
# Val Loss: 0.6952, Accuracy: 0.4615, F1: 0.3158
# Val Precision: 0.7308, Recall: 0.5000
#
# Epoch 2/20:
# Train Loss: 0.5937, Accuracy: 0.6984, F1: 0.7206
# Val Loss: 0.6966, Accuracy: 0.4615, F1: 0.3158
# Val Precision: 0.7308, Recall: 0.5000
#
# Epoch 3/20:
# Train Loss: 0.5428, Accuracy: 0.7222, F1: 0.7287
# Val Loss: 0.6839, Accuracy: 0.5385, F1: 0.3500
# Val Precision: 0.7692, Recall: 0.5000
#
# Epoch 4/20:
# Train Loss: 0.3487, Accuracy: 0.8492, F1: 0.8455
# Val Loss: 0.7021, Accuracy: 0.5385, F1: 0.3500
# Val Precision: 0.7692, Recall: 0.5000
#
# Epoch 5/20:
# Train Loss: 0.2916, Accuracy: 0.8810, F1: 0.8739
# Val Loss: 0.8636, Accuracy: 0.5385, F1: 0.3500
# Val Precision: 0.7692, Recall: 0.5000
#
# Epoch 6/20:
# Train Loss: 0.2169, Accuracy: 0.9206, F1: 0.9138
# Val Loss: 0.8874, Accuracy: 0.3077, F1: 0.2909
# Val Precision: 0.2875, Recall: 0.2976
#
# Epoch 7/20:
# Train Loss: 0.0790, Accuracy: 0.9921, F1: 0.9916
# Val Loss: 1.0984, Accuracy: 0.3077, F1: 0.3077
# Val Precision: 0.3095, Recall: 0.3095
#
# Epoch 8/20:
# Train Loss: 0.0707, Accuracy: 0.9921, F1: 0.9916
# Val Loss: 1.3256, Accuracy: 0.4615, F1: 0.4615
# Val Precision: 0.4643, Recall: 0.4643
#
# Epoch 9/20:
# Train Loss: 0.0838, Accuracy: 0.9683, F1: 0.9667
# Val Loss: 1.5671, Accuracy: 0.3846, F1: 0.3810
# Val Precision: 0.3810, Recall: 0.3810
#
# Epoch 10/20:
# Train Loss: 0.1292, Accuracy: 0.9524, F1: 0.9483
# Val Loss: 1.8467, Accuracy: 0.3077, F1: 0.2909
# Val Precision: 0.2875, Recall: 0.2976
#
# Epoch 11/20:
# Train Loss: 0.0708, Accuracy: 0.9841, F1: 0.9833
# Val Loss: 2.0251, Accuracy: 0.3077, F1: 0.2909
# Val Precision: 0.2875, Recall: 0.2976
#
# Epoch 12/20:
# Train Loss: 0.0302, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.6308, Accuracy: 0.3846, F1: 0.3810
# Val Precision: 0.3875, Recall: 0.3929
#
# Epoch 13/20:
# Train Loss: 0.0651, Accuracy: 0.9762, F1: 0.9756
# Val Loss: 2.6769, Accuracy: 0.2308, F1: 0.2262
# Val Precision: 0.2262, Recall: 0.2262
#
# Early stopping triggered after epoch 13
# Fold 10 Metrics:
# Accuracy: 0.4615, F1-score: 0.4615, Precision: 0.4286, Recall: 0.5000
#
#
# ========== Final Cross-Validation Results ==========
# Avg Accuracy: 0.6533, Avg F1-score: 0.6757, Avg Precision: 0.6308, Avg Recall: 0.7643

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset
from collections import Counter
import numpy as np
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import pandas as pd
import re
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.model_selection import StratifiedKFold

# -----------------------------
# 1. Text Preprocessing Classes
# -----------------------------
class TextPreprocessor:
    def __init__(self, max_vocab_size=15000, max_seq_length=128):
        self.max_vocab_size = max_vocab_size
        self.max_seq_length = max_seq_length
        self.word2idx = {'<PAD>': 0, '<UNK>': 1}
        self.idx2word = {0: '<PAD>', 1: '<UNK>'}
        self.word_counts = Counter()
        
    def clean_text(self, text):
        text = str(text).lower()
        text = re.sub(r'[^a-zA-Z0-9\s.,!?]', '', text)
        text = ' '.join(text.split())
        return text
        
    def fit(self, texts):
        for text in texts:
            cleaned_text = self.clean_text(text)
            words = cleaned_text.split()
            self.word_counts.update(words)
        
        # Reserve two indices for PAD and UNK tokens
        vocab_words = [word for word, count in self.word_counts.most_common(self.max_vocab_size - 2)]
        for word in vocab_words:
            idx = len(self.word2idx)
            self.word2idx[word] = idx
            self.idx2word[idx] = word
    
    def transform(self, texts):
        sequences = []
        for text in texts:
            cleaned_text = self.clean_text(text)
            words = cleaned_text.split()
            # Truncate or pad sequences
            seq = [self.word2idx.get(word, self.word2idx['<UNK>']) for word in words[:self.max_seq_length]]
            seq = seq + [self.word2idx['<PAD>']] * (self.max_seq_length - len(seq))
            sequences.append(seq)
        return torch.tensor(sequences)

class TextDataset(Dataset):
    def __init__(self, texts, labels):
        self.texts = texts
        self.labels = labels
        
    def __len__(self):
        return len(self.texts)
    
    def __getitem__(self, idx):
        return self.texts[idx], self.labels[idx]

# -----------------------------
# 2. Define the Model
# -----------------------------
class ImprovedTextClassifier(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_classes, num_layers=2):
        super(ImprovedTextClassifier, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        self.embedding_dropout = nn.Dropout(0.2 if num_layers > 1 else 0.1)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, num_layers=num_layers, 
                            batch_first=True, bidirectional=True,
                            dropout=0.2 if num_layers > 1 else 0)
        self.attention = nn.Linear(hidden_dim * 2, 1)
        self.fc1 = nn.Linear(hidden_dim * 2, hidden_dim)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.dropout1 = nn.Dropout(0.3)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim // 2)
        self.bn2 = nn.BatchNorm1d(hidden_dim // 2)
        self.dropout2 = nn.Dropout(0.2)
        self.fc3 = nn.Linear(hidden_dim // 2, num_classes)
        
    def attention_net(self, lstm_output):
        # Compute attention weights and context vector
        energy = torch.tanh(self.attention(lstm_output))
        attention_weights = torch.softmax(self.attention(lstm_output), dim=1)
        context_vector = torch.sum(attention_weights * lstm_output, dim=1)
        return context_vector
        
    def forward(self, x):
        embedded = self.embedding(x)
        embedded = self.embedding_dropout(embedded)
        lstm_out, _ = self.lstm(embedded)
        attn_out = self.attention_net(lstm_out)
        x = self.fc1(attn_out)
        x = self.bn1(x)
        x = torch.relu(x)
        x = self.dropout1(x)
        x = self.fc2(x)
        x = self.bn2(x)
        x = torch.relu(x)
        x = self.dropout2(x)
        x = self.fc3(x)
        return x

# -----------------------------
# 3. Function to Load Pretrained Embeddings (GloVe)
# -----------------------------
def load_pretrained_embeddings(embedding_path, word2idx, embed_dim):
    print("Loading pretrained embeddings...")
    # Initialize embeddings with a uniform distribution
    embeddings = np.random.uniform(-0.05, 0.05, (len(word2idx), embed_dim))
    embeddings[word2idx['<PAD>']] = np.zeros(embed_dim)
    found = 0
    with open(embedding_path, 'r', encoding='utf-8') as f:
        for line in f:
            values = line.rstrip().split(' ')
            word = values[0]
            vector = np.asarray(values[1:], dtype='float32')
            if vector.shape[0] != embed_dim:
                continue  # Skip if dimensions mismatch
            if word in word2idx:
                embeddings[word2idx[word]] = vector
                found += 1
    print(f"Found {found} pretrained embeddings out of {len(word2idx)} words")
    return torch.tensor(embeddings, dtype=torch.float)

# -----------------------------
# 4. Training Function
# -----------------------------
def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs, device, preprocessor, config):
    best_f1 = 0
    #patience = 5
    # patience_counter = 0
    
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        train_preds = []
        train_labels = []
        
        for batch_texts, batch_labels in train_loader:
            batch_texts, batch_labels = batch_texts.to(device), batch_labels.to(device)
            optimizer.zero_grad()
            outputs = model(batch_texts)
            loss = criterion(outputs, batch_labels)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            train_loss += loss.item()
            predictions = torch.argmax(outputs, dim=1)
            train_preds.extend(predictions.cpu().numpy())
            train_labels.extend(batch_labels.cpu().numpy())
        
        model.eval()
        val_loss = 0
        val_preds = []
        val_labels = []
        
        with torch.no_grad():
            for batch_texts, batch_labels in val_loader:
                batch_texts, batch_labels = batch_texts.to(device), batch_labels.to(device)
                outputs = model(batch_texts)
                loss = criterion(outputs, batch_labels)
                val_loss += loss.item()
                predictions = torch.argmax(outputs, dim=1)
                val_preds.extend(predictions.cpu().numpy())
                val_labels.extend(batch_labels.cpu().numpy())
        
        train_precision, train_recall, train_f1, _ = precision_recall_fscore_support(train_labels, train_preds, average='binary')
        train_accuracy = accuracy_score(train_labels, train_preds)
        
        val_precision, val_recall, val_f1, _ = precision_recall_fscore_support(val_labels, val_preds, average='macro', zero_division=1)
        val_accuracy = accuracy_score(val_labels, val_preds)
        
        scheduler.step(val_loss)
        
        print(f'Epoch {epoch+1}/{num_epochs}:')
        print(f'Train Loss: {train_loss/len(train_loader):.4f}, Accuracy: {train_accuracy:.4f}, F1: {train_f1:.4f}')
        print(f'Val Loss: {val_loss/len(val_loader):.4f}, Accuracy: {val_accuracy:.4f}, F1: {val_f1:.4f}')
        print(f'Val Precision: {val_precision:.4f}, Recall: {val_recall:.4f}\n')
        
        if val_f1 > best_f1:
            best_f1 = val_f1
            torch.save({
                'model_state_dict': model.state_dict(),
                'preprocessor': preprocessor,
                'config': config
            }, 'best_model.pt')
            #patience_counter = 0
            #patience_counter += 1
            
        # if patience_counter >= patience:

        #     print(f'Early stopping triggered after epoch {epoch+1}')
        #     break

# -----------------------------
# 5. Configuration and Data Loading
# -----------------------------
config = {
    'max_vocab_size': 15000,
    'max_seq_length': 128,
    'embed_dim': 300,  # Must match the dimension of the pretrained embeddings
    'hidden_dim': 256,
    'batch_size': 16,
    'learning_rate': 0.001,
    'num_epochs': 50,
    'num_lstm_layers': 2,
    'pretrained_embedding_path': '/Users/User/CSProjects/CSC392_AI_agent/emphatic-AI-Winter2025/glove.6B/glove.6B.300d.txt'  # Update this path as needed
}  

# Load your datasets (assumed to be in TSV format)
train_df = pd.read_csv('train.tsv', sep='\t')
test_df = pd.read_csv('test.tsv', sep='\t')

# Map your string labels to numerical values
label_mapping = {'NOCUOUS': 0, 'INNOCUOUS': 1}
train_df['Detected as'] = train_df['Detected as'].map(label_mapping)
test_df['Detected as'] = test_df['Detected as'].map(label_mapping)

# -----------------------------
# 6. Preprocessing
# -----------------------------
preprocessor = TextPreprocessor(max_vocab_size=config['max_vocab_size'], 
                                max_seq_length=config['max_seq_length'])
preprocessor.fit(train_df['Sentence'])

X_train = preprocessor.transform(train_df['Sentence'])
X_val = preprocessor.transform(test_df['Sentence'])
y_train = torch.tensor(train_df['Detected as'].values)
y_val = torch.tensor(test_df['Detected as'].values)

train_dataset = TextDataset(X_train, y_train)
val_dataset = TextDataset(X_val, y_val)

train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=config['batch_size'])

x_np = X_train.numpy()
y_np = y_train.numpy()

# ----------------------------
# 7. 10-Fold Cross Validation
# ----------------------------

num_folds = 10
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

fold_results = []

for fold, (train_idx, val_idx) in enumerate(skf.split(x_np, y_np)): 
    print(f"\n------- Fold {fold+1} / {num_folds} --------- ")

    # -----------------------------
    # 1. Split Data
    # -----------------------------
    X_train_fold = torch.tensor(x_np[train_idx])
    y_train_fold = torch.tensor(y_np[train_idx])
    X_val_fold = torch.tensor(x_np[val_idx])
    y_val_fold = torch.tensor(y_np[val_idx])

    train_dataset = TextDataset(X_train_fold, y_train_fold)
    val_dataset = TextDataset(X_val_fold, y_val_fold)

    train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=config['batch_size'])

    # -----------------------------
    # 2. Initialize Model, Optimizer, and Criterion Inside the Loop
    # -----------------------------
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    model = ImprovedTextClassifier(
        vocab_size=len(preprocessor.word2idx),
        embed_dim=config['embed_dim'],
        hidden_dim=config['hidden_dim'],
        num_classes=2,
        num_layers=config['num_lstm_layers']
    ).to(device)

    # Load pretrained embeddings and replace the embedding layer weights
    pretrained_weights = load_pretrained_embeddings(config['pretrained_embedding_path'], 
                                                    preprocessor.word2idx, 
                                                    config['embed_dim'])
    model.embedding = nn.Embedding.from_pretrained(pretrained_weights, freeze=False, padding_idx=0)

    # Compute class weights to handle class imbalance
    small_factor = 1e-4
    class_counts = torch.bincount(y_train_fold) + small_factor  # Avoid division by zero
    class_weights = 1.0 / class_counts.float()
    class_weights = class_weights / class_weights.sum()
    class_weights = class_weights.to(device)

    criterion = nn.CrossEntropyLoss(weight=class_weights)
    optimizer = optim.AdamW(model.parameters(), lr=config['learning_rate'], weight_decay=0.01)
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2, verbose=True)

    # -----------------------------
    # 3. Train the Model
    # -----------------------------
    train_model(model, train_loader, val_loader, criterion, optimizer, scheduler,
                config['num_epochs'], device, preprocessor, config)

    # Load the best model for this fold
    with torch.serialization.safe_globals([TextPreprocessor]):
        checkpoint = torch.load('best_model.pt', weights_only=False)
    
    model.load_state_dict(checkpoint['model_state_dict'])

    # -----------------------------
    # 4. Evaluate the Model
    # -----------------------------
    model.eval()
    val_preds = []
    val_labels = []

    with torch.no_grad():
        for batch_texts, batch_labels in val_loader:
            batch_texts, batch_labels = batch_texts.to(device), batch_labels.to(device)
            outputs = model(batch_texts)
            predictions = torch.argmax(outputs, dim=1)
            val_preds.extend(predictions.cpu().numpy())
            val_labels.extend(batch_labels.cpu().numpy())

    # Compute metrics
    val_precision, val_recall, val_f1, _ = precision_recall_fscore_support(val_labels, val_preds, average='binary')
    val_accuracy = accuracy_score(val_labels, val_preds)

    print(f"Fold {fold+1} Metrics:")
    print(f"Accuracy: {val_accuracy:.4f}, F1-score: {val_f1:.4f}, Precision: {val_precision:.4f}, Recall: {val_recall:.4f}\n")

    fold_results.append((val_accuracy, val_f1, val_precision, val_recall))

# -----------------------------
# 5. Display Overall Results
# -----------------------------
avg_accuracy = sum([x[0] for x in fold_results]) / num_folds
avg_f1 = sum([x[1] for x in fold_results]) / num_folds
avg_precision = sum([x[2] for x in fold_results]) / num_folds
avg_recall = sum([x[3] for x in fold_results]) / num_folds

print("\n========== Final Cross-Validation Results ==========")
print(f"Avg Accuracy: {avg_accuracy:.4f}, Avg F1-score: {avg_f1:.4f}, Avg Precision: {avg_precision:.4f}, Avg Recall: {avg_recall:.4f}")
# Out:
# ------- Fold 1 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/50:
# Train Loss: 0.7097, Accuracy: 0.5920, F1: 0.5641
# Val Loss: 0.6971, Accuracy: 0.4286, F1: 0.3000
# Val Precision: 0.7143, Recall: 0.5000
#
# Epoch 2/50:
# Train Loss: 0.5980, Accuracy: 0.7120, F1: 0.7231
# Val Loss: 0.7037, Accuracy: 0.4286, F1: 0.3000
# Val Precision: 0.7143, Recall: 0.5000
#
# Epoch 3/50:
# Train Loss: 0.4619, Accuracy: 0.7840, F1: 0.7731
# Val Loss: 0.6852, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5222, Recall: 0.5208
#
# Epoch 4/50:
# Train Loss: 0.2972, Accuracy: 0.9200, F1: 0.9194
# Val Loss: 0.6732, Accuracy: 0.7143, F1: 0.6889
# Val Precision: 0.7250, Recall: 0.6875
#
# Epoch 5/50:
# Train Loss: 0.3063, Accuracy: 0.8640, F1: 0.8571
# Val Loss: 0.6857, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5833, Recall: 0.5833
#
# Epoch 6/50:
# Train Loss: 0.2514, Accuracy: 0.9040, F1: 0.8966
# Val Loss: 0.7217, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 7/50:
# Train Loss: 0.1782, Accuracy: 0.9200, F1: 0.9180
# Val Loss: 1.3404, Accuracy: 0.5000, F1: 0.4759
# Val Precision: 0.5606, Recall: 0.5417
#
# Epoch 8/50:
# Train Loss: 0.1211, Accuracy: 0.9680, F1: 0.9667
# Val Loss: 0.9539, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 9/50:
# Train Loss: 0.0826, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 0.9422, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 10/50:
# Train Loss: 0.0702, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.7528, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 11/50:
# Train Loss: 0.0998, Accuracy: 0.9760, F1: 0.9752
# Val Loss: 1.3414, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 12/50:
# Train Loss: 0.0581, Accuracy: 0.9760, F1: 0.9748
# Val Loss: 1.2611, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 13/50:
# Train Loss: 0.0776, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.2576, Accuracy: 0.7143, F1: 0.6889
# Val Precision: 0.7250, Recall: 0.6875
#
# Epoch 14/50:
# Train Loss: 0.0440, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.1763, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 15/50:
# Train Loss: 0.0274, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1332, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 16/50:
# Train Loss: 0.0423, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.1660, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 17/50:
# Train Loss: 0.0377, Accuracy: 0.9840, F1: 0.9836
# Val Loss: 1.1836, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 18/50:
# Train Loss: 0.0492, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.2907, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 19/50:
# Train Loss: 0.0188, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2664, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 20/50:
# Train Loss: 0.0294, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3218, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 21/50:
# Train Loss: 0.0203, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3203, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 22/50:
# Train Loss: 0.0406, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.2955, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 23/50:
# Train Loss: 0.0424, Accuracy: 0.9840, F1: 0.9836
# Val Loss: 1.2450, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 24/50:
# Train Loss: 0.0353, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2743, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 25/50:
# Train Loss: 0.0234, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2810, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 26/50:
# Train Loss: 0.0175, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2549, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 27/50:
# Train Loss: 0.0182, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2355, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 28/50:
# Train Loss: 0.0220, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2411, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 29/50:
# Train Loss: 0.0205, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2295, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 30/50:
# Train Loss: 0.0241, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.2291, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 31/50:
# Train Loss: 0.0209, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2334, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 32/50:
# Train Loss: 0.0434, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.2646, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 33/50:
# Train Loss: 0.0158, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2609, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 34/50:
# Train Loss: 0.0156, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2496, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 35/50:
# Train Loss: 0.0186, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2348, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 36/50:
# Train Loss: 0.0576, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.2472, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 37/50:
# Train Loss: 0.0136, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2276, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 38/50:
# Train Loss: 0.0292, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.2146, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 39/50:
# Train Loss: 0.0620, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.2238, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 40/50:
# Train Loss: 0.0249, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2348, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 41/50:
# Train Loss: 0.0323, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.2664, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 42/50:
# Train Loss: 0.0202, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2607, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 43/50:
# Train Loss: 0.0229, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2439, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 44/50:
# Train Loss: 0.0218, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.2503, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 45/50:
# Train Loss: 0.0283, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.2476, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 46/50:
# Train Loss: 0.0196, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2456, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 47/50:
# Train Loss: 0.0271, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.2495, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 48/50:
# Train Loss: 0.0349, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.2439, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 49/50:
# Train Loss: 0.0242, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2557, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 50/50:
# Train Loss: 0.0376, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.2596, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Fold 1 Metrics:
# Accuracy: 0.7143, F1-score: 0.6667, Precision: 0.6667, Recall: 0.6667
#
#
# ------- Fold 2 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/50:
# Train Loss: 0.7353, Accuracy: 0.4960, F1: 0.3636
# Val Loss: 0.6880, Accuracy: 0.5714, F1: 0.3636
# Val Precision: 0.7857, Recall: 0.5000
#
# Epoch 2/50:
# Train Loss: 0.6142, Accuracy: 0.6960, F1: 0.6984
# Val Loss: 0.6916, Accuracy: 0.5714, F1: 0.3636
# Val Precision: 0.7857, Recall: 0.5000
#
# Epoch 3/50:
# Train Loss: 0.5324, Accuracy: 0.7520, F1: 0.7597
# Val Loss: 0.6974, Accuracy: 0.4286, F1: 0.3000
# Val Precision: 0.7143, Recall: 0.5000
#
# Epoch 4/50:
# Train Loss: 0.4638, Accuracy: 0.7920, F1: 0.8000
# Val Loss: 0.7336, Accuracy: 0.4286, F1: 0.3000
# Val Precision: 0.7143, Recall: 0.5000
#
# Epoch 5/50:
# Train Loss: 0.3196, Accuracy: 0.8880, F1: 0.8852
# Val Loss: 0.6868, Accuracy: 0.6429, F1: 0.6257
# Val Precision: 0.6333, Recall: 0.6250
#
# Epoch 6/50:
# Train Loss: 0.2533, Accuracy: 0.9200, F1: 0.9180
# Val Loss: 0.7410, Accuracy: 0.5000, F1: 0.4269
# Val Precision: 0.7308, Recall: 0.5625
#
# Epoch 7/50:
# Train Loss: 0.2565, Accuracy: 0.9200, F1: 0.9153
# Val Loss: 0.7411, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 8/50:
# Train Loss: 0.1652, Accuracy: 0.9600, F1: 0.9580
# Val Loss: 1.1357, Accuracy: 0.3571, F1: 0.2632
# Val Precision: 0.1923, Recall: 0.4167
#
# Epoch 9/50:
# Train Loss: 0.0816, Accuracy: 0.9840, F1: 0.9836
# Val Loss: 0.9707, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 10/50:
# Train Loss: 0.1043, Accuracy: 0.9680, F1: 0.9667
# Val Loss: 0.8542, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 11/50:
# Train Loss: 0.0867, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 0.9121, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 12/50:
# Train Loss: 0.1531, Accuracy: 0.9520, F1: 0.9483
# Val Loss: 1.1653, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 13/50:
# Train Loss: 0.0758, Accuracy: 0.9760, F1: 0.9748
# Val Loss: 1.2515, Accuracy: 0.5000, F1: 0.4759
# Val Precision: 0.5606, Recall: 0.5417
#
# Epoch 14/50:
# Train Loss: 0.0566, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.1822, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5833, Recall: 0.5833
#
# Epoch 15/50:
# Train Loss: 0.0762, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.1935, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5833, Recall: 0.5833
#
# Epoch 16/50:
# Train Loss: 0.0659, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.1500, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 17/50:
# Train Loss: 0.0616, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.1428, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 18/50:
# Train Loss: 0.0991, Accuracy: 0.9680, F1: 0.9677
# Val Loss: 1.0916, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 19/50:
# Train Loss: 0.0667, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.0810, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 20/50:
# Train Loss: 0.0355, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0904, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 21/50:
# Train Loss: 0.1114, Accuracy: 0.9520, F1: 0.9500
# Val Loss: 1.1140, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 22/50:
# Train Loss: 0.0430, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1077, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 23/50:
# Train Loss: 0.0588, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.0884, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 24/50:
# Train Loss: 0.0806, Accuracy: 0.9760, F1: 0.9748
# Val Loss: 1.1309, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 25/50:
# Train Loss: 0.0508, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.1297, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 26/50:
# Train Loss: 0.0736, Accuracy: 0.9840, F1: 0.9836
# Val Loss: 1.1175, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 27/50:
# Train Loss: 0.0671, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.1246, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 28/50:
# Train Loss: 0.0404, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1127, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 29/50:
# Train Loss: 0.0578, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.1161, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 30/50:
# Train Loss: 0.0996, Accuracy: 0.9600, F1: 0.9593
# Val Loss: 1.1100, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 31/50:
# Train Loss: 0.0295, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1002, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 32/50:
# Train Loss: 0.0683, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.0923, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 33/50:
# Train Loss: 0.0525, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.0927, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 34/50:
# Train Loss: 0.0528, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.0998, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 35/50:
# Train Loss: 0.0551, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.1007, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 36/50:
# Train Loss: 0.0474, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.0998, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 37/50:
# Train Loss: 0.0442, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1017, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 38/50:
# Train Loss: 0.0569, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.0790, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 39/50:
# Train Loss: 0.0411, Accuracy: 0.9840, F1: 0.9836
# Val Loss: 1.0795, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 40/50:
# Train Loss: 0.0353, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0792, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 41/50:
# Train Loss: 0.0593, Accuracy: 0.9760, F1: 0.9748
# Val Loss: 1.0745, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 42/50:
# Train Loss: 0.0535, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.0904, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 43/50:
# Train Loss: 0.0421, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0858, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 44/50:
# Train Loss: 0.0779, Accuracy: 0.9760, F1: 0.9748
# Val Loss: 1.1264, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 45/50:
# Train Loss: 0.0446, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1205, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 46/50:
# Train Loss: 0.0841, Accuracy: 0.9680, F1: 0.9661
# Val Loss: 1.1061, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 47/50:
# Train Loss: 0.0793, Accuracy: 0.9680, F1: 0.9672
# Val Loss: 1.0853, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 48/50:
# Train Loss: 0.0647, Accuracy: 0.9840, F1: 0.9836
# Val Loss: 1.0880, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 49/50:
# Train Loss: 0.0602, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.0881, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 50/50:
# Train Loss: 0.0750, Accuracy: 0.9760, F1: 0.9752
# Val Loss: 1.1036, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Fold 2 Metrics:
# Accuracy: 0.6429, F1-score: 0.6154, Precision: 0.5714, Recall: 0.6667
#
#
# ------- Fold 3 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/50:
# Train Loss: 0.7955, Accuracy: 0.5280, F1: 0.3656
# Val Loss: 0.6910, Accuracy: 0.5714, F1: 0.3636
# Val Precision: 0.7857, Recall: 0.5000
#
# Epoch 2/50:
# Train Loss: 0.6507, Accuracy: 0.7040, F1: 0.6942
# Val Loss: 0.6885, Accuracy: 0.5714, F1: 0.3636
# Val Precision: 0.7857, Recall: 0.5000
#
# Epoch 3/50:
# Train Loss: 0.5384, Accuracy: 0.7200, F1: 0.7154
# Val Loss: 0.6932, Accuracy: 0.3571, F1: 0.2632
# Val Precision: 0.1923, Recall: 0.4167
#
# Epoch 4/50:
# Train Loss: 0.3684, Accuracy: 0.8320, F1: 0.8235
# Val Loss: 0.6701, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 5/50:
# Train Loss: 0.2126, Accuracy: 0.9440, F1: 0.9431
# Val Loss: 0.7701, Accuracy: 0.4286, F1: 0.3000
# Val Precision: 0.7143, Recall: 0.5000
#
# Epoch 6/50:
# Train Loss: 0.2391, Accuracy: 0.8880, F1: 0.8889
# Val Loss: 0.6342, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 7/50:
# Train Loss: 0.2331, Accuracy: 0.8960, F1: 0.8908
# Val Loss: 1.3666, Accuracy: 0.4286, F1: 0.3000
# Val Precision: 0.7143, Recall: 0.5000
#
# Epoch 8/50:
# Train Loss: 0.1805, Accuracy: 0.9200, F1: 0.9167
# Val Loss: 1.2870, Accuracy: 0.5000, F1: 0.4759
# Val Precision: 0.5606, Recall: 0.5417
#
# Epoch 9/50:
# Train Loss: 0.0727, Accuracy: 0.9760, F1: 0.9744
# Val Loss: 1.9895, Accuracy: 0.4286, F1: 0.3778
# Val Precision: 0.4583, Recall: 0.4792
#
# Epoch 10/50:
# Train Loss: 0.0892, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.4520, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 11/50:
# Train Loss: 0.0982, Accuracy: 0.9600, F1: 0.9580
# Val Loss: 1.3371, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 12/50:
# Train Loss: 0.0288, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 2.0702, Accuracy: 0.5000, F1: 0.4759
# Val Precision: 0.5606, Recall: 0.5417
#
# Epoch 13/50:
# Train Loss: 0.0490, Accuracy: 0.9840, F1: 0.9836
# Val Loss: 1.3942, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 14/50:
# Train Loss: 0.0323, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.4350, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 15/50:
# Train Loss: 0.0409, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.5813, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 16/50:
# Train Loss: 0.0192, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5089, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 17/50:
# Train Loss: 0.1123, Accuracy: 0.9520, F1: 0.9483
# Val Loss: 1.2875, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 18/50:
# Train Loss: 0.0290, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.3294, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 19/50:
# Train Loss: 0.0393, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.4010, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 20/50:
# Train Loss: 0.0194, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3644, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 21/50:
# Train Loss: 0.0118, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4192, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 22/50:
# Train Loss: 0.0246, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4322, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 23/50:
# Train Loss: 0.0090, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4358, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 24/50:
# Train Loss: 0.0132, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4081, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 25/50:
# Train Loss: 0.0179, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4098, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 26/50:
# Train Loss: 0.0140, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4036, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 27/50:
# Train Loss: 0.0523, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.4445, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 28/50:
# Train Loss: 0.0184, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.4076, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 29/50:
# Train Loss: 0.0117, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4618, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 30/50:
# Train Loss: 0.0129, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4454, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 31/50:
# Train Loss: 0.0097, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4823, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 32/50:
# Train Loss: 0.0256, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.4454, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 33/50:
# Train Loss: 0.0193, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.3937, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 34/50:
# Train Loss: 0.0348, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.4177, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 35/50:
# Train Loss: 0.0109, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4183, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 36/50:
# Train Loss: 0.0160, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3824, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 37/50:
# Train Loss: 0.0652, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.5558, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 38/50:
# Train Loss: 0.0209, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5841, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 39/50:
# Train Loss: 0.0158, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4942, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 40/50:
# Train Loss: 0.0197, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4977, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 41/50:
# Train Loss: 0.0185, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.5196, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 42/50:
# Train Loss: 0.0094, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4518, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 43/50:
# Train Loss: 0.0132, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3947, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 44/50:
# Train Loss: 0.0086, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4068, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 45/50:
# Train Loss: 0.0128, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4256, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 46/50:
# Train Loss: 0.0144, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4093, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 47/50:
# Train Loss: 0.0326, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.4878, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 48/50:
# Train Loss: 0.0163, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5213, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 49/50:
# Train Loss: 0.0210, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4933, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 50/50:
# Train Loss: 0.0340, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.5066, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Fold 3 Metrics:
# Accuracy: 0.7143, F1-score: 0.6667, Precision: 0.6667, Recall: 0.6667
#
#
# ------- Fold 4 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/50:
# Train Loss: 0.7332, Accuracy: 0.5280, F1: 0.6242
# Val Loss: 0.6922, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 2/50:
# Train Loss: 0.6387, Accuracy: 0.6560, F1: 0.6767
# Val Loss: 0.6837, Accuracy: 0.5000, F1: 0.4759
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 3/50:
# Train Loss: 0.5944, Accuracy: 0.7120, F1: 0.6727
# Val Loss: 0.6985, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 4/50:
# Train Loss: 0.4460, Accuracy: 0.7600, F1: 0.7500
# Val Loss: 0.6932, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 5/50:
# Train Loss: 0.3454, Accuracy: 0.8480, F1: 0.8376
# Val Loss: 0.6775, Accuracy: 0.5714, F1: 0.5333
# Val Precision: 0.6061, Recall: 0.5714
#
# Epoch 6/50:
# Train Loss: 0.1835, Accuracy: 0.9200, F1: 0.9138
# Val Loss: 0.6253, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 7/50:
# Train Loss: 0.2165, Accuracy: 0.8960, F1: 0.8976
# Val Loss: 0.6183, Accuracy: 0.6429, F1: 0.6257
# Val Precision: 0.6750, Recall: 0.6429
#
# Epoch 8/50:
# Train Loss: 0.1115, Accuracy: 0.9600, F1: 0.9573
# Val Loss: 0.7442, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 9/50:
# Train Loss: 0.1548, Accuracy: 0.9440, F1: 0.9421
# Val Loss: 1.0187, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7333, Recall: 0.7143
#
# Epoch 10/50:
# Train Loss: 0.1356, Accuracy: 0.9360, F1: 0.9310
# Val Loss: 1.1130, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7333, Recall: 0.7143
#
# Epoch 11/50:
# Train Loss: 0.0928, Accuracy: 0.9680, F1: 0.9667
# Val Loss: 1.5604, Accuracy: 0.6429, F1: 0.6257
# Val Precision: 0.6750, Recall: 0.6429
#
# Epoch 12/50:
# Train Loss: 0.0622, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.7338, Accuracy: 0.4286, F1: 0.3000
# Val Precision: 0.2308, Recall: 0.4286
#
# Epoch 13/50:
# Train Loss: 0.1532, Accuracy: 0.9600, F1: 0.9573
# Val Loss: 1.2876, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 14/50:
# Train Loss: 0.0721, Accuracy: 0.9680, F1: 0.9661
# Val Loss: 1.3820, Accuracy: 0.6429, F1: 0.6257
# Val Precision: 0.6750, Recall: 0.6429
#
# Epoch 15/50:
# Train Loss: 0.1021, Accuracy: 0.9600, F1: 0.9593
# Val Loss: 1.2117, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 16/50:
# Train Loss: 0.0359, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.3067, Accuracy: 0.6429, F1: 0.6257
# Val Precision: 0.6750, Recall: 0.6429
#
# Epoch 17/50:
# Train Loss: 0.1493, Accuracy: 0.9680, F1: 0.9655
# Val Loss: 1.2429, Accuracy: 0.6429, F1: 0.6257
# Val Precision: 0.6750, Recall: 0.6429
#
# Epoch 18/50:
# Train Loss: 0.0215, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1233, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 19/50:
# Train Loss: 0.0433, Accuracy: 0.9840, F1: 0.9828
# Val Loss: 1.2354, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 20/50:
# Train Loss: 0.0589, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.2218, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 21/50:
# Train Loss: 0.0323, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.2177, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 22/50:
# Train Loss: 0.0122, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2131, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 23/50:
# Train Loss: 0.0530, Accuracy: 0.9680, F1: 0.9667
# Val Loss: 1.2275, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 24/50:
# Train Loss: 0.0378, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.2196, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 25/50:
# Train Loss: 0.0471, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.1974, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 26/50:
# Train Loss: 0.0101, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1813, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 27/50:
# Train Loss: 0.0313, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.1873, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 28/50:
# Train Loss: 0.0196, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1805, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 29/50:
# Train Loss: 0.0258, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1970, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 30/50:
# Train Loss: 0.0196, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.1822, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 31/50:
# Train Loss: 0.0137, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1721, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 32/50:
# Train Loss: 0.0154, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1671, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 33/50:
# Train Loss: 0.0162, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1653, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 34/50:
# Train Loss: 0.0130, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1723, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 35/50:
# Train Loss: 0.0248, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1776, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 36/50:
# Train Loss: 0.0150, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1731, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 37/50:
# Train Loss: 0.0296, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.1840, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 38/50:
# Train Loss: 0.0177, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1883, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 39/50:
# Train Loss: 0.0452, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.1897, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 40/50:
# Train Loss: 0.0210, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.1882, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 41/50:
# Train Loss: 0.0340, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.2114, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 42/50:
# Train Loss: 0.0280, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.1890, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 43/50:
# Train Loss: 0.0326, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.1809, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 44/50:
# Train Loss: 0.0483, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.1852, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 45/50:
# Train Loss: 0.0158, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1764, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 46/50:
# Train Loss: 0.0138, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1667, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 47/50:
# Train Loss: 0.0108, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1699, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 48/50:
# Train Loss: 0.0365, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.1790, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 49/50:
# Train Loss: 0.0131, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1666, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 50/50:
# Train Loss: 0.0145, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1734, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Fold 4 Metrics:
# Accuracy: 0.7143, F1-score: 0.6667, Precision: 0.8000, Recall: 0.5714
#
#
# ------- Fold 5 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/50:
# Train Loss: 0.7347, Accuracy: 0.5040, F1: 0.3673
# Val Loss: 0.6935, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 2/50:
# Train Loss: 0.5864, Accuracy: 0.7040, F1: 0.6992
# Val Loss: 0.6947, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 3/50:
# Train Loss: 0.5046, Accuracy: 0.8160, F1: 0.8217
# Val Loss: 0.6855, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 4/50:
# Train Loss: 0.3146, Accuracy: 0.8880, F1: 0.8833
# Val Loss: 0.6973, Accuracy: 0.5714, F1: 0.5333
# Val Precision: 0.6061, Recall: 0.5714
#
# Epoch 5/50:
# Train Loss: 0.2895, Accuracy: 0.8960, F1: 0.8889
# Val Loss: 0.7238, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 6/50:
# Train Loss: 0.1926, Accuracy: 0.9440, F1: 0.9402
# Val Loss: 0.8249, Accuracy: 0.5714, F1: 0.5333
# Val Precision: 0.6061, Recall: 0.5714
#
# Epoch 7/50:
# Train Loss: 0.1419, Accuracy: 0.9600, F1: 0.9580
# Val Loss: 0.9629, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 8/50:
# Train Loss: 0.1138, Accuracy: 0.9600, F1: 0.9587
# Val Loss: 1.0930, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 9/50:
# Train Loss: 0.0640, Accuracy: 0.9760, F1: 0.9752
# Val Loss: 0.9644, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 10/50:
# Train Loss: 0.0897, Accuracy: 0.9760, F1: 0.9744
# Val Loss: 1.1759, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 11/50:
# Train Loss: 0.0819, Accuracy: 0.9760, F1: 0.9744
# Val Loss: 1.3763, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 12/50:
# Train Loss: 0.0602, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.0769, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 13/50:
# Train Loss: 0.0569, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.2016, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 14/50:
# Train Loss: 0.0307, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2214, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 15/50:
# Train Loss: 0.0722, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.3111, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 16/50:
# Train Loss: 0.0326, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3487, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 17/50:
# Train Loss: 0.0553, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.2996, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 18/50:
# Train Loss: 0.0763, Accuracy: 0.9840, F1: 0.9828
# Val Loss: 1.4155, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 19/50:
# Train Loss: 0.0359, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3121, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 20/50:
# Train Loss: 0.0300, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2824, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 21/50:
# Train Loss: 0.0746, Accuracy: 0.9680, F1: 0.9661
# Val Loss: 1.2451, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 22/50:
# Train Loss: 0.0391, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.2413, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 23/50:
# Train Loss: 0.0813, Accuracy: 0.9760, F1: 0.9744
# Val Loss: 1.2675, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 24/50:
# Train Loss: 0.0350, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.2621, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 25/50:
# Train Loss: 0.0283, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.2611, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 26/50:
# Train Loss: 0.0504, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.2737, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 27/50:
# Train Loss: 0.0336, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.2844, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 28/50:
# Train Loss: 0.0472, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.2917, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 29/50:
# Train Loss: 0.0455, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.2881, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 30/50:
# Train Loss: 0.0280, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2977, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 31/50:
# Train Loss: 0.0168, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2901, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 32/50:
# Train Loss: 0.0319, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.2905, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 33/50:
# Train Loss: 0.0546, Accuracy: 0.9840, F1: 0.9828
# Val Loss: 1.3035, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 34/50:
# Train Loss: 0.0189, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2823, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 35/50:
# Train Loss: 0.0237, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2818, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 36/50:
# Train Loss: 0.0449, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.2828, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 37/50:
# Train Loss: 0.0208, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2741, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 38/50:
# Train Loss: 0.0212, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2822, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 39/50:
# Train Loss: 0.0409, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.2934, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 40/50:
# Train Loss: 0.0239, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2804, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 41/50:
# Train Loss: 0.0459, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.2783, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 42/50:
# Train Loss: 0.0281, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.2808, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 43/50:
# Train Loss: 0.0385, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2877, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 44/50:
# Train Loss: 0.0170, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2834, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 45/50:
# Train Loss: 0.0301, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2759, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 46/50:
# Train Loss: 0.0332, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2845, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 47/50:
# Train Loss: 0.0296, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2734, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 48/50:
# Train Loss: 0.0335, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2868, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 49/50:
# Train Loss: 0.0261, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2646, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 50/50:
# Train Loss: 0.0296, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.2718, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Fold 5 Metrics:
# Accuracy: 0.6429, F1-score: 0.6667, Precision: 0.6250, Recall: 0.7143
#
#
# ------- Fold 6 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/50:
# Train Loss: 0.7364, Accuracy: 0.4880, F1: 0.5362
# Val Loss: 0.6892, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 2/50:
# Train Loss: 0.6105, Accuracy: 0.6640, F1: 0.6719
# Val Loss: 0.6845, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 3/50:
# Train Loss: 0.5819, Accuracy: 0.7040, F1: 0.7087
# Val Loss: 0.6843, Accuracy: 0.5714, F1: 0.4750
# Val Precision: 0.7692, Recall: 0.5714
#
# Epoch 4/50:
# Train Loss: 0.3984, Accuracy: 0.8000, F1: 0.7934
# Val Loss: 0.7077, Accuracy: 0.4286, F1: 0.3778
# Val Precision: 0.3939, Recall: 0.4286
#
# Epoch 5/50:
# Train Loss: 0.2969, Accuracy: 0.8560, F1: 0.8475
# Val Loss: 0.7312, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 6/50:
# Train Loss: 0.2283, Accuracy: 0.9440, F1: 0.9431
# Val Loss: 0.7271, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 7/50:
# Train Loss: 0.2402, Accuracy: 0.9200, F1: 0.9194
# Val Loss: 0.6812, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7333, Recall: 0.7143
#
# Epoch 8/50:
# Train Loss: 0.1046, Accuracy: 0.9600, F1: 0.9580
# Val Loss: 0.9400, Accuracy: 0.5714, F1: 0.5333
# Val Precision: 0.6061, Recall: 0.5714
#
# Epoch 9/50:
# Train Loss: 0.1127, Accuracy: 0.9520, F1: 0.9500
# Val Loss: 1.6438, Accuracy: 0.5000, F1: 0.4759
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 10/50:
# Train Loss: 0.0642, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.2881, Accuracy: 0.6429, F1: 0.5906
# Val Precision: 0.7917, Recall: 0.6429
#
# Epoch 11/50:
# Train Loss: 0.1409, Accuracy: 0.9440, F1: 0.9412
# Val Loss: 1.1582, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 12/50:
# Train Loss: 0.0511, Accuracy: 0.9760, F1: 0.9744
# Val Loss: 1.6782, Accuracy: 0.6429, F1: 0.6257
# Val Precision: 0.6750, Recall: 0.6429
#
# Epoch 13/50:
# Train Loss: 0.0545, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.1045, Accuracy: 0.6429, F1: 0.6257
# Val Precision: 0.6750, Recall: 0.6429
#
# Epoch 14/50:
# Train Loss: 0.0503, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 0.9599, Accuracy: 0.6429, F1: 0.6257
# Val Precision: 0.6750, Recall: 0.6429
#
# Epoch 15/50:
# Train Loss: 0.0392, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.0035, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 16/50:
# Train Loss: 0.0550, Accuracy: 0.9760, F1: 0.9744
# Val Loss: 1.3169, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 17/50:
# Train Loss: 0.0348, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.4565, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 18/50:
# Train Loss: 0.0205, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7390, Accuracy: 0.5000, F1: 0.4759
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 19/50:
# Train Loss: 0.0305, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.5471, Accuracy: 0.5000, F1: 0.4759
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 20/50:
# Train Loss: 0.0346, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.4398, Accuracy: 0.5000, F1: 0.4759
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 21/50:
# Train Loss: 0.0230, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3408, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 22/50:
# Train Loss: 0.0220, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.2671, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 23/50:
# Train Loss: 0.0319, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.3756, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 24/50:
# Train Loss: 0.0237, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3932, Accuracy: 0.5000, F1: 0.4759
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 25/50:
# Train Loss: 0.0217, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.3757, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 26/50:
# Train Loss: 0.0170, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3509, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 27/50:
# Train Loss: 0.0236, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3536, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 28/50:
# Train Loss: 0.0263, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.3405, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 29/50:
# Train Loss: 0.0320, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.3475, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 30/50:
# Train Loss: 0.0430, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.3945, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 31/50:
# Train Loss: 0.0216, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3971, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 32/50:
# Train Loss: 0.0381, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.3977, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 33/50:
# Train Loss: 0.0416, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.4011, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 34/50:
# Train Loss: 0.0377, Accuracy: 0.9840, F1: 0.9828
# Val Loss: 1.3891, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 35/50:
# Train Loss: 0.0223, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3909, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 36/50:
# Train Loss: 0.0176, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3759, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 37/50:
# Train Loss: 0.0449, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.3738, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 38/50:
# Train Loss: 0.0634, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.3722, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 39/50:
# Train Loss: 0.0224, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3875, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 40/50:
# Train Loss: 0.0190, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4022, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 41/50:
# Train Loss: 0.0331, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.3825, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 42/50:
# Train Loss: 0.0230, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.3953, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 43/50:
# Train Loss: 0.0405, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.4138, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 44/50:
# Train Loss: 0.0179, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3766, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 45/50:
# Train Loss: 0.0114, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3832, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 46/50:
# Train Loss: 0.0162, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3659, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 47/50:
# Train Loss: 0.0340, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.3867, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 48/50:
# Train Loss: 0.0209, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4088, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 49/50:
# Train Loss: 0.0637, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.4019, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 50/50:
# Train Loss: 0.0456, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.3976, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Fold 6 Metrics:
# Accuracy: 0.7143, F1-score: 0.6667, Precision: 0.8000, Recall: 0.5714
#
#
# ------- Fold 7 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/50:
# Train Loss: 0.6988, Accuracy: 0.5920, F1: 0.5321
# Val Loss: 0.6998, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 2/50:
# Train Loss: 0.7062, Accuracy: 0.6640, F1: 0.6500
# Val Loss: 0.6988, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# ...
#
# Fold 8 Metrics:
# Accuracy: 0.7857, F1-score: 0.7692, Precision: 0.8333, Recall: 0.7143
#
#
# ------- Fold 9 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/50:
# Train Loss: 0.7634, Accuracy: 0.5120, F1: 0.4874
# Val Loss: 0.6909, Accuracy: 0.7857, F1: 0.7846
# Val Precision: 0.7917, Recall: 0.7857
#
# Epoch 2/50:
# Train Loss: 0.6153, Accuracy: 0.6320, F1: 0.6761
# Val Loss: 0.6897, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 3/50:
# Train Loss: 0.5332, Accuracy: 0.7840, F1: 0.7652
# Val Loss: 0.6875, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 4/50:
# Train Loss: 0.3449, Accuracy: 0.8480, F1: 0.8403
# Val Loss: 0.7344, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 5/50:
# Train Loss: 0.3516, Accuracy: 0.8640, F1: 0.8595
# Val Loss: 0.6995, Accuracy: 0.6429, F1: 0.6257
# Val Precision: 0.6750, Recall: 0.6429
#
# Epoch 6/50:
# Train Loss: 0.2477, Accuracy: 0.9040, F1: 0.9048
# Val Loss: 0.8387, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 7/50:
# Train Loss: 0.1408, Accuracy: 0.9600, F1: 0.9580
# Val Loss: 0.7900, Accuracy: 0.7857, F1: 0.7754
# Val Precision: 0.8500, Recall: 0.7857
#
# Epoch 8/50:
# Train Loss: 0.1192, Accuracy: 0.9680, F1: 0.9655
# Val Loss: 1.0219, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 9/50:
# Train Loss: 0.1002, Accuracy: 0.9680, F1: 0.9649
# Val Loss: 1.4435, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 10/50:
# Train Loss: 0.0489, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5128, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 11/50:
# Train Loss: 0.0668, Accuracy: 0.9760, F1: 0.9748
# Val Loss: 1.4554, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 12/50:
# Train Loss: 0.0563, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.5348, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 13/50:
# Train Loss: 0.0397, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6280, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 14/50:
# Train Loss: 0.0668, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.6765, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 15/50:
# Train Loss: 0.0410, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.6807, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 16/50:
# Train Loss: 0.0387, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.6918, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 17/50:
# Train Loss: 0.0359, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7647, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 18/50:
# Train Loss: 0.0505, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7508, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 19/50:
# Train Loss: 0.0292, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7301, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 20/50:
# Train Loss: 0.0392, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.7628, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 21/50:
# Train Loss: 0.0256, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7370, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 22/50:
# Train Loss: 0.0394, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.7442, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 23/50:
# Train Loss: 0.0256, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.7368, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 24/50:
# Train Loss: 0.0331, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7401, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 25/50:
# Train Loss: 0.0198, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7645, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 26/50:
# Train Loss: 0.0326, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7978, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 27/50:
# Train Loss: 0.0391, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.8115, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 28/50:
# Train Loss: 0.0298, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7831, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 29/50:
# Train Loss: 0.0342, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.8082, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 30/50:
# Train Loss: 0.0220, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7688, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 31/50:
# Train Loss: 0.0451, Accuracy: 0.9840, F1: 0.9828
# Val Loss: 1.8014, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 32/50:
# Train Loss: 0.0413, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.7705, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 33/50:
# Train Loss: 0.0426, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.7545, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 34/50:
# Train Loss: 0.0331, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7314, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 35/50:
# Train Loss: 0.0195, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7645, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 36/50:
# Train Loss: 0.0562, Accuracy: 0.9840, F1: 0.9828
# Val Loss: 1.7735, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 37/50:
# Train Loss: 0.0181, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7735, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 38/50:
# Train Loss: 0.0199, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7525, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 39/50:
# Train Loss: 0.0246, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7694, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 40/50:
# Train Loss: 0.0343, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7545, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 41/50:
# Train Loss: 0.0763, Accuracy: 0.9680, F1: 0.9667
# Val Loss: 1.7923, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 42/50:
# Train Loss: 0.0204, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7745, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 43/50:
# Train Loss: 0.0258, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7820, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 44/50:
# Train Loss: 0.0201, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7731, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 45/50:
# Train Loss: 0.0534, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.7969, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 46/50:
# Train Loss: 0.0330, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.7746, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 47/50:
# Train Loss: 0.0183, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7508, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 48/50:
# Train Loss: 0.0356, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.7674, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 49/50:
# Train Loss: 0.0226, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7697, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 50/50:
# Train Loss: 0.0196, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7919, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Fold 9 Metrics:
# Accuracy: 0.7857, F1-score: 0.7692, Precision: 0.8333, Recall: 0.7143
#
#
# ------- Fold 10 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/50:
# Train Loss: 0.7420, Accuracy: 0.5794, F1: 0.5546
# Val Loss: 0.6904, Accuracy: 0.5385, F1: 0.3500
# Val Precision: 0.7692, Recall: 0.5000
#
# Epoch 2/50:
# Train Loss: 0.6524, Accuracy: 0.6905, F1: 0.7023
# Val Loss: 0.6928, Accuracy: 0.5385, F1: 0.3500
# Val Precision: 0.7692, Recall: 0.5000
#
# Epoch 3/50:
# Train Loss: 0.5124, Accuracy: 0.7540, F1: 0.7559
# Val Loss: 0.6881, Accuracy: 0.5385, F1: 0.3500
# Val Precision: 0.7692, Recall: 0.5000
#
# Epoch 4/50:
# Train Loss: 0.4177, Accuracy: 0.8571, F1: 0.8525
# Val Loss: 0.6781, Accuracy: 0.5385, F1: 0.3500
# Val Precision: 0.7692, Recall: 0.5000
#
# Epoch 5/50:
# Train Loss: 0.2942, Accuracy: 0.8810, F1: 0.8819
# Val Loss: 0.6590, Accuracy: 0.5385, F1: 0.4583
# Val Precision: 0.5227, Recall: 0.5119
#
# Epoch 6/50:
# Train Loss: 0.1809, Accuracy: 0.9444, F1: 0.9431
# Val Loss: 0.7427, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 7/50:
# Train Loss: 0.2397, Accuracy: 0.9127, F1: 0.9060
# Val Loss: 1.8224, Accuracy: 0.5385, F1: 0.4583
# Val Precision: 0.7500, Recall: 0.5714
#
# Epoch 8/50:
# Train Loss: 0.1351, Accuracy: 0.9603, F1: 0.9600
# Val Loss: 1.0994, Accuracy: 0.5385, F1: 0.5357
# Val Precision: 0.5500, Recall: 0.5476
#
# Epoch 9/50:
# Train Loss: 0.0711, Accuracy: 0.9683, F1: 0.9667
# Val Loss: 1.2236, Accuracy: 0.4615, F1: 0.4615
# Val Precision: 0.4643, Recall: 0.4643
#
# Epoch 10/50:
# Train Loss: 0.0527, Accuracy: 0.9921, F1: 0.9917
# Val Loss: 1.3538, Accuracy: 0.4615, F1: 0.4615
# Val Precision: 0.4643, Recall: 0.4643
#
# Epoch 11/50:
# Train Loss: 0.0701, Accuracy: 0.9603, F1: 0.9580
# Val Loss: 1.3381, Accuracy: 0.4615, F1: 0.4615
# Val Precision: 0.4643, Recall: 0.4643
#
# Epoch 12/50:
# Train Loss: 0.0347, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5315, Accuracy: 0.4615, F1: 0.4615
# Val Precision: 0.4643, Recall: 0.4643
#
# Epoch 13/50:
# Train Loss: 0.0188, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7469, Accuracy: 0.3846, F1: 0.3810
# Val Precision: 0.3810, Recall: 0.3810
#
# Epoch 14/50:
# Train Loss: 0.0522, Accuracy: 0.9841, F1: 0.9836
# Val Loss: 1.9149, Accuracy: 0.3846, F1: 0.3810
# Val Precision: 0.3810, Recall: 0.3810
#
# Epoch 15/50:
# Train Loss: 0.0273, Accuracy: 0.9921, F1: 0.9916
# Val Loss: 1.8982, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 16/50:
# Train Loss: 0.0644, Accuracy: 0.9841, F1: 0.9831
# Val Loss: 1.8192, Accuracy: 0.3846, F1: 0.3810
# Val Precision: 0.3810, Recall: 0.3810
#
# Epoch 17/50:
# Train Loss: 0.0172, Accuracy: 0.9921, F1: 0.9917
# Val Loss: 1.8661, Accuracy: 0.3846, F1: 0.3810
# Val Precision: 0.3810, Recall: 0.3810
#
# Epoch 18/50:
# Train Loss: 0.0164, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.8838, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 19/50:
# Train Loss: 0.0230, Accuracy: 0.9921, F1: 0.9917
# Val Loss: 1.8845, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 20/50:
# Train Loss: 0.0489, Accuracy: 0.9762, F1: 0.9752
# Val Loss: 1.9071, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 21/50:
# Train Loss: 0.0226, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.9065, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 22/50:
# Train Loss: 0.0119, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.8891, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 23/50:
# Train Loss: 0.0371, Accuracy: 0.9841, F1: 0.9833
# Val Loss: 1.9365, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 24/50:
# Train Loss: 0.0135, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.9415, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 25/50:
# Train Loss: 0.0162, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.9381, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 26/50:
# Train Loss: 0.0196, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.9098, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 27/50:
# Train Loss: 0.0151, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.9394, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 28/50:
# Train Loss: 0.0119, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.9533, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 29/50:
# Train Loss: 0.0247, Accuracy: 0.9841, F1: 0.9833
# Val Loss: 1.9672, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 30/50:
# Train Loss: 0.0203, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.9600, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 31/50:
# Train Loss: 0.0179, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.9517, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 32/50:
# Train Loss: 0.0283, Accuracy: 0.9921, F1: 0.9916
# Val Loss: 1.9420, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 33/50:
# Train Loss: 0.0266, Accuracy: 0.9921, F1: 0.9916
# Val Loss: 1.9424, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 34/50:
# Train Loss: 0.0706, Accuracy: 0.9762, F1: 0.9756
# Val Loss: 1.9536, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 35/50:
# Train Loss: 0.0209, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.9723, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 36/50:
# Train Loss: 0.0363, Accuracy: 0.9841, F1: 0.9831
# Val Loss: 1.9794, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 37/50:
# Train Loss: 0.0469, Accuracy: 0.9921, F1: 0.9917
# Val Loss: 1.9782, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 38/50:
# Train Loss: 0.0142, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.9824, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 39/50:
# Train Loss: 0.1379, Accuracy: 0.9524, F1: 0.9483
# Val Loss: 1.9519, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 40/50:
# Train Loss: 0.0302, Accuracy: 0.9921, F1: 0.9916
# Val Loss: 1.9449, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 41/50:
# Train Loss: 0.0299, Accuracy: 0.9921, F1: 0.9916
# Val Loss: 1.9621, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 42/50:
# Train Loss: 0.0131, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.9672, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 43/50:
# Train Loss: 0.0196, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.9900, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 44/50:
# Train Loss: 0.0180, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.9576, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 45/50:
# Train Loss: 0.0664, Accuracy: 0.9762, F1: 0.9756
# Val Loss: 1.9726, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 46/50:
# Train Loss: 0.0710, Accuracy: 0.9762, F1: 0.9756
# Val Loss: 1.9640, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 47/50:
# Train Loss: 0.0412, Accuracy: 0.9921, F1: 0.9916
# Val Loss: 1.9535, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 48/50:
# Train Loss: 0.0344, Accuracy: 0.9841, F1: 0.9836
# Val Loss: 1.9668, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 49/50:
# Train Loss: 0.0218, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.9657, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Epoch 50/50:
# Train Loss: 0.0344, Accuracy: 0.9921, F1: 0.9916
# Val Loss: 1.9612, Accuracy: 0.4615, F1: 0.4485
# Val Precision: 0.4500, Recall: 0.4524
#
# Fold 10 Metrics:
# Accuracy: 0.5385, F1-score: 0.5714, Precision: 0.5000, Recall: 0.6667
#
#
# ========== Final Cross-Validation Results ==========
# Avg Accuracy: 0.6824, Avg F1-score: 0.6630, Avg Precision: 0.6868, Avg Recall: 0.6524
