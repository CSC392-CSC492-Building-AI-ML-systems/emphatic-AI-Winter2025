# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset
from collections import Counter
import numpy as np
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import pandas as pd
import re
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.model_selection import StratifiedKFold

# -----------------------------
# 1. Text Preprocessing Classes
# -----------------------------
class TextPreprocessor:
    def __init__(self, max_vocab_size=15000, max_seq_length=128):
        self.max_vocab_size = max_vocab_size
        self.max_seq_length = max_seq_length
        self.word2idx = {'<PAD>': 0, '<UNK>': 1}
        self.idx2word = {0: '<PAD>', 1: '<UNK>'}
        self.word_counts = Counter()
        
    def clean_text(self, text):
        text = str(text).lower()
        text = re.sub(r'[^a-zA-Z0-9\s.,!?]', '', text)
        text = ' '.join(text.split())
        return text
        
    def fit(self, texts):
        for text in texts:
            cleaned_text = self.clean_text(text)
            words = cleaned_text.split()
            self.word_counts.update(words)
        
        # Reserve two indices for PAD and UNK tokens
        vocab_words = [word for word, count in self.word_counts.most_common(self.max_vocab_size - 2)]
        for word in vocab_words:
            idx = len(self.word2idx)
            self.word2idx[word] = idx
            self.idx2word[idx] = word
    
    def transform(self, texts):
        sequences = []
        for text in texts:
            cleaned_text = self.clean_text(text)
            words = cleaned_text.split()
            # Truncate or pad sequences
            seq = [self.word2idx.get(word, self.word2idx['<UNK>']) for word in words[:self.max_seq_length]]
            padded_sequences = np.zeros((len(sequences), self.max_seq_length), dtype=np.int64)
            for i, seq in enumerate(sequences):
                padded_sequences[i, :len(seq)] = seq
        return torch.tensor(sequences)

class TextDataset(Dataset):
    def __init__(self, texts, labels):
        self.texts = texts
        self.labels = self.labels = torch.tensor(labels, dtype=torch.long) # crossEntropyLoss

        
    def __len__(self):
        return len(self.texts)
    
    def __getitem__(self, idx):
        return self.texts[idx], self.labels[idx]

# -----------------------------
# 2. Define the Model
# -----------------------------
class ImprovedTextClassifier(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_classes, num_layers=2):
        super(ImprovedTextClassifier, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        self.embedding_dropout = nn.Dropout(0.2 if num_layers > 1 else 0.1)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, num_layers=num_layers, 
                            batch_first=True, bidirectional=True,
                            dropout=0.2 if num_layers > 1 else 0)
        self.attention = nn.Linear(hidden_dim * 2, 1)
        self.fc1 = nn.Linear(hidden_dim * 2, hidden_dim)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.dropout1 = nn.Dropout(0.3)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim // 2)
        self.bn2 = nn.BatchNorm1d(hidden_dim // 2)
        self.dropout2 = nn.Dropout(0.2)
        self.fc3 = nn.Linear(hidden_dim // 2, num_classes)
        
    def attention_net(self, lstm_output):
        # Compute attention weights and context vector
        energy = torch.tanh(self.attention(lstm_output))
        attention_weights = torch.softmax(self.attention(lstm_output), dim=1)
        context_vector = torch.sum(attention_weights * lstm_output, dim=1)
        return context_vector
        
    def forward(self, x):
        embedded = self.embedding(x)
        embedded = self.embedding_dropout(embedded)
        lstm_out, _ = self.lstm(embedded)
        attn_out = self.attention_net(lstm_out)
        x = self.fc1(attn_out)
        x = self.bn1(x)
        x = torch.relu(x)
        x = self.dropout1(x)
        x = self.fc2(x)
        x = self.bn2(x)
        x = torch.relu(x)
        x = self.dropout2(x)
        x = self.fc3(x)
        return x

# -----------------------------
# 3. Function to Load Pretrained Embeddings (GloVe)
# -----------------------------
def load_pretrained_embeddings(embedding_path, word2idx, embed_dim):
    print("Loading pretrained embeddings...")
    # Initialize embeddings with a uniform distribution
    embeddings = np.random.uniform(-0.05, 0.05, (len(word2idx), embed_dim))
    embeddings[word2idx['<PAD>']] = np.zeros(embed_dim)
    found = 0
    with open(embedding_path, 'r', encoding='utf-8') as f:
        for line in f:
            values = line.rstrip().split(' ')
            word = values[0]
            vector = np.asarray(values[1:], dtype='float32')
            if vector.shape[0] != embed_dim:
                continue  # Skip if dimensions mismatch
            if word in word2idx:
                embeddings[word2idx[word]] = vector
                found += 1
    print(f"Found {found} pretrained embeddings out of {len(word2idx)} words")
    return torch.tensor(embeddings, dtype=torch.float)

# -----------------------------
# 4. Training Function
# -----------------------------
def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs, device, preprocessor, config):
    best_f1 = 0
    patience = 5
    patience_counter = 0
    
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        train_preds = []
        train_labels = []
        
        for batch_texts, batch_labels in train_loader:
            batch_texts, batch_labels = batch_texts.to(device), batch_labels.to(device)
            optimizer.zero_grad()
            outputs = model(batch_texts)
            loss = criterion(outputs, batch_labels)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            train_loss += loss.item()
            predictions = torch.argmax(outputs, dim=1)
            train_preds.extend(predictions.cpu().numpy())
            train_labels.extend(batch_labels.cpu().numpy())
        
        model.eval()
        val_loss = 0
        val_preds = []
        val_labels = []
        
        with torch.no_grad():
            for batch_texts, batch_labels in val_loader:
                batch_texts, batch_labels = batch_texts.to(device), batch_labels.to(device)
                outputs = model(batch_texts)
                loss = criterion(outputs, batch_labels)
                val_loss += loss.item()
                predictions = torch.argmax(outputs, dim=1)
                val_preds.extend(predictions.cpu().numpy())
                val_labels.extend(batch_labels.cpu().numpy())
        
        train_precision, train_recall, train_f1, _ = precision_recall_fscore_support(train_labels, train_preds, average='binary')
        train_accuracy = accuracy_score(train_labels, train_preds)
        
        val_precision, val_recall, val_f1, _ = precision_recall_fscore_support(val_labels, val_preds, average='macro', zero_division=1)
        val_accuracy = accuracy_score(val_labels, val_preds)
        
        scheduler.step(val_loss)
        
        print(f'Epoch {epoch+1}/{num_epochs}:')
        print(f'Train Loss: {train_loss/len(train_loader):.4f}, Accuracy: {train_accuracy:.4f}, F1: {train_f1:.4f}')
        print(f'Val Loss: {val_loss/len(val_loader):.4f}, Accuracy: {val_accuracy:.4f}, F1: {val_f1:.4f}')
        print(f'Val Precision: {val_precision:.4f}, Recall: {val_recall:.4f}\n')
        
        if val_f1 > best_f1:
            best_f1 = val_f1
            torch.save({
                'model_state_dict': model.state_dict(),
                'preprocessor': preprocessor,
                'config': config
            }, 'best_model.pt')
            patience_counter = 0
        else:
            patience_counter += 1
            
        if patience_counter >= patience:

            print(f'Early stopping triggered after epoch {epoch+1}')
            break

# -----------------------------
# 5. Configuration and Data Loading
# -----------------------------
config = {
    'max_vocab_size': 15000,
    'max_seq_length': 128,
    'embed_dim': 300,  # Must match the dimension of the pretrained embeddings
    'hidden_dim': 256,
    'batch_size': 16,
    'learning_rate': 0.001,
    'num_epochs': 20,
    'num_lstm_layers': 2,
    'pretrained_embedding_path': '/Users/User/CSProjects/CSC392_AI_agent/emphatic-AI-Winter2025/glove.6B/glove.6B.300d.txt'  # Update this path as needed
}  

# Load your datasets (assumed to be in TSV format)
train_df = pd.read_csv('train.tsv', sep='\t')
test_df = pd.read_csv('test.tsv', sep='\t')

# Map your string labels to numerical values
label_mapping = {'NOCUOUS': 0, 'INNOCUOUS': 1}
train_df['Detected as'] = train_df['Detected as'].map(label_mapping)
test_df['Detected as'] = test_df['Detected as'].map(label_mapping)

# -----------------------------
# 6. Preprocessing
# -----------------------------
preprocessor = TextPreprocessor(max_vocab_size=config['max_vocab_size'], 
                                max_seq_length=config['max_seq_length'])
preprocessor.fit(train_df['Sentence'])

X_train = preprocessor.transform(train_df['Sentence'])
X_val = preprocessor.transform(test_df['Sentence'])
y_train = torch.tensor(train_df['Detected as'].values)
y_val = torch.tensor(test_df['Detected as'].values)

train_dataset = TextDataset(X_train, y_train)
val_dataset = TextDataset(X_val, y_val)

train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=config['batch_size'])

x_np = X_train.numpy()
y_np = y_train.numpy()

# ----------------------------
# 7. 10-Fold Cross Validation
# ----------------------------

num_folds = 10
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

fold_results = []

for fold, (train_idx, val_idx) in enumerate(skf.split(x_np, y_np)): 
    print(f"\n------- Fold {fold+1} / {num_folds} --------- ")

    # -----------------------------
    # 1. Split Data
    # -----------------------------
    X_train_fold = torch.tensor(x_np[train_idx])
    y_train_fold = torch.tensor(y_np[train_idx])
    X_val_fold = torch.tensor(x_np[val_idx])
    y_val_fold = torch.tensor(y_np[val_idx])

    train_dataset = TextDataset(X_train_fold, y_train_fold)
    val_dataset = TextDataset(X_val_fold, y_val_fold)

    train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=config['batch_size'])

    # -----------------------------
    # 2. Initialize Model, Optimizer, and Criterion Inside the Loop
    # -----------------------------
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    model = ImprovedTextClassifier(
        vocab_size=len(preprocessor.word2idx),
        embed_dim=config['embed_dim'],
        hidden_dim=config['hidden_dim'],
        num_classes=2,
        num_layers=config['num_lstm_layers']
    ).to(device)

    # Load pretrained embeddings and replace the embedding layer weights
    pretrained_weights = load_pretrained_embeddings(config['pretrained_embedding_path'], 
                                                    preprocessor.word2idx, 
                                                    config['embed_dim'])
    model.embedding = nn.Embedding.from_pretrained(pretrained_weights, freeze=False, padding_idx=0)

    # Compute class weights to handle class imbalance
    small_factor = 1e-4
    class_counts = torch.bincount(y_train_fold) + small_factor  # Avoid division by zero
    class_weights = 1.0 / class_counts.float()
    class_weights = class_weights / class_weights.sum()
    class_weights = class_weights.to(device)

    criterion = nn.CrossEntropyLoss(weight=class_weights)
    optimizer = optim.AdamW(model.parameters(), lr=config['learning_rate'], weight_decay=0.01)
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2, verbose=True)

    # -----------------------------
    # 3. Train the Model
    # -----------------------------
    train_model(model, train_loader, val_loader, criterion, optimizer, scheduler,
                config['num_epochs'], device, preprocessor, config)

    # Load the best model for this fold
    with torch.serialization.safe_globals([TextPreprocessor]):
        checkpoint = torch.load('best_model.pt', weights_only=False)
    
    model.load_state_dict(checkpoint['model_state_dict'])

    # -----------------------------
    # 4. Evaluate the Model
    # -----------------------------
    model.eval()
    val_preds = []
    val_labels = []

    with torch.no_grad():
        for batch_texts, batch_labels in val_loader:
            batch_texts, batch_labels = batch_texts.to(device), batch_labels.to(device)
            outputs = model(batch_texts)
            predictions = torch.argmax(outputs, dim=1)
            val_preds.extend(predictions.cpu().numpy())
            val_labels.extend(batch_labels.cpu().numpy())

    # Compute metrics
    val_precision, val_recall, val_f1, _ = precision_recall_fscore_support(val_labels, val_preds, average='binary')
    val_accuracy = accuracy_score(val_labels, val_preds)

    print(f"Fold {fold+1} Metrics:")
    print(f"Accuracy: {val_accuracy:.4f}, F1-score: {val_f1:.4f}, Precision: {val_precision:.4f}, Recall: {val_recall:.4f}\n")

    fold_results.append((val_accuracy, val_f1, val_precision, val_recall))

# -----------------------------
# 5. Display Overall Results
# -----------------------------
avg_accuracy = sum([x[0] for x in fold_results]) / num_folds
avg_f1 = sum([x[1] for x in fold_results]) / num_folds
avg_precision = sum([x[2] for x in fold_results]) / num_folds
avg_recall = sum([x[3] for x in fold_results]) / num_folds

print("\n========== Final Cross-Validation Results ==========")
print(f"Avg Accuracy: {avg_accuracy:.4f}, Avg F1-score: {avg_f1:.4f}, Avg Precision: {avg_precision:.4f}, Avg Recall: {avg_recall:.4f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       2 import torch.nn as nn
#       3 import torch.optim as optim
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\__init__.py:2108
#    2101 from torch._compile import _disable_dynamo  # usort: skip
#    2103 ################################################################################
#    2104 # Import interface functions defined in Python
#    2105 ################################################################################
#    2106
#    2107 # needs to be after the above ATen bindings so we can overwrite from Python side
# -> 2108 from torch import _VF as _VF, functional as functional  # usort: skip
#    2109 from torch.functional import *  # usort: skip # noqa: F403
#    2111 ################################################################################
#    2112 # Remove unnecessary members
#    2113 ################################################################################
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\functional.py:7
#       4 from typing import Any, List, Optional, Sequence, Tuple, TYPE_CHECKING, Union
#       6 import torch
# ----> 7 import torch.nn.functional as F
#       8 from torch import _VF, Tensor
#       9 from torch._C import _add_docstr
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\__init__.py:8
#       1 # mypy: allow-untyped-defs
#       2 from torch.nn.parameter import (  # usort: skip
#       3     Buffer as Buffer,
#       4     Parameter as Parameter,
#       5     UninitializedBuffer as UninitializedBuffer,
#       6     UninitializedParameter as UninitializedParameter,
#       7 )
# ----> 8 from torch.nn.modules import *  # usort: skip # noqa: F403
#       9 from torch.nn import (
#      10     attention as attention,
#      11     functional as functional,
#    (...)
#      16     utils as utils,
#      17 )
#      18 from torch.nn.parallel import DataParallel as DataParallel
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\__init__.py:135
#     117 from .padding import (
#     118     CircularPad1d,
#     119     CircularPad2d,
#    (...)
#     132     ZeroPad3d,
#     133 )
#     134 from .pixelshuffle import PixelShuffle, PixelUnshuffle
# --> 135 from .pooling import (
#     136     AdaptiveAvgPool1d,
#     137     AdaptiveAvgPool2d,
#     138     AdaptiveAvgPool3d,
#     139     AdaptiveMaxPool1d,
#     140     AdaptiveMaxPool2d,
#     141     AdaptiveMaxPool3d,
#     142     AvgPool1d,
#     143     AvgPool2d,
#     144     AvgPool3d,
#     145     FractionalMaxPool2d,
#     146     FractionalMaxPool3d,
#     147     LPPool1d,
#     148     LPPool2d,
#     149     LPPool3d,
#     150     MaxPool1d,
#     151     MaxPool2d,
#     152     MaxPool3d,
#     153     MaxUnpool1d,
#     154     MaxUnpool2d,
#     155     MaxUnpool3d,
#     156 )
#     157 from .rnn import GRU, GRUCell, LSTM, LSTMCell, RNN, RNNBase, RNNCell, RNNCellBase
#     158 from .sparse import Embedding, EmbeddingBag
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1091, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1190, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset
from collections import Counter
import numpy as np
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import pandas as pd
import re
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.model_selection import StratifiedKFold

# -----------------------------
# 1. Text Preprocessing Classes
# -----------------------------
class TextPreprocessor:
    def __init__(self, max_vocab_size=15000, max_seq_length=128):
        self.max_vocab_size = max_vocab_size
        self.max_seq_length = max_seq_length
        self.word2idx = {'<PAD>': 0, '<UNK>': 1}
        self.idx2word = {0: '<PAD>', 1: '<UNK>'}
        self.word_counts = Counter()
        
    def clean_text(self, text):
        text = str(text).lower()
        text = re.sub(r'[^a-zA-Z0-9\s.,!?]', '', text)
        text = ' '.join(text.split())
        return text
        
    def fit(self, texts):
        for text in texts:
            cleaned_text = self.clean_text(text)
            words = cleaned_text.split()
            self.word_counts.update(words)
        
        # Reserve two indices for PAD and UNK tokens
        vocab_words = [word for word, count in self.word_counts.most_common(self.max_vocab_size - 2)]
        for word in vocab_words:
            idx = len(self.word2idx)
            self.word2idx[word] = idx
            self.idx2word[idx] = word
    
    def transform(self, texts):
        sequences = []
        for text in texts:
            cleaned_text = self.clean_text(text)
            words = cleaned_text.split()
            # Truncate or pad sequences
            seq = [self.word2idx.get(word, self.word2idx['<UNK>']) for word in words[:self.max_seq_length]]
            seq = seq + [self.word2idx['<PAD>']] * (self.max_seq_length - len(seq))
            sequences.append(seq)
        return torch.tensor(sequences)

class TextDataset(Dataset):
    def __init__(self, texts, labels):
        self.texts = texts
        self.labels = labels
        
    def __len__(self):
        return len(self.texts)
    
    def __getitem__(self, idx):
        return self.texts[idx], self.labels[idx]

# -----------------------------
# 2. Define the Model
# -----------------------------
class ImprovedTextClassifier(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_classes, num_layers=2):
        super(ImprovedTextClassifier, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        self.embedding_dropout = nn.Dropout(0.2 if num_layers > 1 else 0.1)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, num_layers=num_layers, 
                            batch_first=True, bidirectional=True,
                            dropout=0.2 if num_layers > 1 else 0)
        self.attention = nn.Linear(hidden_dim * 2, 1)
        self.fc1 = nn.Linear(hidden_dim * 2, hidden_dim)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.dropout1 = nn.Dropout(0.3)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim // 2)
        self.bn2 = nn.BatchNorm1d(hidden_dim // 2)
        self.dropout2 = nn.Dropout(0.2)
        self.fc3 = nn.Linear(hidden_dim // 2, num_classes)
        
    def attention_net(self, lstm_output):
        # Compute attention weights and context vector
        energy = torch.tanh(self.attention(lstm_output))
        attention_weights = torch.softmax(self.attention(lstm_output), dim=1)
        context_vector = torch.sum(attention_weights * lstm_output, dim=1)
        return context_vector
        
    def forward(self, x):
        embedded = self.embedding(x)
        embedded = self.embedding_dropout(embedded)
        lstm_out, _ = self.lstm(embedded)
        attn_out = self.attention_net(lstm_out)
        x = self.fc1(attn_out)
        x = self.bn1(x)
        x = torch.relu(x)
        x = self.dropout1(x)
        x = self.fc2(x)
        x = self.bn2(x)
        x = torch.relu(x)
        x = self.dropout2(x)
        x = self.fc3(x)
        return x

# -----------------------------
# 3. Function to Load Pretrained Embeddings (GloVe)
# -----------------------------
def load_pretrained_embeddings(embedding_path, word2idx, embed_dim):
    print("Loading pretrained embeddings...")
    # Initialize embeddings with a uniform distribution
    embeddings = np.random.uniform(-0.05, 0.05, (len(word2idx), embed_dim))
    embeddings[word2idx['<PAD>']] = np.zeros(embed_dim)
    found = 0
    with open(embedding_path, 'r', encoding='utf-8') as f:
        for line in f:
            values = line.rstrip().split(' ')
            word = values[0]
            vector = np.asarray(values[1:], dtype='float32')
            if vector.shape[0] != embed_dim:
                continue  # Skip if dimensions mismatch
            if word in word2idx:
                embeddings[word2idx[word]] = vector
                found += 1
    print(f"Found {found} pretrained embeddings out of {len(word2idx)} words")
    return torch.tensor(embeddings, dtype=torch.float)

# -----------------------------
# 4. Training Function
# -----------------------------
def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs, device, preprocessor, config):
    best_f1 = 0
    #patience = 5
    # patience_counter = 0
    
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        train_preds = []
        train_labels = []
        
        for batch_texts, batch_labels in train_loader:
            batch_texts, batch_labels = batch_texts.to(device), batch_labels.to(device)
            optimizer.zero_grad()
            outputs = model(batch_texts)
            loss = criterion(outputs, batch_labels)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            train_loss += loss.item()
            predictions = torch.argmax(outputs, dim=1)
            train_preds.extend(predictions.cpu().numpy())
            train_labels.extend(batch_labels.cpu().numpy())
        
        model.eval()
        val_loss = 0
        val_preds = []
        val_labels = []
        
        with torch.no_grad():
            for batch_texts, batch_labels in val_loader:
                batch_texts, batch_labels = batch_texts.to(device), batch_labels.to(device)
                outputs = model(batch_texts)
                loss = criterion(outputs, batch_labels)
                val_loss += loss.item()
                predictions = torch.argmax(outputs, dim=1)
                val_preds.extend(predictions.cpu().numpy())
                val_labels.extend(batch_labels.cpu().numpy())
        
        train_precision, train_recall, train_f1, _ = precision_recall_fscore_support(train_labels, train_preds, average='binary')
        train_accuracy = accuracy_score(train_labels, train_preds)
        
        val_precision, val_recall, val_f1, _ = precision_recall_fscore_support(val_labels, val_preds, average='macro', zero_division=1)
        val_accuracy = accuracy_score(val_labels, val_preds)
        
        scheduler.step(val_loss)
        
        print(f'Epoch {epoch+1}/{num_epochs}:')
        print(f'Train Loss: {train_loss/len(train_loader):.4f}, Accuracy: {train_accuracy:.4f}, F1: {train_f1:.4f}')
        print(f'Val Loss: {val_loss/len(val_loader):.4f}, Accuracy: {val_accuracy:.4f}, F1: {val_f1:.4f}')
        print(f'Val Precision: {val_precision:.4f}, Recall: {val_recall:.4f}\n')
        
        if val_f1 > best_f1:
            best_f1 = val_f1
            torch.save({
                'model_state_dict': model.state_dict(),
                'preprocessor': preprocessor,
                'config': config
            }, 'best_model.pt')
            #patience_counter = 0
            #patience_counter += 1
            
        # if patience_counter >= patience:

        #     print(f'Early stopping triggered after epoch {epoch+1}')
        #     break

# -----------------------------
# 5. Configuration and Data Loading
# -----------------------------
config = {
    'max_vocab_size': 15000,
    'max_seq_length': 128,
    'embed_dim': 300,  # Must match the dimension of the pretrained embeddings
    'hidden_dim': 256,
    'batch_size': 16,
    'learning_rate': 0.001,
    'num_epochs': 50,
    'num_lstm_layers': 2,
    'pretrained_embedding_path': '/Users/User/CSProjects/CSC392_AI_agent/emphatic-AI-Winter2025/glove.6B/glove.6B.300d.txt'  # Update this path as needed
}  

# Load your datasets (assumed to be in TSV format)
train_df = pd.read_csv('train.tsv', sep='\t')
test_df = pd.read_csv('test.tsv', sep='\t')

# Map your string labels to numerical values
label_mapping = {'NOCUOUS': 0, 'INNOCUOUS': 1}
train_df['Detected as'] = train_df['Detected as'].map(label_mapping)
test_df['Detected as'] = test_df['Detected as'].map(label_mapping)

# -----------------------------
# 6. Preprocessing
# -----------------------------
preprocessor = TextPreprocessor(max_vocab_size=config['max_vocab_size'], 
                                max_seq_length=config['max_seq_length'])
preprocessor.fit(train_df['Sentence'])

X_train = preprocessor.transform(train_df['Sentence'])
X_val = preprocessor.transform(test_df['Sentence'])
y_train = torch.tensor(train_df['Detected as'].values)
y_val = torch.tensor(test_df['Detected as'].values)

train_dataset = TextDataset(X_train, y_train)
val_dataset = TextDataset(X_val, y_val)

train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=config['batch_size'])

x_np = X_train.numpy()
y_np = y_train.numpy()

# ----------------------------
# 7. 10-Fold Cross Validation
# ----------------------------

num_folds = 10
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

fold_results = []

for fold, (train_idx, val_idx) in enumerate(skf.split(x_np, y_np)): 
    print(f"\n------- Fold {fold+1} / {num_folds} --------- ")

    # -----------------------------
    # 1. Split Data
    # -----------------------------
    X_train_fold = torch.tensor(x_np[train_idx])
    y_train_fold = torch.tensor(y_np[train_idx])
    X_val_fold = torch.tensor(x_np[val_idx])
    y_val_fold = torch.tensor(y_np[val_idx])

    train_dataset = TextDataset(X_train_fold, y_train_fold)
    val_dataset = TextDataset(X_val_fold, y_val_fold)

    train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=config['batch_size'])

    # -----------------------------
    # 2. Initialize Model, Optimizer, and Criterion Inside the Loop
    # -----------------------------
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    model = ImprovedTextClassifier(
        vocab_size=len(preprocessor.word2idx),
        embed_dim=config['embed_dim'],
        hidden_dim=config['hidden_dim'],
        num_classes=2,
        num_layers=config['num_lstm_layers']
    ).to(device)

    # Load pretrained embeddings and replace the embedding layer weights
    pretrained_weights = load_pretrained_embeddings(config['pretrained_embedding_path'], 
                                                    preprocessor.word2idx, 
                                                    config['embed_dim'])
    model.embedding = nn.Embedding.from_pretrained(pretrained_weights, freeze=False, padding_idx=0)

    # Compute class weights to handle class imbalance
    small_factor = 1e-4
    class_counts = torch.bincount(y_train_fold) + small_factor  # Avoid division by zero
    class_weights = 1.0 / class_counts.float()
    class_weights = class_weights / class_weights.sum()
    class_weights = class_weights.to(device)

    criterion = nn.CrossEntropyLoss(weight=class_weights)
    optimizer = optim.AdamW(model.parameters(), lr=config['learning_rate'], weight_decay=0.01)
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2, verbose=True)

    # -----------------------------
    # 3. Train the Model
    # -----------------------------
    train_model(model, train_loader, val_loader, criterion, optimizer, scheduler,
                config['num_epochs'], device, preprocessor, config)

    # Load the best model for this fold
    with torch.serialization.safe_globals([TextPreprocessor]):
        checkpoint = torch.load('best_model.pt', weights_only=False)
    
    model.load_state_dict(checkpoint['model_state_dict'])

    # -----------------------------
    # 4. Evaluate the Model
    # -----------------------------
    model.eval()
    val_preds = []
    val_labels = []

    with torch.no_grad():
        for batch_texts, batch_labels in val_loader:
            batch_texts, batch_labels = batch_texts.to(device), batch_labels.to(device)
            outputs = model(batch_texts)
            predictions = torch.argmax(outputs, dim=1)
            val_preds.extend(predictions.cpu().numpy())
            val_labels.extend(batch_labels.cpu().numpy())

    # Compute metrics
    val_precision, val_recall, val_f1, _ = precision_recall_fscore_support(val_labels, val_preds, average='binary')
    val_accuracy = accuracy_score(val_labels, val_preds)

    print(f"Fold {fold+1} Metrics:")
    print(f"Accuracy: {val_accuracy:.4f}, F1-score: {val_f1:.4f}, Precision: {val_precision:.4f}, Recall: {val_recall:.4f}\n")

    fold_results.append((val_accuracy, val_f1, val_precision, val_recall))

# -----------------------------
# 5. Display Overall Results
# -----------------------------
avg_accuracy = sum([x[0] for x in fold_results]) / num_folds
avg_f1 = sum([x[1] for x in fold_results]) / num_folds
avg_precision = sum([x[2] for x in fold_results]) / num_folds
avg_recall = sum([x[3] for x in fold_results]) / num_folds

print("\n========== Final Cross-Validation Results ==========")
print(f"Avg Accuracy: {avg_accuracy:.4f}, Avg F1-score: {avg_f1:.4f}, Avg Precision: {avg_precision:.4f}, Avg Recall: {avg_recall:.4f}")
# Out:
# ------- Fold 1 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/50:
# Train Loss: 0.7015, Accuracy: 0.5680, F1: 0.3864
# Val Loss: 0.6878, Accuracy: 0.5714, F1: 0.3636
# Val Precision: 0.7857, Recall: 0.5000
#
# Epoch 2/50:
# Train Loss: 0.6060, Accuracy: 0.6640, F1: 0.6500
# Val Loss: 0.6859, Accuracy: 0.5714, F1: 0.3636
# Val Precision: 0.7857, Recall: 0.5000
#
# Epoch 3/50:
# Train Loss: 0.5496, Accuracy: 0.7200, F1: 0.7287
# Val Loss: 0.6887, Accuracy: 0.5714, F1: 0.3636
# Val Precision: 0.7857, Recall: 0.5000
#
# Epoch 4/50:
# Train Loss: 0.4751, Accuracy: 0.7840, F1: 0.7769
# Val Loss: 0.6839, Accuracy: 0.5714, F1: 0.3636
# Val Precision: 0.7857, Recall: 0.5000
#
# Epoch 5/50:
# Train Loss: 0.3849, Accuracy: 0.8320, F1: 0.8293
# Val Loss: 0.6917, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 6/50:
# Train Loss: 0.2100, Accuracy: 0.9520, F1: 0.9508
# Val Loss: 0.7215, Accuracy: 0.7857, F1: 0.7754
# Val Precision: 0.7889, Recall: 0.7708
#
# Epoch 7/50:
# Train Loss: 0.2019, Accuracy: 0.9440, F1: 0.9421
# Val Loss: 1.4007, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 8/50:
# Train Loss: 0.1468, Accuracy: 0.9520, F1: 0.9516
# Val Loss: 0.9826, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 9/50:
# Train Loss: 0.0917, Accuracy: 0.9760, F1: 0.9752
# Val Loss: 1.1640, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 10/50:
# Train Loss: 0.0729, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 0.9380, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 11/50:
# Train Loss: 0.0307, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1159, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 12/50:
# Train Loss: 0.0287, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.0567, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 13/50:
# Train Loss: 0.0431, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.2027, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 14/50:
# Train Loss: 0.0251, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.2247, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 15/50:
# Train Loss: 0.0254, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2100, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 16/50:
# Train Loss: 0.0421, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.2525, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 17/50:
# Train Loss: 0.0147, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2395, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 18/50:
# Train Loss: 0.0627, Accuracy: 0.9760, F1: 0.9748
# Val Loss: 1.2179, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 19/50:
# Train Loss: 0.0541, Accuracy: 0.9760, F1: 0.9752
# Val Loss: 1.1426, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 20/50:
# Train Loss: 0.0433, Accuracy: 0.9840, F1: 0.9836
# Val Loss: 1.2006, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 21/50:
# Train Loss: 0.0167, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1937, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 22/50:
# Train Loss: 0.0333, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2214, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 23/50:
# Train Loss: 0.0344, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2158, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 24/50:
# Train Loss: 0.0161, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2159, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 25/50:
# Train Loss: 0.0126, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2158, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 26/50:
# Train Loss: 0.0124, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1970, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 27/50:
# Train Loss: 0.0358, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.2173, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 28/50:
# Train Loss: 0.0215, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2113, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 29/50:
# Train Loss: 0.0163, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2048, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 30/50:
# Train Loss: 0.0413, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.2065, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 31/50:
# Train Loss: 0.0130, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2063, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 32/50:
# Train Loss: 0.0607, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.2152, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 33/50:
# Train Loss: 0.0117, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2079, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 34/50:
# Train Loss: 0.0408, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.2170, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 35/50:
# Train Loss: 0.0396, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.2191, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 36/50:
# Train Loss: 0.0118, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2164, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 37/50:
# Train Loss: 0.0216, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2216, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 38/50:
# Train Loss: 0.0244, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2239, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 39/50:
# Train Loss: 0.0159, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2141, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 40/50:
# Train Loss: 0.0493, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.2082, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 41/50:
# Train Loss: 0.0145, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2039, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 42/50:
# Train Loss: 0.0134, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2068, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 43/50:
# Train Loss: 0.0471, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.2042, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 44/50:
# Train Loss: 0.0508, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.2122, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 45/50:
# Train Loss: 0.0274, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2128, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 46/50:
# Train Loss: 0.0188, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2062, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 47/50:
# Train Loss: 0.0177, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2059, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 48/50:
# Train Loss: 0.0163, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2081, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 49/50:
# Train Loss: 0.0136, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2004, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 50/50:
# Train Loss: 0.0193, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2123, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Fold 1 Metrics:
# Accuracy: 0.7857, F1-score: 0.7273, Precision: 0.8000, Recall: 0.6667
#
#
# ------- Fold 2 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/50:
# Train Loss: 0.7198, Accuracy: 0.4720, F1: 0.4107
# Val Loss: 0.6954, Accuracy: 0.4286, F1: 0.3000
# Val Precision: 0.7143, Recall: 0.5000
#
# Epoch 2/50:
# Train Loss: 0.6222, Accuracy: 0.6240, F1: 0.6619
# Val Loss: 0.7187, Accuracy: 0.4286, F1: 0.3000
# Val Precision: 0.7143, Recall: 0.5000
#
# Epoch 3/50:
# Train Loss: 0.5148, Accuracy: 0.7600, F1: 0.7761
# Val Loss: 0.7340, Accuracy: 0.4286, F1: 0.3000
# Val Precision: 0.7143, Recall: 0.5000
#
# Epoch 4/50:
# Train Loss: 0.4336, Accuracy: 0.7760, F1: 0.7778
# Val Loss: 0.7028, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5222, Recall: 0.5208
#
# Epoch 5/50:
# Train Loss: 0.2996, Accuracy: 0.8880, F1: 0.8852
# Val Loss: 0.7068, Accuracy: 0.3571, F1: 0.2632
# Val Precision: 0.1923, Recall: 0.4167
#
# Epoch 6/50:
# Train Loss: 0.1879, Accuracy: 0.9200, F1: 0.9194
# Val Loss: 0.7248, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 7/50:
# Train Loss: 0.1965, Accuracy: 0.9360, F1: 0.9310
# Val Loss: 0.7473, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 8/50:
# Train Loss: 0.1330, Accuracy: 0.9600, F1: 0.9587
# Val Loss: 0.8603, Accuracy: 0.4286, F1: 0.3778
# Val Precision: 0.4583, Recall: 0.4792
#
# Epoch 9/50:
# Train Loss: 0.1737, Accuracy: 0.9280, F1: 0.9268
# Val Loss: 1.0142, Accuracy: 0.5000, F1: 0.4759
# Val Precision: 0.5606, Recall: 0.5417
#
# Epoch 10/50:
# Train Loss: 0.0868, Accuracy: 0.9840, F1: 0.9836
# Val Loss: 0.9825, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 11/50:
# Train Loss: 0.1305, Accuracy: 0.9520, F1: 0.9508
# Val Loss: 0.9981, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5833, Recall: 0.5833
#
# Epoch 12/50:
# Train Loss: 0.1319, Accuracy: 0.9520, F1: 0.9508
# Val Loss: 0.9194, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 13/50:
# Train Loss: 0.0767, Accuracy: 0.9760, F1: 0.9744
# Val Loss: 0.8666, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 14/50:
# Train Loss: 0.0578, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 0.9225, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 15/50:
# Train Loss: 0.0781, Accuracy: 0.9760, F1: 0.9756
# Val Loss: 0.9060, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 16/50:
# Train Loss: 0.0708, Accuracy: 0.9760, F1: 0.9752
# Val Loss: 0.9794, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 17/50:
# Train Loss: 0.0398, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.9080, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 18/50:
# Train Loss: 0.0511, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 0.8958, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 19/50:
# Train Loss: 0.0762, Accuracy: 0.9680, F1: 0.9667
# Val Loss: 0.9135, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7083, Recall: 0.7083
#
# Epoch 20/50:
# Train Loss: 0.0587, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.9380, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 21/50:
# Train Loss: 0.0759, Accuracy: 0.9760, F1: 0.9748
# Val Loss: 0.9476, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 22/50:
# Train Loss: 0.0602, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 0.9528, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 23/50:
# Train Loss: 0.0496, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.9400, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 24/50:
# Train Loss: 0.0563, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 0.9308, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 25/50:
# Train Loss: 0.0714, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 0.9404, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 26/50:
# Train Loss: 0.0716, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 0.9428, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 27/50:
# Train Loss: 0.0645, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 0.9392, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 28/50:
# Train Loss: 0.0509, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 0.9243, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 29/50:
# Train Loss: 0.0392, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.9149, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 30/50:
# Train Loss: 0.0398, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.9223, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 31/50:
# Train Loss: 0.0421, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 0.9251, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 32/50:
# Train Loss: 0.0675, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.9254, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 33/50:
# Train Loss: 0.0432, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.9307, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 34/50:
# Train Loss: 0.0537, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 0.9211, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 35/50:
# Train Loss: 0.0851, Accuracy: 0.9680, F1: 0.9672
# Val Loss: 0.9400, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 36/50:
# Train Loss: 0.0497, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.9380, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 37/50:
# Train Loss: 0.2554, Accuracy: 0.9360, F1: 0.9365
# Val Loss: 0.9594, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 38/50:
# Train Loss: 0.0815, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 0.9367, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 39/50:
# Train Loss: 0.0475, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.9295, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 40/50:
# Train Loss: 0.0347, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.9146, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 41/50:
# Train Loss: 0.0629, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 0.9302, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 42/50:
# Train Loss: 0.0748, Accuracy: 0.9680, F1: 0.9672
# Val Loss: 0.9214, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 43/50:
# Train Loss: 0.0463, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 0.9182, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 44/50:
# Train Loss: 0.0521, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 0.9305, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 45/50:
# Train Loss: 0.0438, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 0.9247, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 46/50:
# Train Loss: 0.0811, Accuracy: 0.9760, F1: 0.9752
# Val Loss: 0.9310, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 47/50:
# Train Loss: 0.0789, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 0.9215, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 48/50:
# Train Loss: 0.0816, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 0.9319, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6429, Recall: 0.6458
#
# Epoch 49/50:
# Train Loss: 0.0713, Accuracy: 0.9840, F1: 0.9836
# Val Loss: 0.9409, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 50/50:
# Train Loss: 0.0547, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 0.9446, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Fold 2 Metrics:
# Accuracy: 0.7143, F1-score: 0.7143, Precision: 0.6250, Recall: 0.8333
#
#
# ------- Fold 3 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/50:
# Train Loss: 0.7481, Accuracy: 0.5920, F1: 0.6107
# Val Loss: 0.6899, Accuracy: 0.5714, F1: 0.3636
# Val Precision: 0.7857, Recall: 0.5000
#
# Epoch 2/50:
# Train Loss: 0.6543, Accuracy: 0.5680, F1: 0.5574
# Val Loss: 0.6919, Accuracy: 0.5714, F1: 0.3636
# Val Precision: 0.7857, Recall: 0.5000
#
# Epoch 3/50:
# Train Loss: 0.5499, Accuracy: 0.7680, F1: 0.7642
# Val Loss: 0.6998, Accuracy: 0.4286, F1: 0.3000
# Val Precision: 0.7143, Recall: 0.5000
#
# Epoch 4/50:
# Train Loss: 0.4370, Accuracy: 0.8240, F1: 0.8226
# Val Loss: 0.7099, Accuracy: 0.4286, F1: 0.3000
# Val Precision: 0.7143, Recall: 0.5000
#
# Epoch 5/50:
# Train Loss: 0.3454, Accuracy: 0.8560, F1: 0.8500
# Val Loss: 0.6458, Accuracy: 0.7143, F1: 0.6889
# Val Precision: 0.7250, Recall: 0.6875
#
# Epoch 6/50:
# Train Loss: 0.2807, Accuracy: 0.9120, F1: 0.9060
# Val Loss: 0.6182, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 7/50:
# Train Loss: 0.2092, Accuracy: 0.9440, F1: 0.9402
# Val Loss: 0.5835, Accuracy: 0.7857, F1: 0.7846
# Val Precision: 0.7857, Recall: 0.7917
#
# Epoch 8/50:
# Train Loss: 0.1605, Accuracy: 0.9760, F1: 0.9752
# Val Loss: 0.6437, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 9/50:
# Train Loss: 0.0891, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 0.6900, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 10/50:
# Train Loss: 0.1227, Accuracy: 0.9680, F1: 0.9667
# Val Loss: 0.7576, Accuracy: 0.7857, F1: 0.7846
# Val Precision: 0.7857, Recall: 0.7917
#
# Epoch 11/50:
# Train Loss: 0.0572, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 0.9662, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 12/50:
# Train Loss: 0.0700, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.2247, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 13/50:
# Train Loss: 0.0408, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1484, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 14/50:
# Train Loss: 0.0500, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0084, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 15/50:
# Train Loss: 0.0661, Accuracy: 0.9840, F1: 0.9836
# Val Loss: 0.9100, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 16/50:
# Train Loss: 0.0930, Accuracy: 0.9680, F1: 0.9667
# Val Loss: 0.7755, Accuracy: 0.7857, F1: 0.7846
# Val Precision: 0.7857, Recall: 0.7917
#
# Epoch 17/50:
# Train Loss: 0.0278, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.8507, Accuracy: 0.7857, F1: 0.7846
# Val Precision: 0.7857, Recall: 0.7917
#
# Epoch 18/50:
# Train Loss: 0.0298, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.8671, Accuracy: 0.7857, F1: 0.7846
# Val Precision: 0.7857, Recall: 0.7917
#
# Epoch 19/50:
# Train Loss: 0.0292, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.8808, Accuracy: 0.7857, F1: 0.7846
# Val Precision: 0.7857, Recall: 0.7917
#
# Epoch 20/50:
# Train Loss: 0.0269, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.8975, Accuracy: 0.7857, F1: 0.7846
# Val Precision: 0.7857, Recall: 0.7917
#
# Epoch 21/50:
# Train Loss: 0.0417, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 0.9557, Accuracy: 0.7857, F1: 0.7846
# Val Precision: 0.7857, Recall: 0.7917
#
# Epoch 22/50:
# Train Loss: 0.0443, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.0335, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 23/50:
# Train Loss: 0.0251, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0510, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 24/50:
# Train Loss: 0.0346, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0741, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 25/50:
# Train Loss: 0.0356, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.0799, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 26/50:
# Train Loss: 0.0320, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.0005, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 27/50:
# Train Loss: 0.0218, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.9865, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 28/50:
# Train Loss: 0.0338, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.9608, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 29/50:
# Train Loss: 0.0977, Accuracy: 0.9600, F1: 0.9593
# Val Loss: 1.0247, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 30/50:
# Train Loss: 0.0281, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0024, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 31/50:
# Train Loss: 0.0218, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0070, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 32/50:
# Train Loss: 0.0433, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 0.9966, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 33/50:
# Train Loss: 0.0698, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 0.9770, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 34/50:
# Train Loss: 0.0373, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 0.9612, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 35/50:
# Train Loss: 0.0304, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.9855, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 36/50:
# Train Loss: 0.0333, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 0.9854, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 37/50:
# Train Loss: 0.0347, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 1.0092, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 38/50:
# Train Loss: 0.0278, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0497, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 39/50:
# Train Loss: 0.0741, Accuracy: 0.9600, F1: 0.9593
# Val Loss: 1.0766, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Epoch 40/50:
# Train Loss: 0.0447, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.0060, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 41/50:
# Train Loss: 0.0192, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.9858, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 42/50:
# Train Loss: 0.0355, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0044, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 43/50:
# Train Loss: 0.0330, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0026, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 44/50:
# Train Loss: 0.0402, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 0.9585, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 45/50:
# Train Loss: 0.0305, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.9468, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 46/50:
# Train Loss: 0.0252, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.9714, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 47/50:
# Train Loss: 0.0419, Accuracy: 0.9920, F1: 0.9917
# Val Loss: 0.9759, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 48/50:
# Train Loss: 0.0254, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.9548, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7292, Recall: 0.7292
#
# Epoch 49/50:
# Train Loss: 0.0500, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 0.9855, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6778, Recall: 0.6667
#
# Epoch 50/50:
# Train Loss: 0.0417, Accuracy: 0.9840, F1: 0.9836
# Val Loss: 1.0413, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.6250, Recall: 0.6042
#
# Fold 3 Metrics:
# Accuracy: 0.7857, F1-score: 0.7692, Precision: 0.7143, Recall: 0.8333
#
#
# ------- Fold 4 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/50:
# Train Loss: 0.8290, Accuracy: 0.4480, F1: 0.4889
# Val Loss: 0.6909, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 2/50:
# Train Loss: 0.6662, Accuracy: 0.6400, F1: 0.6667
# Val Loss: 0.6821, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 3/50:
# Train Loss: 0.6034, Accuracy: 0.6800, F1: 0.6774
# Val Loss: 0.6803, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 4/50:
# Train Loss: 0.5533, Accuracy: 0.7600, F1: 0.7368
# Val Loss: 0.7021, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 5/50:
# Train Loss: 0.3798, Accuracy: 0.8560, F1: 0.8475
# Val Loss: 0.7575, Accuracy: 0.2857, F1: 0.2708
# Val Precision: 0.2667, Recall: 0.2857
#
# Epoch 6/50:
# Train Loss: 0.3840, Accuracy: 0.8480, F1: 0.8319
# Val Loss: 0.6998, Accuracy: 0.4286, F1: 0.3000
# Val Precision: 0.2308, Recall: 0.4286
#
# Epoch 7/50:
# Train Loss: 0.2168, Accuracy: 0.9200, F1: 0.9138
# Val Loss: 0.5128, Accuracy: 0.7857, F1: 0.7846
# Val Precision: 0.7917, Recall: 0.7857
#
# Epoch 8/50:
# Train Loss: 0.1403, Accuracy: 0.9600, F1: 0.9587
# Val Loss: 0.8055, Accuracy: 0.6429, F1: 0.6257
# Val Precision: 0.6750, Recall: 0.6429
#
# Epoch 9/50:
# Train Loss: 0.1583, Accuracy: 0.9440, F1: 0.9421
# Val Loss: 0.6582, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7333, Recall: 0.7143
#
# Epoch 10/50:
# Train Loss: 0.1615, Accuracy: 0.9440, F1: 0.9412
# Val Loss: 0.6779, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 11/50:
# Train Loss: 0.0647, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.0073, Accuracy: 0.5714, F1: 0.4750
# Val Precision: 0.7692, Recall: 0.5714
#
# Epoch 12/50:
# Train Loss: 0.0891, Accuracy: 0.9680, F1: 0.9667
# Val Loss: 0.9578, Accuracy: 0.5000, F1: 0.4269
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 13/50:
# Train Loss: 0.0466, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 0.7625, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7333, Recall: 0.7143
#
# Epoch 14/50:
# Train Loss: 0.0439, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 0.6882, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 15/50:
# Train Loss: 0.0493, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 0.6628, Accuracy: 0.7857, F1: 0.7846
# Val Precision: 0.7917, Recall: 0.7857
#
# Epoch 16/50:
# Train Loss: 0.0498, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.6587, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 17/50:
# Train Loss: 0.0362, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.6608, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 18/50:
# Train Loss: 0.0315, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.6551, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 19/50:
# Train Loss: 0.0636, Accuracy: 0.9760, F1: 0.9748
# Val Loss: 0.6628, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 20/50:
# Train Loss: 0.0381, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 0.6553, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 21/50:
# Train Loss: 0.0302, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 0.6545, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 22/50:
# Train Loss: 0.0366, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 0.6581, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 23/50:
# Train Loss: 0.0522, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 0.6610, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 24/50:
# Train Loss: 0.0267, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.6635, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 25/50:
# Train Loss: 0.0300, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 0.6661, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 26/50:
# Train Loss: 0.0407, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 0.6773, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 27/50:
# Train Loss: 0.0589, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 0.6718, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 28/50:
# Train Loss: 0.0289, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.6756, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 29/50:
# Train Loss: 0.0997, Accuracy: 0.9680, F1: 0.9661
# Val Loss: 0.6820, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 30/50:
# Train Loss: 0.0335, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 0.6735, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 31/50:
# Train Loss: 0.0262, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.6739, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 32/50:
# Train Loss: 0.0441, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 0.6731, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 33/50:
# Train Loss: 0.0457, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 0.6833, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 34/50:
# Train Loss: 0.0304, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.6798, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 35/50:
# Train Loss: 0.0286, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.6837, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 36/50:
# Train Loss: 0.0240, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.6752, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 37/50:
# Train Loss: 0.0527, Accuracy: 0.9680, F1: 0.9661
# Val Loss: 0.6721, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 38/50:
# Train Loss: 0.0634, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 0.6793, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 39/50:
# Train Loss: 0.0239, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 0.6705, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 40/50:
# Train Loss: 0.0362, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 0.6715, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 41/50:
# Train Loss: 0.0274, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.6714, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 42/50:
# Train Loss: 0.0498, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 0.6792, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 43/50:
# Train Loss: 0.0368, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 0.6760, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 44/50:
# Train Loss: 0.0693, Accuracy: 0.9760, F1: 0.9748
# Val Loss: 0.6736, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 45/50:
# Train Loss: 0.0483, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 0.6717, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 46/50:
# Train Loss: 0.0396, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 0.6688, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 47/50:
# Train Loss: 0.0472, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 0.6651, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 48/50:
# Train Loss: 0.0444, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 0.6691, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 49/50:
# Train Loss: 0.0824, Accuracy: 0.9760, F1: 0.9744
# Val Loss: 0.6765, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Epoch 50/50:
# Train Loss: 0.0302, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 0.6782, Accuracy: 0.8571, F1: 0.8571
# Val Precision: 0.8571, Recall: 0.8571
#
# Fold 4 Metrics:
# Accuracy: 0.8571, F1-score: 0.8571, Precision: 0.8571, Recall: 0.8571
#
#
# ------- Fold 5 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/50:
# Train Loss: 0.7427, Accuracy: 0.5280, F1: 0.5042
# Val Loss: 0.6916, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 2/50:
# Train Loss: 0.6173, Accuracy: 0.6880, F1: 0.6929
# Val Loss: 0.6900, Accuracy: 0.5714, F1: 0.4750
# Val Precision: 0.7692, Recall: 0.5714
#
# Epoch 3/50:
# Train Loss: 0.5156, Accuracy: 0.7920, F1: 0.7937
# Val Loss: 0.6869, Accuracy: 0.5000, F1: 0.4759
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 4/50:
# Train Loss: 0.3327, Accuracy: 0.8880, F1: 0.8852
# Val Loss: 0.6862, Accuracy: 0.5000, F1: 0.4269
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 5/50:
# Train Loss: 0.2323, Accuracy: 0.8960, F1: 0.8960
# Val Loss: 0.6861, Accuracy: 0.5000, F1: 0.4269
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 6/50:
# Train Loss: 0.2549, Accuracy: 0.9040, F1: 0.9000
# Val Loss: 0.6747, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 7/50:
# Train Loss: 0.1381, Accuracy: 0.9360, F1: 0.9310
# Val Loss: 0.8235, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 8/50:
# Train Loss: 0.1266, Accuracy: 0.9600, F1: 0.9573
# Val Loss: 1.3216, Accuracy: 0.5000, F1: 0.4269
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 9/50:
# Train Loss: 0.1839, Accuracy: 0.9280, F1: 0.9231
# Val Loss: 1.5401, Accuracy: 0.6429, F1: 0.6257
# Val Precision: 0.6750, Recall: 0.6429
#
# Epoch 10/50:
# Train Loss: 0.0900, Accuracy: 0.9760, F1: 0.9748
# Val Loss: 1.8006, Accuracy: 0.6429, F1: 0.5906
# Val Precision: 0.7917, Recall: 0.6429
#
# Epoch 11/50:
# Train Loss: 0.1037, Accuracy: 0.9520, F1: 0.9508
# Val Loss: 1.2341, Accuracy: 0.7143, F1: 0.6889
# Val Precision: 0.8182, Recall: 0.7143
#
# Epoch 12/50:
# Train Loss: 0.0466, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.4666, Accuracy: 0.5000, F1: 0.4759
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 13/50:
# Train Loss: 0.0244, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4979, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 14/50:
# Train Loss: 0.0356, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.3616, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 15/50:
# Train Loss: 0.0302, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.2603, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 16/50:
# Train Loss: 0.0460, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.2679, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 17/50:
# Train Loss: 0.0213, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.3742, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 18/50:
# Train Loss: 0.0211, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3784, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 19/50:
# Train Loss: 0.0829, Accuracy: 0.9600, F1: 0.9593
# Val Loss: 1.4460, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 20/50:
# Train Loss: 0.0495, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.4037, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 21/50:
# Train Loss: 0.0281, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4946, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 22/50:
# Train Loss: 0.0212, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5132, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 23/50:
# Train Loss: 0.0515, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.5175, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 24/50:
# Train Loss: 0.0211, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.4874, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 25/50:
# Train Loss: 0.0156, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4829, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 26/50:
# Train Loss: 0.0506, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.4676, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 27/50:
# Train Loss: 0.0143, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4908, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 28/50:
# Train Loss: 0.0120, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4833, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 29/50:
# Train Loss: 0.0261, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.4328, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 30/50:
# Train Loss: 0.0084, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3881, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 31/50:
# Train Loss: 0.0246, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.4556, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 32/50:
# Train Loss: 0.0274, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.4643, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 33/50:
# Train Loss: 0.0255, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.3968, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 34/50:
# Train Loss: 0.0098, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4042, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 35/50:
# Train Loss: 0.0330, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.4791, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 36/50:
# Train Loss: 0.0447, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.4766, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 37/50:
# Train Loss: 0.0168, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4976, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 38/50:
# Train Loss: 0.0110, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4855, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 39/50:
# Train Loss: 0.0118, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5006, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 40/50:
# Train Loss: 0.0532, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.4971, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 41/50:
# Train Loss: 0.0206, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.4496, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 42/50:
# Train Loss: 0.0228, Accuracy: 0.9840, F1: 0.9828
# Val Loss: 1.4955, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 43/50:
# Train Loss: 0.1077, Accuracy: 0.9760, F1: 0.9744
# Val Loss: 1.4559, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 44/50:
# Train Loss: 0.0469, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.4592, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 45/50:
# Train Loss: 0.0333, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.4382, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 46/50:
# Train Loss: 0.0527, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.4962, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 47/50:
# Train Loss: 0.0087, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4793, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 48/50:
# Train Loss: 0.0717, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.4664, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 49/50:
# Train Loss: 0.0272, Accuracy: 0.9840, F1: 0.9828
# Val Loss: 1.4744, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 50/50:
# Train Loss: 0.0179, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.4851, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Fold 5 Metrics:
# Accuracy: 0.7143, F1-score: 0.7778, Precision: 0.6364, Recall: 1.0000
#
#
# ------- Fold 6 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/50:
# Train Loss: 0.7352, Accuracy: 0.5440, F1: 0.6014
# Val Loss: 0.6930, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 2/50:
# Train Loss: 0.6727, Accuracy: 0.6160, F1: 0.6250
# Val Loss: 0.6982, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 3/50:
# Train Loss: 0.5212, Accuracy: 0.7840, F1: 0.7840
# Val Loss: 0.6836, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 4/50:
# Train Loss: 0.3240, Accuracy: 0.8880, F1: 0.8833
# Val Loss: 0.6780, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 5/50:
# Train Loss: 0.4068, Accuracy: 0.8320, F1: 0.8108
# Val Loss: 0.7509, Accuracy: 0.5000, F1: 0.4759
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 6/50:
# Train Loss: 0.4210, Accuracy: 0.8480, F1: 0.8348
# Val Loss: 0.6013, Accuracy: 0.7143, F1: 0.6889
# Val Precision: 0.8182, Recall: 0.7143
#
# Epoch 7/50:
# Train Loss: 0.2127, Accuracy: 0.9360, F1: 0.9322
# Val Loss: 0.9870, Accuracy: 0.5714, F1: 0.4750
# Val Precision: 0.7692, Recall: 0.5714
#
# Epoch 8/50:
# Train Loss: 0.1255, Accuracy: 0.9760, F1: 0.9748
# Val Loss: 0.7877, Accuracy: 0.6429, F1: 0.5906
# Val Precision: 0.7917, Recall: 0.6429
#
# Epoch 9/50:
# Train Loss: 0.1154, Accuracy: 0.9680, F1: 0.9661
# Val Loss: 1.6618, Accuracy: 0.5000, F1: 0.4269
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 10/50:
# Train Loss: 0.0648, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.5851, Accuracy: 0.6429, F1: 0.5906
# Val Precision: 0.7917, Recall: 0.6429
#
# Epoch 11/50:
# Train Loss: 0.0921, Accuracy: 0.9760, F1: 0.9748
# Val Loss: 1.1562, Accuracy: 0.5000, F1: 0.4759
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 12/50:
# Train Loss: 0.0560, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.0334, Accuracy: 0.7143, F1: 0.7083
# Val Precision: 0.7333, Recall: 0.7143
#
# Epoch 13/50:
# Train Loss: 0.0408, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.0571, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 14/50:
# Train Loss: 0.0656, Accuracy: 0.9840, F1: 0.9833
# Val Loss: 1.2249, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 15/50:
# Train Loss: 0.0312, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.0890, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 16/50:
# Train Loss: 0.0263, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.0456, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 17/50:
# Train Loss: 0.0262, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.0817, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 18/50:
# Train Loss: 0.0169, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1988, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 19/50:
# Train Loss: 0.0234, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.2924, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 20/50:
# Train Loss: 0.0269, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3267, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 21/50:
# Train Loss: 0.0122, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3325, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 22/50:
# Train Loss: 0.0165, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2691, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 23/50:
# Train Loss: 0.0476, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.2302, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 24/50:
# Train Loss: 0.0135, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2233, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 25/50:
# Train Loss: 0.0155, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2141, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 26/50:
# Train Loss: 0.0199, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2272, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 27/50:
# Train Loss: 0.0139, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2228, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 28/50:
# Train Loss: 0.0198, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2173, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 29/50:
# Train Loss: 0.0257, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2170, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 30/50:
# Train Loss: 0.0491, Accuracy: 0.9840, F1: 0.9831
# Val Loss: 1.2339, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 31/50:
# Train Loss: 0.0151, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2261, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 32/50:
# Train Loss: 0.0300, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.2052, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 33/50:
# Train Loss: 0.0106, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2405, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 34/50:
# Train Loss: 0.0369, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.2435, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 35/50:
# Train Loss: 0.0621, Accuracy: 0.9760, F1: 0.9744
# Val Loss: 1.2316, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 36/50:
# Train Loss: 0.0179, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2136, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 37/50:
# Train Loss: 0.0248, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.2211, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 38/50:
# Train Loss: 0.0237, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2520, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 39/50:
# Train Loss: 0.0108, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2319, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 40/50:
# Train Loss: 0.0394, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.2197, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 41/50:
# Train Loss: 0.0320, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.2394, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 42/50:
# Train Loss: 0.0287, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2264, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 43/50:
# Train Loss: 0.0184, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2382, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 44/50:
# Train Loss: 0.0160, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2351, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 45/50:
# Train Loss: 0.0179, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2485, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 46/50:
# Train Loss: 0.0158, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2268, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 47/50:
# Train Loss: 0.0114, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2173, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 48/50:
# Train Loss: 0.0354, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 1.2005, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 49/50:
# Train Loss: 0.0102, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2261, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Epoch 50/50:
# Train Loss: 0.0201, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2280, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6458, Recall: 0.6429
#
# Fold 6 Metrics:
# Accuracy: 0.7143, F1-score: 0.7500, Precision: 0.6667, Recall: 0.8571
#
#
# ------- Fold 7 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/50:
# Train Loss: 0.7302, Accuracy: 0.5200, F1: 0.5946
# Val Loss: 0.6919, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 2/50:
# Train Loss: 0.6087, Accuracy: 0.6480, F1: 0.6812
# Val Loss: 0.6931, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# ...
#
# Fold 8 Metrics:
# Accuracy: 0.7143, F1-score: 0.7143, Precision: 0.7143, Recall: 0.7143
#
#
# ------- Fold 9 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/50:
# Train Loss: 0.7126, Accuracy: 0.5440, F1: 0.5128
# Val Loss: 0.6914, Accuracy: 0.7143, F1: 0.6889
# Val Precision: 0.8182, Recall: 0.7143
#
# Epoch 2/50:
# Train Loss: 0.6135, Accuracy: 0.6800, F1: 0.6610
# Val Loss: 0.6976, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 3/50:
# Train Loss: 0.5365, Accuracy: 0.7760, F1: 0.7742
# Val Loss: 0.6890, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 4/50:
# Train Loss: 0.3348, Accuracy: 0.8720, F1: 0.8667
# Val Loss: 0.7330, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 5/50:
# Train Loss: 0.1909, Accuracy: 0.9440, F1: 0.9381
# Val Loss: 0.8009, Accuracy: 0.2857, F1: 0.2708
# Val Precision: 0.2667, Recall: 0.2857
#
# Epoch 6/50:
# Train Loss: 0.1983, Accuracy: 0.9280, F1: 0.9231
# Val Loss: 0.7938, Accuracy: 0.5714, F1: 0.5333
# Val Precision: 0.6061, Recall: 0.5714
#
# Epoch 7/50:
# Train Loss: 0.1532, Accuracy: 0.9440, F1: 0.9431
# Val Loss: 1.1920, Accuracy: 0.5000, F1: 0.4759
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 8/50:
# Train Loss: 0.1434, Accuracy: 0.9520, F1: 0.9500
# Val Loss: 1.1798, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 9/50:
# Train Loss: 0.0748, Accuracy: 0.9760, F1: 0.9744
# Val Loss: 1.5496, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 10/50:
# Train Loss: 0.0384, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.9582, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 11/50:
# Train Loss: 0.0668, Accuracy: 0.9760, F1: 0.9748
# Val Loss: 1.7494, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 12/50:
# Train Loss: 0.0467, Accuracy: 0.9840, F1: 0.9828
# Val Loss: 1.7609, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 13/50:
# Train Loss: 0.0290, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.8557, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 14/50:
# Train Loss: 0.0388, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 2.0965, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 15/50:
# Train Loss: 0.0256, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.0093, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 16/50:
# Train Loss: 0.0347, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 1.9483, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 17/50:
# Train Loss: 0.0531, Accuracy: 0.9760, F1: 0.9748
# Val Loss: 1.9892, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 18/50:
# Train Loss: 0.0442, Accuracy: 0.9760, F1: 0.9748
# Val Loss: 1.9906, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 19/50:
# Train Loss: 0.0209, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.0411, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 20/50:
# Train Loss: 0.0236, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.0543, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 21/50:
# Train Loss: 0.0952, Accuracy: 0.9600, F1: 0.9573
# Val Loss: 2.1583, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 22/50:
# Train Loss: 0.0219, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 2.0922, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 23/50:
# Train Loss: 0.0128, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.0713, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 24/50:
# Train Loss: 0.0119, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.1197, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 25/50:
# Train Loss: 0.0275, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.1159, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 26/50:
# Train Loss: 0.0103, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.1134, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 27/50:
# Train Loss: 0.0448, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 2.0634, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 28/50:
# Train Loss: 0.0176, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.0561, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 29/50:
# Train Loss: 0.0145, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.0862, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 30/50:
# Train Loss: 0.0155, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.1166, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 31/50:
# Train Loss: 0.0478, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 2.1726, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 32/50:
# Train Loss: 0.0185, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.1446, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 33/50:
# Train Loss: 0.0604, Accuracy: 0.9920, F1: 0.9915
# Val Loss: 2.1313, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 34/50:
# Train Loss: 0.0444, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 2.0594, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 35/50:
# Train Loss: 0.0163, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.0672, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 36/50:
# Train Loss: 0.0130, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.1189, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 37/50:
# Train Loss: 0.0105, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.1103, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 38/50:
# Train Loss: 0.0607, Accuracy: 0.9760, F1: 0.9744
# Val Loss: 2.1627, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 39/50:
# Train Loss: 0.0315, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 2.1294, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 40/50:
# Train Loss: 0.0183, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 2.1248, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 41/50:
# Train Loss: 0.0144, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.1094, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 42/50:
# Train Loss: 0.0092, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.1422, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 43/50:
# Train Loss: 0.0189, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.1332, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 44/50:
# Train Loss: 0.0426, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 2.2214, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 45/50:
# Train Loss: 0.0167, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.1884, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 46/50:
# Train Loss: 0.0182, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.1828, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 47/50:
# Train Loss: 0.0127, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.2133, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 48/50:
# Train Loss: 0.0149, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.1828, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 49/50:
# Train Loss: 0.0226, Accuracy: 0.9920, F1: 0.9916
# Val Loss: 2.1557, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Epoch 50/50:
# Train Loss: 0.0154, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.1191, Accuracy: 0.4286, F1: 0.4167
# Val Precision: 0.4222, Recall: 0.4286
#
# Fold 9 Metrics:
# Accuracy: 0.7143, F1-score: 0.6000, Precision: 1.0000, Recall: 0.4286
#
#
# ------- Fold 10 / 10 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/50:
# Train Loss: 0.7171, Accuracy: 0.5397, F1: 0.5606
# Val Loss: 0.6904, Accuracy: 0.5385, F1: 0.3500
# Val Precision: 0.7692, Recall: 0.5000
#
# Epoch 2/50:
# Train Loss: 0.6581, Accuracy: 0.6270, F1: 0.6713
# Val Loss: 0.6937, Accuracy: 0.4615, F1: 0.3158
# Val Precision: 0.7308, Recall: 0.5000
#
# Epoch 3/50:
# Train Loss: 0.5107, Accuracy: 0.7460, F1: 0.7460
# Val Loss: 0.6833, Accuracy: 0.5385, F1: 0.3500
# Val Precision: 0.7692, Recall: 0.5000
#
# Epoch 4/50:
# Train Loss: 0.4630, Accuracy: 0.8254, F1: 0.8281
# Val Loss: 0.7339, Accuracy: 0.4615, F1: 0.3158
# Val Precision: 0.7308, Recall: 0.5000
#
# Epoch 5/50:
# Train Loss: 0.4220, Accuracy: 0.8095, F1: 0.8065
# Val Loss: 0.6545, Accuracy: 0.4615, F1: 0.3158
# Val Precision: 0.2500, Recall: 0.4286
#
# Epoch 6/50:
# Train Loss: 0.2006, Accuracy: 0.9683, F1: 0.9661
# Val Loss: 0.7229, Accuracy: 0.3077, F1: 0.2909
# Val Precision: 0.2875, Recall: 0.2976
#
# Epoch 7/50:
# Train Loss: 0.1458, Accuracy: 0.9603, F1: 0.9593
# Val Loss: 1.5312, Accuracy: 0.4615, F1: 0.3158
# Val Precision: 0.7308, Recall: 0.5000
#
# Epoch 8/50:
# Train Loss: 0.1971, Accuracy: 0.9127, F1: 0.9106
# Val Loss: 1.2873, Accuracy: 0.3846, F1: 0.3810
# Val Precision: 0.3810, Recall: 0.3810
#
# Epoch 9/50:
# Train Loss: 0.0816, Accuracy: 0.9762, F1: 0.9756
# Val Loss: 1.3421, Accuracy: 0.3077, F1: 0.2909
# Val Precision: 0.2875, Recall: 0.2976
#
# Epoch 10/50:
# Train Loss: 0.0778, Accuracy: 0.9762, F1: 0.9748
# Val Loss: 1.2176, Accuracy: 0.3846, F1: 0.3810
# Val Precision: 0.3810, Recall: 0.3810
#
# Epoch 11/50:
# Train Loss: 0.0494, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.3767, Accuracy: 0.6154, F1: 0.6061
# Val Precision: 0.6528, Recall: 0.6310
#
# Epoch 12/50:
# Train Loss: 0.0386, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.8216, Accuracy: 0.3077, F1: 0.2909
# Val Precision: 0.2875, Recall: 0.2976
#
# Epoch 13/50:
# Train Loss: 0.1320, Accuracy: 0.9603, F1: 0.9587
# Val Loss: 2.1370, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 14/50:
# Train Loss: 0.0425, Accuracy: 0.9841, F1: 0.9836
# Val Loss: 2.2734, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 15/50:
# Train Loss: 0.0996, Accuracy: 0.9762, F1: 0.9752
# Val Loss: 2.3427, Accuracy: 0.3077, F1: 0.2353
# Val Precision: 0.2000, Recall: 0.2857
#
# Epoch 16/50:
# Train Loss: 0.0400, Accuracy: 0.9841, F1: 0.9833
# Val Loss: 2.3328, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 17/50:
# Train Loss: 0.0566, Accuracy: 0.9921, F1: 0.9916
# Val Loss: 2.3772, Accuracy: 0.3077, F1: 0.2909
# Val Precision: 0.2875, Recall: 0.2976
#
# Epoch 18/50:
# Train Loss: 0.0577, Accuracy: 0.9762, F1: 0.9748
# Val Loss: 2.3410, Accuracy: 0.3077, F1: 0.2909
# Val Precision: 0.2875, Recall: 0.2976
#
# Epoch 19/50:
# Train Loss: 0.0442, Accuracy: 0.9921, F1: 0.9916
# Val Loss: 2.3480, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 20/50:
# Train Loss: 0.0293, Accuracy: 0.9921, F1: 0.9917
# Val Loss: 2.3837, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 21/50:
# Train Loss: 0.0146, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.3818, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 22/50:
# Train Loss: 0.0138, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.3751, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 23/50:
# Train Loss: 0.0467, Accuracy: 0.9841, F1: 0.9831
# Val Loss: 2.3406, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 24/50:
# Train Loss: 0.0152, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.3917, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 25/50:
# Train Loss: 0.0229, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.3796, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 26/50:
# Train Loss: 0.0205, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.4038, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 27/50:
# Train Loss: 0.0240, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.3971, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 28/50:
# Train Loss: 0.0226, Accuracy: 0.9921, F1: 0.9917
# Val Loss: 2.4084, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 29/50:
# Train Loss: 0.0958, Accuracy: 0.9762, F1: 0.9756
# Val Loss: 2.4334, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 30/50:
# Train Loss: 0.0290, Accuracy: 0.9921, F1: 0.9917
# Val Loss: 2.4599, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 31/50:
# Train Loss: 0.0443, Accuracy: 0.9841, F1: 0.9833
# Val Loss: 2.4320, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 32/50:
# Train Loss: 0.0346, Accuracy: 0.9921, F1: 0.9917
# Val Loss: 2.4320, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 33/50:
# Train Loss: 0.0266, Accuracy: 0.9921, F1: 0.9916
# Val Loss: 2.4144, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 34/50:
# Train Loss: 0.0163, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.4134, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 35/50:
# Train Loss: 0.0335, Accuracy: 0.9921, F1: 0.9916
# Val Loss: 2.4309, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 36/50:
# Train Loss: 0.0179, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.4360, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 37/50:
# Train Loss: 0.0212, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.4433, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 38/50:
# Train Loss: 0.0236, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.4638, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 39/50:
# Train Loss: 0.0209, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.4241, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 40/50:
# Train Loss: 0.0187, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.4641, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 41/50:
# Train Loss: 0.0137, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.4521, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 42/50:
# Train Loss: 0.0130, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.4223, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 43/50:
# Train Loss: 0.0217, Accuracy: 0.9921, F1: 0.9917
# Val Loss: 2.4256, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 44/50:
# Train Loss: 0.0173, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.4201, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 45/50:
# Train Loss: 0.0274, Accuracy: 0.9921, F1: 0.9917
# Val Loss: 2.4232, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 46/50:
# Train Loss: 0.0318, Accuracy: 0.9921, F1: 0.9917
# Val Loss: 2.4420, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 47/50:
# Train Loss: 0.0148, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.4700, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 48/50:
# Train Loss: 0.0279, Accuracy: 0.9921, F1: 0.9916
# Val Loss: 2.4375, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 49/50:
# Train Loss: 0.0264, Accuracy: 0.9921, F1: 0.9916
# Val Loss: 2.4386, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Epoch 50/50:
# Train Loss: 0.0227, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 2.4290, Accuracy: 0.2308, F1: 0.1875
# Val Precision: 0.1667, Recall: 0.2143
#
# Fold 10 Metrics:
# Accuracy: 0.6154, F1-score: 0.6667, Precision: 0.5556, Recall: 0.8333
#
#
# ========== Final Cross-Validation Results ==========
# Avg Accuracy: 0.7044, Avg F1-score: 0.7132, Avg Precision: 0.7024, Avg Recall: 0.7738

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset
from collections import Counter
import numpy as np
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import pandas as pd
import re
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.model_selection import StratifiedKFold
import sys


# -----------------------------
# 1. Text Preprocessing Classes
# -----------------------------
class TextPreprocessor:
    def __init__(self, max_vocab_size=15000, max_seq_length=128):
        self.max_vocab_size = max_vocab_size
        self.max_seq_length = max_seq_length
        self.word2idx = {'<PAD>': 0, '<UNK>': 1}
        self.idx2word = {0: '<PAD>', 1: '<UNK>'}
        self.word_counts = Counter()
        
    def clean_text(self, text):
        text = str(text).lower()
        text = re.sub(r'[^a-zA-Z0-9\s.,!?]', '', text)
        text = ' '.join(text.split())
        return text
        
    def fit(self, texts):
        for text in texts:
            cleaned_text = self.clean_text(text)
            words = cleaned_text.split()
            self.word_counts.update(words)
        
        # Reserve two indices for PAD and UNK tokens
        vocab_words = [word for word, count in self.word_counts.most_common(self.max_vocab_size - 2)]
        for word in vocab_words:
            idx = len(self.word2idx)
            self.word2idx[word] = idx
            self.idx2word[idx] = word
    
    def transform(self, texts):
        sequences = []
        for text in texts:
            cleaned_text = self.clean_text(text)
            words = cleaned_text.split()
            # Truncate or pad sequences
            seq = [self.word2idx.get(word, self.word2idx['<UNK>']) for word in words[:self.max_seq_length]]
            seq = seq + [self.word2idx['<PAD>']] * (self.max_seq_length - len(seq))
            sequences.append(seq)
        return torch.tensor(sequences)

class TextDataset(Dataset):
    def __init__(self, texts, labels):
        self.texts = texts
        self.labels = labels
        
    def __len__(self):
        return len(self.texts)
    
    def __getitem__(self, idx):
        return self.texts[idx], self.labels[idx]

# -----------------------------
# 2. Define the Model
# -----------------------------
class ImprovedTextClassifier(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_classes, num_layers=2):
        super(ImprovedTextClassifier, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        self.embedding_dropout = nn.Dropout(0.2 if num_layers > 1 else 0.1)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, num_layers=num_layers, 
                            batch_first=True, bidirectional=True,
                            dropout=0.2 if num_layers > 1 else 0)
        self.attention = nn.Linear(hidden_dim * 2, 1)
        self.fc1 = nn.Linear(hidden_dim * 2, hidden_dim)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.dropout1 = nn.Dropout(0.3)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim // 2)
        self.bn2 = nn.BatchNorm1d(hidden_dim // 2)
        self.dropout2 = nn.Dropout(0.2)
        self.fc3 = nn.Linear(hidden_dim // 2, num_classes)
        
    def attention_net(self, lstm_output):
        # Compute attention weights and context vector
        energy = torch.tanh(self.attention(lstm_output))
        attention_weights = torch.softmax(self.attention(lstm_output), dim=1)
        context_vector = torch.sum(attention_weights * lstm_output, dim=1)
        return context_vector
        
    def forward(self, x):
        embedded = self.embedding(x)
        embedded = self.embedding_dropout(embedded)
        lstm_out, _ = self.lstm(embedded)
        attn_out = self.attention_net(lstm_out)
        x = self.fc1(attn_out)
        x = self.bn1(x)
        x = torch.relu(x)
        x = self.dropout1(x)
        x = self.fc2(x)
        x = self.bn2(x)
        x = torch.relu(x)
        x = self.dropout2(x)
        x = self.fc3(x)
        return x

# -----------------------------
# 3. Function to Load Pretrained Embeddings (GloVe)
# -----------------------------
def load_pretrained_embeddings(embedding_path, word2idx, embed_dim):
    print("Loading pretrained embeddings...")
    sys.stdout.flush()
    # Initialize embeddings with a uniform distribution
    embeddings = np.random.uniform(-0.05, 0.05, (len(word2idx), embed_dim))
    embeddings[word2idx['<PAD>']] = np.zeros(embed_dim)
    found = 0
    with open(embedding_path, 'r', encoding='utf-8') as f:
        for line in f:
            values = line.rstrip().split(' ')
            word = values[0]
            vector = np.asarray(values[1:], dtype='float32')
            if vector.shape[0] != embed_dim:
                continue  # Skip if dimensions mismatch
            if word in word2idx:
                embeddings[word2idx[word]] = vector
                found += 1
    print(f"Found {found} pretrained embeddings out of {len(word2idx)} words", flush=True)
    sys.stdout.flush()
    return torch.tensor(embeddings, dtype=torch.float)

# -----------------------------
# 4. Training Function
# -----------------------------
def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs, device, preprocessor, config):
    best_f1 = 0
    #patience = 5
    # patience_counter = 0
    
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        train_preds = []
        train_labels = []
        
        for batch_texts, batch_labels in train_loader:
            batch_texts, batch_labels = batch_texts.to(device), batch_labels.to(device)
            optimizer.zero_grad()
            outputs = model(batch_texts)
            loss = criterion(outputs, batch_labels)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            train_loss += loss.item()
            predictions = torch.argmax(outputs, dim=1)
            train_preds.extend(predictions.cpu().numpy())
            train_labels.extend(batch_labels.cpu().numpy())
        
        model.eval()
        val_loss = 0
        val_preds = []
        val_labels = []
        
        with torch.no_grad():
            for batch_texts, batch_labels in val_loader:
                batch_texts, batch_labels = batch_texts.to(device), batch_labels.to(device)
                outputs = model(batch_texts)
                loss = criterion(outputs, batch_labels)
                val_loss += loss.item()
                predictions = torch.argmax(outputs, dim=1)
                val_preds.extend(predictions.cpu().numpy())
                val_labels.extend(batch_labels.cpu().numpy())
        
        train_precision, train_recall, train_f1, _ = precision_recall_fscore_support(train_labels, train_preds, average='binary')
        train_accuracy = accuracy_score(train_labels, train_preds)
        
        val_precision, val_recall, val_f1, _ = precision_recall_fscore_support(val_labels, val_preds, average='macro', zero_division=1)
        val_accuracy = accuracy_score(val_labels, val_preds)
        
        scheduler.step(val_loss)
        
        print(f'Epoch {epoch+1}/{num_epochs}:', flush=True)
        sys.stdout.flush()

        print(f'Train Loss: {train_loss/len(train_loader):.4f}, Accuracy: {train_accuracy:.4f}, F1: {train_f1:.4f}', flush=True)
        sys.stdout.flush()

        print(f'Val Loss: {val_loss/len(val_loader):.4f}, Accuracy: {val_accuracy:.4f}, F1: {val_f1:.4f}', flush=True)
        sys.stdout.flush()
        print(f'Val Precision: {val_precision:.4f}, Recall: {val_recall:.4f}\n', flush=True)
        sys.stdout.flush()
        
        if val_f1 > best_f1:
            best_f1 = val_f1
            torch.save({
                'model_state_dict': model.state_dict(),
                'preprocessor': preprocessor,
                'config': config
            }, 'best_model.pt')
            #patience_counter = 0
            #patience_counter += 1
            
        # if patience_counter >= patience:

        #     print(f'Early stopping triggered after epoch {epoch+1}')
        #     break

# -----------------------------
# 5. Configuration and Data Loading
# -----------------------------
config = {
    'max_vocab_size': 15000,
    'max_seq_length': 128,
    'embed_dim': 300,  # Must match the dimension of the pretrained embeddings
    'hidden_dim': 256,
    'batch_size': 16,
    'learning_rate': 0.001,
    'num_epochs': 50,
    'num_lstm_layers': 2,
    'pretrained_embedding_path': '/Users/User/CSProjects/CSC392_AI_agent/emphatic-AI-Winter2025/glove.6B/glove.6B.300d.txt'  # Update this path as needed
}  

# Load your datasets (assumed to be in TSV format)
train_df = pd.read_csv('train.tsv', sep='\t')
test_df = pd.read_csv('test.tsv', sep='\t')

# Map your string labels to numerical values
label_mapping = {'NOCUOUS': 0, 'INNOCUOUS': 1}
train_df['Detected as'] = train_df['Detected as'].map(label_mapping)
test_df['Detected as'] = test_df['Detected as'].map(label_mapping)

# -----------------------------
# 6. Preprocessing
# -----------------------------
preprocessor = TextPreprocessor(max_vocab_size=config['max_vocab_size'], 
                                max_seq_length=config['max_seq_length'])
preprocessor.fit(train_df['Sentence'])

X_train = preprocessor.transform(train_df['Sentence'])
X_val = preprocessor.transform(test_df['Sentence'])
y_train = torch.tensor(train_df['Detected as'].values)
y_val = torch.tensor(test_df['Detected as'].values)

train_dataset = TextDataset(X_train, y_train)
val_dataset = TextDataset(X_val, y_val)

train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=config['batch_size'])

x_np = X_train.numpy()
y_np = y_train.numpy()

# ----------------------------
# 7. 10-Fold Cross Validation
# ----------------------------

num_folds = 5
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

fold_results = []

for fold, (train_idx, val_idx) in enumerate(skf.split(x_np, y_np)): #here
    print(f"\n------- Fold {fold+1} / {num_folds} --------- ", flush=True)
    sys.stdout.flush()


    # -----------------------------
    # 1. Split Data
    # -----------------------------
    X_train_fold = torch.tensor(x_np[train_idx])
    y_train_fold = torch.tensor(y_np[train_idx])
    X_val_fold = torch.tensor(x_np[val_idx])
    y_val_fold = torch.tensor(y_np[val_idx])

    train_dataset = TextDataset(X_train_fold, y_train_fold)
    val_dataset = TextDataset(X_val_fold, y_val_fold)

    train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=config['batch_size'])

    # -----------------------------
    # 2. Initialize Model, Optimizer, and Criterion Inside the Loop
    # -----------------------------
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    model = ImprovedTextClassifier(
        vocab_size=len(preprocessor.word2idx),
        embed_dim=config['embed_dim'],
        hidden_dim=config['hidden_dim'],
        num_classes=2,
    ).to(device)

    # Load pretrained embeddings and replace the embedding layer weights
    pretrained_weights = load_pretrained_embeddings(config['pretrained_embedding_path'], 
                                                    preprocessor.word2idx, 
                                                    config['embed_dim'])
    model.embedding = nn.Embedding.from_pretrained(pretrained_weights, freeze=False, padding_idx=0)

    # Compute class weights to handle class imbalance
    small_factor = 1e-4
    class_counts = torch.bincount(y_train_fold) + small_factor  # Avoid division by zero
    class_weights = 1.0 / class_counts.float()
    class_weights = class_weights / class_weights.sum()
    class_weights = class_weights.to(device)

    # criterion = nn.CrossEntropyLoss(weight=class_weights)
    optimizer = optim.AdamW(model.parameters(), lr=config['learning_rate'], weight_decay=0.01)
    # scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2, verbose=True)

    criterion = nn.CrossEntropyLoss()
    # optimizer = optim.Adam(model.parameters(), lr=config['learning_rate'])
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2)


    # -----------------------------
    # 3. Train the Model
    # -----------------------------
    train_model(model, train_loader, val_loader, criterion, optimizer, scheduler,
                config['num_epochs'], device, preprocessor, config)

    # Load the best model for this fold
    with torch.serialization.safe_globals([TextPreprocessor]):
        checkpoint = torch.load('best_model.pt', weights_only=False)

    # Save best model after training
    # torch.save(model.state_dict(), f'best_model_fold{fold+1}.pt')

    # # Load best model for evaluation
    # model.load_state_dict(torch.load(f'best_model_fold{fold+1}.pt'))


    #model.load_state_dict(checkpoint['model_state_dict'])

    # -----------------------------
    # 4. Evaluate the Model
    # -----------------------------
    model.eval()
    val_preds = []
    val_labels = []

    with torch.no_grad():
        for batch_texts, batch_labels in val_loader:
            batch_texts, batch_labels = batch_texts.to(device), batch_labels.to(device)
            outputs = model(batch_texts)
            predictions = torch.argmax(outputs, dim=1)
            val_preds.extend(predictions.cpu().numpy())
            val_labels.extend(batch_labels.cpu().numpy())

    # Compute metrics
    val_precision, val_recall, val_f1, _ = precision_recall_fscore_support(val_labels, val_preds, average='binary')
    val_accuracy = accuracy_score(val_labels, val_preds)

    print(f"Fold {fold+1} Metrics:", flush=True)
    sys.stdout.flush()
    print(f"Accuracy: {val_accuracy:.4f}, F1-score: {val_f1:.4f}, Precision: {val_precision:.4f}, Recall: {val_recall:.4f}\n", flush=True)
    sys.stdout.flush()


    fold_results.append((val_accuracy, val_f1, val_precision, val_recall))

# -----------------------------
# 5. Display Overall Results
# -----------------------------

avg_results = np.mean(fold_results, axis=0)
print(f"\nAverage Metrics Over {num_folds} Folds:")
sys.stdout.flush()

print(f"Accuracy: {avg_results[0]:.4f}, F1-score: {avg_results[1]:.4f}, Precision: {avg_results[2]:.4f}, Recall: {avg_results[3]:.4f}")
sys.stdout.flush()


avg_accuracy = sum([x[0] for x in fold_results]) / num_folds
avg_f1 = sum([x[1] for x in fold_results]) / num_folds
avg_precision = sum([x[2] for x in fold_results]) / num_folds
avg_recall = sum([x[3] for x in fold_results]) / num_folds

print("\n========== Final Cross-Validation Results ==========")
sys.stdout.flush()

print(f"Avg Accuracy: {avg_accuracy:.4f}, Avg F1-score: {avg_f1:.4f}, Avg Precision: {avg_precision:.4f}, Avg Recall: {avg_recall:.4f}")
sys.stdout.flush()
# Out:
# ------- Fold 1 / 5 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# Epoch 1/50:
# Train Loss: 0.7789, Accuracy: 0.4955, F1: 0.5254
# Val Loss: 0.6883, Accuracy: 0.5357, F1: 0.3488
# Val Precision: 0.7679, Recall: 0.5000
#
# Epoch 2/50:
# Train Loss: 0.5917, Accuracy: 0.7027, F1: 0.7080
# Val Loss: 0.6902, Accuracy: 0.5357, F1: 0.3488
# Val Precision: 0.7679, Recall: 0.5000
#
# Epoch 3/50:
# Train Loss: 0.5127, Accuracy: 0.7748, F1: 0.7706
# Val Loss: 0.6946, Accuracy: 0.5357, F1: 0.5303
# Val Precision: 0.5500, Recall: 0.5462
#
# Epoch 4/50:
# Train Loss: 0.3718, Accuracy: 0.8649, F1: 0.8544
# Val Loss: 0.6756, Accuracy: 0.7857, F1: 0.7846
# Val Precision: 0.7846, Recall: 0.7846
#
# Epoch 5/50:
# Train Loss: 0.2396, Accuracy: 0.9099, F1: 0.9038
# Val Loss: 0.6605, Accuracy: 0.8214, F1: 0.8212
# Val Precision: 0.8214, Recall: 0.8231
#
# Epoch 6/50:
# Train Loss: 0.3198, Accuracy: 0.8649, F1: 0.8624
# Val Loss: 0.6719, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6578, Recall: 0.6513
#
# Epoch 7/50:
# Train Loss: 0.1600, Accuracy: 0.9640, F1: 0.9623
# Val Loss: 0.6774, Accuracy: 0.6786, F1: 0.6782
# Val Precision: 0.6875, Recall: 0.6846
#
# Epoch 8/50:
# Train Loss: 0.1827, Accuracy: 0.9189, F1: 0.9174
# Val Loss: 1.4741, Accuracy: 0.4643, F1: 0.3665
# Val Precision: 0.4808, Recall: 0.4949
#
# Epoch 9/50:
# Train Loss: 0.1536, Accuracy: 0.9640, F1: 0.9630
# Val Loss: 0.9180, Accuracy: 0.6786, F1: 0.6748
# Val Precision: 0.7056, Recall: 0.6897
#
# Epoch 10/50:
# Train Loss: 0.0694, Accuracy: 0.9550, F1: 0.9541
# Val Loss: 0.8022, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6578, Recall: 0.6513
#
# Epoch 11/50:
# Train Loss: 0.0546, Accuracy: 0.9820, F1: 0.9811
# Val Loss: 0.8942, Accuracy: 0.6429, F1: 0.6111
# Val Precision: 0.6667, Recall: 0.6256
#
# Epoch 12/50:
# Train Loss: 0.0351, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 0.9200, Accuracy: 0.7857, F1: 0.7846
# Val Precision: 0.7846, Recall: 0.7846
#
# Epoch 13/50:
# Train Loss: 0.0555, Accuracy: 0.9730, F1: 0.9709
# Val Loss: 1.3059, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6578, Recall: 0.6513
#
# Epoch 14/50:
# Train Loss: 0.0470, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.3759, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5965, Recall: 0.5846
#
# Epoch 15/50:
# Train Loss: 0.0416, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.1424, Accuracy: 0.6429, F1: 0.6410
# Val Precision: 0.6578, Recall: 0.6513
#
# Epoch 16/50:
# Train Loss: 0.0237, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1104, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 17/50:
# Train Loss: 0.1228, Accuracy: 0.9640, F1: 0.9623
# Val Loss: 1.0860, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 18/50:
# Train Loss: 0.0501, Accuracy: 0.9910, F1: 0.9907
# Val Loss: 1.0466, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 19/50:
# Train Loss: 0.0342, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.0350, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 20/50:
# Train Loss: 0.0203, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0269, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 21/50:
# Train Loss: 0.0193, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0128, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 22/50:
# Train Loss: 0.0315, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0029, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 23/50:
# Train Loss: 0.0284, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0254, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 24/50:
# Train Loss: 0.0203, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0171, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 25/50:
# Train Loss: 0.0266, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0317, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 26/50:
# Train Loss: 0.0851, Accuracy: 0.9730, F1: 0.9709
# Val Loss: 1.0541, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 27/50:
# Train Loss: 0.0253, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0541, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 28/50:
# Train Loss: 0.0445, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.0495, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 29/50:
# Train Loss: 0.0317, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0467, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 30/50:
# Train Loss: 0.0169, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0243, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 31/50:
# Train Loss: 0.0192, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0418, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 32/50:
# Train Loss: 0.0212, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0451, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 33/50:
# Train Loss: 0.0402, Accuracy: 0.9910, F1: 0.9907
# Val Loss: 1.0297, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 34/50:
# Train Loss: 0.0204, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0319, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 35/50:
# Train Loss: 0.0230, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0291, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 36/50:
# Train Loss: 0.0210, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0268, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 37/50:
# Train Loss: 0.0571, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.0559, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 38/50:
# Train Loss: 0.0306, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.0547, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 39/50:
# Train Loss: 0.0531, Accuracy: 0.9820, F1: 0.9811
# Val Loss: 1.0416, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 40/50:
# Train Loss: 0.0452, Accuracy: 0.9820, F1: 0.9811
# Val Loss: 1.0866, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 41/50:
# Train Loss: 0.1011, Accuracy: 0.9640, F1: 0.9615
# Val Loss: 1.0925, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 42/50:
# Train Loss: 0.0288, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0752, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 43/50:
# Train Loss: 0.0214, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0545, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 44/50:
# Train Loss: 0.0142, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0311, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 45/50:
# Train Loss: 0.0222, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0502, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 46/50:
# Train Loss: 0.0271, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.0335, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 47/50:
# Train Loss: 0.0164, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0151, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 48/50:
# Train Loss: 0.0588, Accuracy: 0.9730, F1: 0.9720
# Val Loss: 1.0342, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 49/50:
# Train Loss: 0.0163, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0259, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Epoch 50/50:
# Train Loss: 0.0175, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.0238, Accuracy: 0.7143, F1: 0.7143
# Val Precision: 0.7179, Recall: 0.7179
#
# Fold 1 Metrics:
# Accuracy: 0.7143, F1-score: 0.7143, Precision: 0.6667, Recall: 0.7692
#
#
# ------- Fold 2 / 5 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# Epoch 1/50:
# Train Loss: 0.7678, Accuracy: 0.4595, F1: 0.5000
# Val Loss: 0.6965, Accuracy: 0.4643, F1: 0.3171
# Val Precision: 0.7321, Recall: 0.5000
#
# Epoch 2/50:
# Train Loss: 0.6232, Accuracy: 0.6757, F1: 0.6786
# Val Loss: 0.6899, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.2593, Recall: 0.4667
#
# Epoch 3/50:
# Train Loss: 0.4869, Accuracy: 0.7928, F1: 0.7810
# Val Loss: 0.6869, Accuracy: 0.5357, F1: 0.3488
# Val Precision: 0.7679, Recall: 0.5000
#
# Epoch 4/50:
# Train Loss: 0.3564, Accuracy: 0.8559, F1: 0.8462
# Val Loss: 0.6683, Accuracy: 0.5357, F1: 0.3488
# Val Precision: 0.7679, Recall: 0.5000
#
# Epoch 5/50:
# Train Loss: 0.2133, Accuracy: 0.9279, F1: 0.9245
# Val Loss: 0.6843, Accuracy: 0.5357, F1: 0.3488
# Val Precision: 0.7679, Recall: 0.5000
#
# Epoch 6/50:
# Train Loss: 0.2650, Accuracy: 0.8919, F1: 0.8868
# Val Loss: 0.6947, Accuracy: 0.6071, F1: 0.5942
# Val Precision: 0.6056, Recall: 0.5974
#
# Epoch 7/50:
# Train Loss: 0.1324, Accuracy: 0.9820, F1: 0.9811
# Val Loss: 0.7689, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5668, Recall: 0.5641
#
# Epoch 8/50:
# Train Loss: 0.1093, Accuracy: 0.9550, F1: 0.9533
# Val Loss: 0.9113, Accuracy: 0.5714, F1: 0.5508
# Val Precision: 0.5673, Recall: 0.5590
#
# Epoch 9/50:
# Train Loss: 0.1096, Accuracy: 0.9730, F1: 0.9709
# Val Loss: 0.9964, Accuracy: 0.6429, F1: 0.6257
# Val Precision: 0.6491, Recall: 0.6308
#
# Epoch 10/50:
# Train Loss: 0.0932, Accuracy: 0.9820, F1: 0.9808
# Val Loss: 1.1815, Accuracy: 0.6429, F1: 0.6354
# Val Precision: 0.6417, Recall: 0.6359
#
# Epoch 11/50:
# Train Loss: 0.0279, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6904, Accuracy: 0.4643, F1: 0.4581
# Val Precision: 0.4722, Recall: 0.4744
#
# Epoch 12/50:
# Train Loss: 0.0622, Accuracy: 0.9730, F1: 0.9725
# Val Loss: 1.3408, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 13/50:
# Train Loss: 0.0733, Accuracy: 0.9820, F1: 0.9815
# Val Loss: 1.2799, Accuracy: 0.6429, F1: 0.6257
# Val Precision: 0.6491, Recall: 0.6308
#
# Epoch 14/50:
# Train Loss: 0.0435, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.2849, Accuracy: 0.6429, F1: 0.6354
# Val Precision: 0.6417, Recall: 0.6359
#
# Epoch 15/50:
# Train Loss: 0.0207, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7427, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5080, Recall: 0.5077
#
# Epoch 16/50:
# Train Loss: 0.0422, Accuracy: 0.9910, F1: 0.9907
# Val Loss: 1.4845, Accuracy: 0.6429, F1: 0.6354
# Val Precision: 0.6417, Recall: 0.6359
#
# Epoch 17/50:
# Train Loss: 0.0732, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.5998, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 18/50:
# Train Loss: 0.0126, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7868, Accuracy: 0.5714, F1: 0.5692
# Val Precision: 0.5692, Recall: 0.5692
#
# Epoch 19/50:
# Train Loss: 0.0114, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7902, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5744, Recall: 0.5744
#
# Epoch 20/50:
# Train Loss: 0.0889, Accuracy: 0.9820, F1: 0.9815
# Val Loss: 1.7680, Accuracy: 0.5357, F1: 0.5351
# Val Precision: 0.5357, Recall: 0.5359
#
# Epoch 21/50:
# Train Loss: 0.0144, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7047, Accuracy: 0.5714, F1: 0.5692
# Val Precision: 0.5692, Recall: 0.5692
#
# Epoch 22/50:
# Train Loss: 0.0105, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6317, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 23/50:
# Train Loss: 0.0201, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6226, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 24/50:
# Train Loss: 0.0113, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6315, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 25/50:
# Train Loss: 0.0120, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6308, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 26/50:
# Train Loss: 0.0161, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6346, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 27/50:
# Train Loss: 0.0188, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6514, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 28/50:
# Train Loss: 0.0086, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.7215, Accuracy: 0.5714, F1: 0.5692
# Val Precision: 0.5692, Recall: 0.5692
#
# Epoch 29/50:
# Train Loss: 0.0562, Accuracy: 0.9910, F1: 0.9907
# Val Loss: 1.7242, Accuracy: 0.5714, F1: 0.5692
# Val Precision: 0.5692, Recall: 0.5692
#
# Epoch 30/50:
# Train Loss: 0.0108, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6428, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 31/50:
# Train Loss: 0.0180, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6389, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 32/50:
# Train Loss: 0.0271, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6587, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 33/50:
# Train Loss: 0.0127, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6461, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 34/50:
# Train Loss: 0.0123, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6365, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 35/50:
# Train Loss: 0.0141, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6362, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 36/50:
# Train Loss: 0.0142, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6505, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 37/50:
# Train Loss: 0.0438, Accuracy: 0.9910, F1: 0.9907
# Val Loss: 1.6369, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 38/50:
# Train Loss: 0.0159, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6638, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 39/50:
# Train Loss: 0.0097, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6562, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 40/50:
# Train Loss: 0.0153, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6569, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 41/50:
# Train Loss: 0.0170, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6486, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 42/50:
# Train Loss: 0.0140, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6408, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 43/50:
# Train Loss: 0.0128, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6348, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 44/50:
# Train Loss: 0.0117, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6404, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 45/50:
# Train Loss: 0.0111, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6336, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 46/50:
# Train Loss: 0.0174, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6362, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 47/50:
# Train Loss: 0.0127, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6412, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 48/50:
# Train Loss: 0.0110, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6407, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 49/50:
# Train Loss: 0.0120, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6421, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Epoch 50/50:
# Train Loss: 0.0136, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.6483, Accuracy: 0.6071, F1: 0.6026
# Val Precision: 0.6042, Recall: 0.6026
#
# Fold 2 Metrics:
# Accuracy: 0.6071, F1-score: 0.5600, Precision: 0.5833, Recall: 0.5385
#
#
# ------- Fold 3 / 5 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# Epoch 1/50:
# Train Loss: 0.7681, Accuracy: 0.4234, F1: 0.2381
# Val Loss: 0.6894, Accuracy: 0.5357, F1: 0.3488
# Val Precision: 0.7679, Recall: 0.5000
#
# Epoch 2/50:
# Train Loss: 0.6100, Accuracy: 0.6577, F1: 0.6122
# Val Loss: 0.6884, Accuracy: 0.5357, F1: 0.3488
# Val Precision: 0.7679, Recall: 0.5000
#
# Epoch 3/50:
# Train Loss: 0.5472, Accuracy: 0.7387, F1: 0.7238
# Val Loss: 0.6885, Accuracy: 0.5357, F1: 0.3488
# Val Precision: 0.7679, Recall: 0.5000
#
# Epoch 4/50:
# Train Loss: 0.4548, Accuracy: 0.8378, F1: 0.8269
# Val Loss: 0.6848, Accuracy: 0.5357, F1: 0.3488
# Val Precision: 0.7679, Recall: 0.5000
#
# Epoch 5/50:
# Train Loss: 0.3745, Accuracy: 0.8378, F1: 0.8302
# Val Loss: 0.6729, Accuracy: 0.6071, F1: 0.4992
# Val Precision: 0.7885, Recall: 0.5769
#
# Epoch 6/50:
# Train Loss: 0.3228, Accuracy: 0.8919, F1: 0.8868
# Val Loss: 0.6731, Accuracy: 0.6071, F1: 0.4992
# Val Precision: 0.7885, Recall: 0.5769
#
# Epoch 7/50:
# Train Loss: 0.2221, Accuracy: 0.9189, F1: 0.9143
# Val Loss: 0.6747, Accuracy: 0.6786, F1: 0.6748
# Val Precision: 0.7056, Recall: 0.6897
#
# Epoch 8/50:
# Train Loss: 0.1468, Accuracy: 0.9369, F1: 0.9346
# Val Loss: 0.8249, Accuracy: 0.5714, F1: 0.5333
# Val Precision: 0.6609, Recall: 0.5949
#
# Epoch 9/50:
# Train Loss: 0.1303, Accuracy: 0.9550, F1: 0.9524
# Val Loss: 0.7296, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5668, Recall: 0.5641
#
# Epoch 10/50:
# Train Loss: 0.1220, Accuracy: 0.9730, F1: 0.9709
# Val Loss: 0.8903, Accuracy: 0.6071, F1: 0.5810
# Val Precision: 0.6125, Recall: 0.5923
#
# Epoch 11/50:
# Train Loss: 0.1244, Accuracy: 0.9459, F1: 0.9423
# Val Loss: 0.9939, Accuracy: 0.6786, F1: 0.6782
# Val Precision: 0.6875, Recall: 0.6846
#
# Epoch 12/50:
# Train Loss: 0.0576, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 0.9849, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5668, Recall: 0.5641
#
# Epoch 13/50:
# Train Loss: 0.0486, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.1011, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5744, Recall: 0.5744
#
# Epoch 14/50:
# Train Loss: 0.0501, Accuracy: 0.9820, F1: 0.9811
# Val Loss: 1.1399, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5668, Recall: 0.5641
#
# Epoch 15/50:
# Train Loss: 0.0353, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.1747, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 16/50:
# Train Loss: 0.0659, Accuracy: 0.9820, F1: 0.9808
# Val Loss: 1.1866, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5668, Recall: 0.5641
#
# Epoch 17/50:
# Train Loss: 0.0381, Accuracy: 0.9910, F1: 0.9907
# Val Loss: 1.2161, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 18/50:
# Train Loss: 0.0372, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.2192, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 19/50:
# Train Loss: 0.0311, Accuracy: 0.9910, F1: 0.9907
# Val Loss: 1.2081, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 20/50:
# Train Loss: 0.0275, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2360, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 21/50:
# Train Loss: 0.0377, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.2485, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 22/50:
# Train Loss: 0.0247, Accuracy: 0.9910, F1: 0.9907
# Val Loss: 1.2343, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 23/50:
# Train Loss: 0.0441, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.2374, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 24/50:
# Train Loss: 0.0455, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.2369, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 25/50:
# Train Loss: 0.0301, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.2179, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 26/50:
# Train Loss: 0.0540, Accuracy: 0.9910, F1: 0.9907
# Val Loss: 1.2372, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 27/50:
# Train Loss: 0.0213, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2176, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 28/50:
# Train Loss: 0.0399, Accuracy: 0.9910, F1: 0.9907
# Val Loss: 1.2106, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 29/50:
# Train Loss: 0.0329, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2133, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 30/50:
# Train Loss: 0.0212, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2205, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 31/50:
# Train Loss: 0.0219, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2163, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 32/50:
# Train Loss: 0.0399, Accuracy: 0.9910, F1: 0.9907
# Val Loss: 1.2369, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 33/50:
# Train Loss: 0.0412, Accuracy: 0.9910, F1: 0.9907
# Val Loss: 1.2349, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 34/50:
# Train Loss: 0.0167, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2146, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 35/50:
# Train Loss: 0.0329, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2199, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 36/50:
# Train Loss: 0.0302, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.2292, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 37/50:
# Train Loss: 0.0273, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2296, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 38/50:
# Train Loss: 0.0356, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.2101, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 39/50:
# Train Loss: 0.0269, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2176, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 40/50:
# Train Loss: 0.0221, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2193, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 41/50:
# Train Loss: 0.0265, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2270, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 42/50:
# Train Loss: 0.0609, Accuracy: 0.9730, F1: 0.9725
# Val Loss: 1.2337, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 43/50:
# Train Loss: 0.0236, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2169, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 44/50:
# Train Loss: 0.0364, Accuracy: 0.9910, F1: 0.9907
# Val Loss: 1.2159, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 45/50:
# Train Loss: 0.0412, Accuracy: 0.9820, F1: 0.9811
# Val Loss: 1.2235, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 46/50:
# Train Loss: 0.0250, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2283, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 47/50:
# Train Loss: 0.0272, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2276, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 48/50:
# Train Loss: 0.0226, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2238, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 49/50:
# Train Loss: 0.0389, Accuracy: 0.9910, F1: 0.9907
# Val Loss: 1.2198, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Epoch 50/50:
# Train Loss: 0.0253, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2071, Accuracy: 0.5357, F1: 0.5204
# Val Precision: 0.5278, Recall: 0.5256
#
# Fold 3 Metrics:
# Accuracy: 0.5357, F1-score: 0.4348, Precision: 0.5000, Recall: 0.3846
#
#
# ------- Fold 4 / 5 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# Epoch 1/50:
# Train Loss: 0.7735, Accuracy: 0.5856, F1: 0.6167
# Val Loss: 0.6972, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 2/50:
# Train Loss: 0.6021, Accuracy: 0.7027, F1: 0.6972
# Val Loss: 0.6948, Accuracy: 0.4286, F1: 0.4256
# Val Precision: 0.4271, Recall: 0.4286
#
# Epoch 3/50:
# Train Loss: 0.5376, Accuracy: 0.7658, F1: 0.7547
# Val Loss: 0.6942, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 4/50:
# Train Loss: 0.4265, Accuracy: 0.8018, F1: 0.7800
# Val Loss: 0.7155, Accuracy: 0.5000, F1: 0.3333
# Val Precision: 0.7500, Recall: 0.5000
#
# Epoch 5/50:
# Train Loss: 0.3112, Accuracy: 0.9009, F1: 0.8952
# Val Loss: 0.7316, Accuracy: 0.4643, F1: 0.4286
# Val Precision: 0.4524, Recall: 0.4643
#
# Epoch 6/50:
# Train Loss: 0.2113, Accuracy: 0.9189, F1: 0.9126
# Val Loss: 0.7534, Accuracy: 0.5000, F1: 0.4556
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 7/50:
# Train Loss: 0.1527, Accuracy: 0.9550, F1: 0.9533
# Val Loss: 0.8156, Accuracy: 0.5357, F1: 0.5303
# Val Precision: 0.5374, Recall: 0.5357
#
# Epoch 8/50:
# Train Loss: 0.2316, Accuracy: 0.9550, F1: 0.9524
# Val Loss: 1.3807, Accuracy: 0.5357, F1: 0.4822
# Val Precision: 0.5609, Recall: 0.5357
#
# Epoch 9/50:
# Train Loss: 0.1221, Accuracy: 0.9730, F1: 0.9709
# Val Loss: 1.0928, Accuracy: 0.5714, F1: 0.5625
# Val Precision: 0.5778, Recall: 0.5714
#
# Epoch 10/50:
# Train Loss: 0.1244, Accuracy: 0.9730, F1: 0.9709
# Val Loss: 1.4411, Accuracy: 0.5357, F1: 0.4822
# Val Precision: 0.5609, Recall: 0.5357
#
# Epoch 11/50:
# Train Loss: 0.0777, Accuracy: 0.9730, F1: 0.9720
# Val Loss: 1.2592, Accuracy: 0.5357, F1: 0.5048
# Val Precision: 0.5476, Recall: 0.5357
#
# Epoch 12/50:
# Train Loss: 0.1082, Accuracy: 0.9459, F1: 0.9412
# Val Loss: 1.1877, Accuracy: 0.5714, F1: 0.5692
# Val Precision: 0.5729, Recall: 0.5714
#
# Epoch 13/50:
# Train Loss: 0.1018, Accuracy: 0.9820, F1: 0.9811
# Val Loss: 1.2650, Accuracy: 0.5357, F1: 0.5303
# Val Precision: 0.5374, Recall: 0.5357
#
# Epoch 14/50:
# Train Loss: 0.0551, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.2788, Accuracy: 0.5714, F1: 0.5692
# Val Precision: 0.5729, Recall: 0.5714
#
# Epoch 15/50:
# Train Loss: 0.0607, Accuracy: 0.9820, F1: 0.9811
# Val Loss: 1.2769, Accuracy: 0.5000, F1: 0.4974
# Val Precision: 0.5000, Recall: 0.5000
#
# Epoch 16/50:
# Train Loss: 0.0395, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2638, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 17/50:
# Train Loss: 0.0305, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2574, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 18/50:
# Train Loss: 0.1198, Accuracy: 0.9550, F1: 0.9533
# Val Loss: 1.2958, Accuracy: 0.5357, F1: 0.5351
# Val Precision: 0.5359, Recall: 0.5357
#
# Epoch 19/50:
# Train Loss: 0.0518, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.2719, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 20/50:
# Train Loss: 0.0410, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.2596, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 21/50:
# Train Loss: 0.0291, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2567, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 22/50:
# Train Loss: 0.0429, Accuracy: 0.9910, F1: 0.9903
# Val Loss: 1.2590, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 23/50:
# Train Loss: 0.0381, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.2536, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 24/50:
# Train Loss: 0.0366, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2503, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 25/50:
# Train Loss: 0.0319, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2594, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 26/50:
# Train Loss: 0.0426, Accuracy: 0.9910, F1: 0.9903
# Val Loss: 1.2654, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 27/50:
# Train Loss: 0.0363, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2728, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 28/50:
# Train Loss: 0.1440, Accuracy: 0.9550, F1: 0.9495
# Val Loss: 1.2724, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 29/50:
# Train Loss: 0.0279, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2732, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 30/50:
# Train Loss: 0.0373, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2631, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 31/50:
# Train Loss: 0.0329, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2865, Accuracy: 0.5357, F1: 0.5351
# Val Precision: 0.5359, Recall: 0.5357
#
# Epoch 32/50:
# Train Loss: 0.0312, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2734, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 33/50:
# Train Loss: 0.0341, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2848, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 34/50:
# Train Loss: 0.0391, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2794, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 35/50:
# Train Loss: 0.0343, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.2723, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 36/50:
# Train Loss: 0.0284, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2767, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 37/50:
# Train Loss: 0.0447, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.2736, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 38/50:
# Train Loss: 0.0472, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.2789, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 39/50:
# Train Loss: 0.1129, Accuracy: 0.9730, F1: 0.9709
# Val Loss: 1.2859, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 40/50:
# Train Loss: 0.0491, Accuracy: 0.9910, F1: 0.9903
# Val Loss: 1.2838, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 41/50:
# Train Loss: 0.0522, Accuracy: 0.9820, F1: 0.9811
# Val Loss: 1.2787, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 42/50:
# Train Loss: 0.0366, Accuracy: 0.9910, F1: 0.9903
# Val Loss: 1.2796, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 43/50:
# Train Loss: 0.0450, Accuracy: 0.9910, F1: 0.9903
# Val Loss: 1.2707, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 44/50:
# Train Loss: 0.0568, Accuracy: 0.9820, F1: 0.9808
# Val Loss: 1.2685, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 45/50:
# Train Loss: 0.0297, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2733, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 46/50:
# Train Loss: 0.0434, Accuracy: 0.9910, F1: 0.9905
# Val Loss: 1.2747, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 47/50:
# Train Loss: 0.0327, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2738, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 48/50:
# Train Loss: 0.0338, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2624, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 49/50:
# Train Loss: 0.0295, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2733, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Epoch 50/50:
# Train Loss: 0.0489, Accuracy: 0.9820, F1: 0.9804
# Val Loss: 1.2775, Accuracy: 0.5714, F1: 0.5714
# Val Precision: 0.5714, Recall: 0.5714
#
# Fold 4 Metrics:
# Accuracy: 0.5714, F1-score: 0.5714, Precision: 0.5714, Recall: 0.5714
#
#
# ------- Fold 5 / 5 ---------
# Loading pretrained embeddings...
# Found 781 pretrained embeddings out of 999 words
# Epoch 1/50:
# Train Loss: 0.7540, Accuracy: 0.4554, F1: 0.4786
# Val Loss: 0.6915, Accuracy: 0.5185, F1: 0.3415
# Val Precision: 0.7593, Recall: 0.5000
#
# Epoch 2/50:
# Train Loss: 0.6342, Accuracy: 0.6696, F1: 0.6783
# Val Loss: 0.6864, Accuracy: 0.5185, F1: 0.3415
# Val Precision: 0.7593, Recall: 0.5000
#
# Epoch 3/50:
# Train Loss: 0.5175, Accuracy: 0.7321, F1: 0.7115
# Val Loss: 0.6936, Accuracy: 0.5185, F1: 0.3415
# Val Precision: 0.7593, Recall: 0.5000
#
# Epoch 4/50:
# Train Loss: 0.3591, Accuracy: 0.8839, F1: 0.8738
# Val Loss: 0.6820, Accuracy: 0.5185, F1: 0.3415
# Val Precision: 0.7593, Recall: 0.5000
#
# Epoch 5/50:
# Train Loss: 0.2786, Accuracy: 0.8571, F1: 0.8431
# Val Loss: 0.7018, Accuracy: 0.5185, F1: 0.3415
# Val Precision: 0.7593, Recall: 0.5000
#
# Epoch 6/50:
# Train Loss: 0.2071, Accuracy: 0.9286, F1: 0.9259
# Val Loss: 0.7648, Accuracy: 0.4074, F1: 0.3864
# Val Precision: 0.3889, Recall: 0.4011
#
# Epoch 7/50:
# Train Loss: 0.2086, Accuracy: 0.9196, F1: 0.9174
# Val Loss: 0.7906, Accuracy: 0.5926, F1: 0.5714
# Val Precision: 0.6020, Recall: 0.5852
#
# Epoch 8/50:
# Train Loss: 0.1736, Accuracy: 0.9375, F1: 0.9346
# Val Loss: 0.9575, Accuracy: 0.4444, F1: 0.4156
# Val Precision: 0.4243, Recall: 0.4368
#
# Epoch 9/50:
# Train Loss: 0.0705, Accuracy: 0.9911, F1: 0.9905
# Val Loss: 0.9806, Accuracy: 0.5926, F1: 0.5534
# Val Precision: 0.6190, Recall: 0.5824
#
# Epoch 10/50:
# Train Loss: 0.0487, Accuracy: 0.9911, F1: 0.9907
# Val Loss: 1.0656, Accuracy: 0.5926, F1: 0.5534
# Val Precision: 0.6190, Recall: 0.5824
#
# Epoch 11/50:
# Train Loss: 0.0341, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.2635, Accuracy: 0.4815, F1: 0.4631
# Val Precision: 0.4722, Recall: 0.4753
#
# Epoch 12/50:
# Train Loss: 0.0462, Accuracy: 0.9821, F1: 0.9811
# Val Loss: 1.4467, Accuracy: 0.4444, F1: 0.4414
# Val Precision: 0.4460, Recall: 0.4478
#
# Epoch 13/50:
# Train Loss: 0.0700, Accuracy: 0.9821, F1: 0.9811
# Val Loss: 1.4895, Accuracy: 0.4815, F1: 0.4808
# Val Precision: 0.4833, Recall: 0.4835
#
# Epoch 14/50:
# Train Loss: 0.0423, Accuracy: 0.9911, F1: 0.9907
# Val Loss: 1.4147, Accuracy: 0.5926, F1: 0.5903
# Val Precision: 0.5917, Recall: 0.5907
#
# Epoch 15/50:
# Train Loss: 0.0210, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5181, Accuracy: 0.5556, F1: 0.5549
# Val Precision: 0.5549, Recall: 0.5549
#
# Epoch 16/50:
# Train Loss: 0.0161, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5739, Accuracy: 0.5185, F1: 0.5159
# Val Precision: 0.5167, Recall: 0.5165
#
# Epoch 17/50:
# Train Loss: 0.0186, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5740, Accuracy: 0.5185, F1: 0.5159
# Val Precision: 0.5167, Recall: 0.5165
#
# Epoch 18/50:
# Train Loss: 0.0161, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5674, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 19/50:
# Train Loss: 0.0158, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5622, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 20/50:
# Train Loss: 0.0189, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5514, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 21/50:
# Train Loss: 0.0146, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5700, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 22/50:
# Train Loss: 0.0883, Accuracy: 0.9643, F1: 0.9630
# Val Loss: 1.5717, Accuracy: 0.5185, F1: 0.4935
# Val Precision: 0.5132, Recall: 0.5110
#
# Epoch 23/50:
# Train Loss: 0.0169, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5430, Accuracy: 0.5185, F1: 0.4935
# Val Precision: 0.5132, Recall: 0.5110
#
# Epoch 24/50:
# Train Loss: 0.0210, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5450, Accuracy: 0.5185, F1: 0.4935
# Val Precision: 0.5132, Recall: 0.5110
#
# Epoch 25/50:
# Train Loss: 0.0244, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5581, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 26/50:
# Train Loss: 0.0123, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5361, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 27/50:
# Train Loss: 0.0182, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5540, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 28/50:
# Train Loss: 0.0169, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5528, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 29/50:
# Train Loss: 0.0231, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5674, Accuracy: 0.4444, F1: 0.4414
# Val Precision: 0.4417, Recall: 0.4423
#
# Epoch 30/50:
# Train Loss: 0.0275, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5663, Accuracy: 0.4444, F1: 0.4414
# Val Precision: 0.4417, Recall: 0.4423
#
# Epoch 31/50:
# Train Loss: 0.0206, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5767, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 32/50:
# Train Loss: 0.0134, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5820, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 33/50:
# Train Loss: 0.0148, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5828, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 34/50:
# Train Loss: 0.0224, Accuracy: 0.9911, F1: 0.9905
# Val Loss: 1.5848, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 35/50:
# Train Loss: 0.0142, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5676, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 36/50:
# Train Loss: 0.0396, Accuracy: 0.9911, F1: 0.9907
# Val Loss: 1.5722, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 37/50:
# Train Loss: 0.0496, Accuracy: 0.9821, F1: 0.9815
# Val Loss: 1.5728, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 38/50:
# Train Loss: 0.0154, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5918, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 39/50:
# Train Loss: 0.0158, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5727, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 40/50:
# Train Loss: 0.0166, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5764, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 41/50:
# Train Loss: 0.0320, Accuracy: 0.9911, F1: 0.9905
# Val Loss: 1.5760, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 42/50:
# Train Loss: 0.0154, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5651, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 43/50:
# Train Loss: 0.0137, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5628, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 44/50:
# Train Loss: 0.0279, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5821, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 45/50:
# Train Loss: 0.0148, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5685, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 46/50:
# Train Loss: 0.0242, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5685, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 47/50:
# Train Loss: 0.0229, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5654, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 48/50:
# Train Loss: 0.0232, Accuracy: 0.9911, F1: 0.9905
# Val Loss: 1.5619, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 49/50:
# Train Loss: 0.0286, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5728, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Epoch 50/50:
# Train Loss: 0.0137, Accuracy: 1.0000, F1: 1.0000
# Val Loss: 1.5877, Accuracy: 0.4815, F1: 0.4750
# Val Precision: 0.4773, Recall: 0.4780
#
# Fold 5 Metrics:
# Accuracy: 0.4815, F1-score: 0.4167, Precision: 0.4545, Recall: 0.3846
#
#
# Average Metrics Over 5 Folds:
# Accuracy: 0.5820, F1-score: 0.5394, Precision: 0.5552, Recall: 0.5297
#
# ========== Final Cross-Validation Results ==========
# Avg Accuracy: 0.5820, Avg F1-score: 0.5394, Avg Precision: 0.5552, Avg Recall: 0.5297
